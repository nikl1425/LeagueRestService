# %%
# What version of Python do you have?
import sys
import os
import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import numpy as np
import mne
import pathlib
import openpyxl
from datetime import datetime
import pytz
import random
from skimage.restoration import (denoise_wavelet, estimate_sigma)
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, Sequential
# %matplotlib inline

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.5.0
# Keras Version: 2.5.0
#
# Python 3.9.7 (default, Sep 16 2021, 23:53:23)
# [Clang 12.0.0 ]
# Pandas 1.3.1
# Scikit-Learn 0.24.2
# GPU is available

# %% [markdown]
# # Reading data and data-details

# %% [markdown]
# Read in the eeg timestamps + details.
# Then format it so we can use the timestamps for automatic processing of the .EDF files

# %%
# Read data detail sheet

print(type(str(pathlib.Path().resolve())))
print(os.getcwd())

currentPath = str(pathlib.Path().resolve())

EEG_details = pd.ExcelFile("Dataset/Data_detail.xlsx", engine="openpyxl")
# Out:
# <class 'str'>
# /Users/niklashjort/Desktop/Notes/Speciale/projects

# %%
#Sheets to dataframes:

print(EEG_details.sheet_names)


xl_detailDf = EEG_details.parse("Ark1")
print(type(xl_detailDf))
xl_detailDf
# Out:
# ['Ark1']
# <class 'pandas.core.frame.DataFrame'>
#     sync  seizure      time_trial_eeg             time_emu      delay  \
# 0      1        0                 NaT                  NaN        NaN
# 1      1        0 2019-05-20 19:33:54  20-05-2019 19:32:37  77.000000
# 2      1        0 2019-05-21 13:00:59  21-05-2019 12:59:36  83.000000
# 3      0        1 2019-05-22 02:46:45  2019-05-22 02:45:22  83.000001
# 4      1        0 2019-05-22 02:47:01  2019-05-22 02:45:37  84.000000
# 5      0        2                 NaT  2019-05-22 03:50:49        NaN
# 6      1        0 2019-05-22 03:52:16  2019-05-22 03:50:53  83.000000
# 7      0        3                 NaT  2019-05-22 05:27:56        NaN
# 8      1        0 2019-05-22 05:29:18  2019-05-22 05:27:57  81.000000
# 9      0        4                 NaT  2019-05-22 07:07:04        NaN
# 10     1        0 2019-05-22 07:08:37  2019-05-22 07:07:16  81.000000
# 11     0        5                 NaT  2019-05-22 07:51:24        NaN
# 12     1        0 2019-05-22 07:29:29  2019-05-22 07:28:08  81.000000
# 13     0        6                 NaT  2019-05-22 08:13:42        NaN
# 14     1        0 2019-05-22 08:15:03  2019-05-22 08:13:43  80.000000
# 15     0        7                 NaT  2019-05-22 09:03:55        NaN
# 16     1        0 2019-05-22 09:05:28  2019-05-22 09:04:00  88.000000
# 17     0        8                 NaT  2019-05-22 09:41:47        NaN
# 18     1        0 2019-05-22 09:41:01  2019-05-22 09:39:34  87.000000
# 19     0        9                 NaT  2019-05-22 10:20:40        NaN
# 20     1        0 2019-05-22 10:22:27  2019-05-22 10:20:59  88.000000
# 21     1        0 2019-05-22 20:21:46  2019-05-22 20:20:23  83.000000
#
#     seiz_duration                                      file_name_EEG
# 0             NaN  20190520110039_p4dag1.sdeeg_converted_.easy_fi...
# 1             NaN  20190520160924_p4nat1.sdeeg_converted_.easy_fi...
# 2             NaN  20190521084849_p4dag2.sdeeg_converted_.easy_fi...
# 3            56.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 4             NaN                                        Ny Sync-tid
# 5            53.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 6             NaN                                        Ny Sync-tid
# 7            48.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 8             NaN                                        Ny Sync-tid
# 9            52.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 10            NaN                                        Ny Sync-tid
# 11           53.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 12            NaN                                        Ny Sync-tid
# 13           54.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 14            NaN                                        Ny Sync-tid
# 15           54.0  20190522090132_p4dag3.sdeeg_converted_.easy_fi...
# 16            NaN                                        Ny Sync-tid
# 17           60.0  20190522090132_p4dag3.sdeeg_converted_.easy_fi...
# 18            NaN                                        Ny Sync-tid
# 19           73.0  20190522090132_p4dag3.sdeeg_converted_.easy_fi...
# 20            NaN                                        Ny Sync-tid
# 21            NaN  20190522171939_p4nat3.sdeeg_converted_.easy_fi...

# %%
def get(file):
    dt = datetime.strptime( file[0:file.index('_')], '%Y%m%d%H%M%S')
    return dt.timestamp()*1000

def get2(data):
    dt = datetime.strptime(data, '%Y-%m-%d %H:%M:%S').timestamp() * 1000;
    return dt # convert seconds til miliseconds

x = datetime.strptime( "22-05-2019 03:50:49", '%d-%m-%Y %H:%M:%S').timestamp()*1000

y = get2("2019-05-22 09:03:55")

y = y - 30 * 1000

print(x)
print(y)
# Out:
# 1558489849000.0
# 1558508605000.0

# %% [markdown]
# Read .EDF file

# %%
# Get seizure timestamps, filenames to array

'''
# %m Month as a zero-padded decimal number.
# %H	Hour (24-hour clock) as a zero-padded decimal number.
# %Y	Year with century as a decimal number.
# %S	Second as a zero-padded decimal number.
# %M	Minute as a zero-padded decimal number.
# %d - Represents the day of the month. Example: 01, 02, ..., 31
'''

def get_sz_time_in_ms(data):
    dt = datetime.strptime(data, '%Y-%m-%d %H:%M:%S').timestamp() * 1000;
    return dt # convert seconds til miliseconds

"""
1. if sz duration != null pass hele rækken til df
2. fil navn, duration og starttid til liste
3. returner liste
"""

buffer = 30 # ONLY USE THIS IF PRED IS BAD

def get_sz_info(xlDataFrame):
    xl_info_list = []
    for index, row in xlDataFrame.iterrows():
        if(str(row.seiz_duration) != 'nan'):
            xl_info_list.append([row['file_name_EEG'], row['time_emu'], row['seiz_duration']])
            
    for row in xl_info_list:
        sz_duration = row[2]
        sz_start = get_sz_time_in_ms(str(row[1])) - (buffer * 1000)
        sz_end = sz_start + ((row[2] + buffer + buffer) * 1000)
        row.append(sz_start)
        row.append(sz_end)
    return xl_info_list
            
        
        
xl_info_formatted = get_sz_info(xl_detailDf)
xl_info_formatted
# Out:
# [['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 2, 45, 22),
#   56.0,
#   1558485892000.0,
#   1558486008000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 3, 50, 49),
#   53.0,
#   1558489819000.0,
#   1558489932000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 5, 27, 56),
#   48.0,
#   1558495646000.0,
#   1558495754000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 7, 7, 4),
#   52.0,
#   1558501594000.0,
#   1558501706000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 7, 51, 24),
#   53.0,
#   1558504254000.0,
#   1558504367000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 8, 13, 42),
#   54.0,
#   1558505592000.0,
#   1558505706000.0],
#  ['20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 9, 3, 55),
#   54.0,
#   1558508605000.0,
#   1558508719000.0],
#  ['20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 9, 41, 47),
#   60.0,
#   1558510877000.0,
#   1558510997000.0],
#  ['20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 10, 20, 40),
#   73.0,
#   1558513210000.0,
#   1558513343000.0]]

# %%
def GetAllEdfFileNames(directory):
    fileType = ".edf"
    files = os.listdir(directory)
    edfFileNameList = [(directory + "/" + x) for x in files if x.endswith(fileType)]
    return edfFileNameList

EEG_dataset= GetAllEdfFileNames("Dataset")

for file in EEG_dataset:
    print(file)

def ReadEdfFile(FileName):
    data = mne.io.read_raw_edf(FileName)
    raw_data = data.get_data()
    print("\n" + FileName.upper())
    print(data.info)
    print(type(raw_data)) # Numpy
    print(raw_data.shape)
    return raw_data, data.ch_names
# Out:
# Dataset/20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# Dataset/20190520160924_p4nat1.sdeeg_converted_.easy_filtered.edf
# Dataset/20190521084849_p4dag2.sdeeg_converted_.easy_filtered.edf
# Dataset/20190520110039_p4dag1.sdeeg_converted_.easy_filtered.edf
# Dataset/20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# Dataset/20190522171939_p4nat3.sdeeg_converted_.easy_filtered.edf

# %% [markdown]
# 1 / samplerate(500) = 2 ms

# %%
# Insert time stamp col in all dataframes function.

def get_time_in_ms(file):
    print(datetime.strptime( file[0:file.index('_')], '%Y%m%d%H%M%S'))
    dt = datetime.strptime( file[0:file.index('_')], '%Y%m%d%H%M%S')
    return dt.timestamp() * 1000 # convert seconds til miliseconds

df_list = list()

# Create dataframes, add col=timestamps, insert into df list

for file in EEG_dataset:
    currentEDF, channel = ReadEdfFile(file)
    df = pd.DataFrame(currentEDF.transpose(), columns=channel)
    timeStart = get_time_in_ms(file.replace("Dataset/", ""))
    df.insert(0, "timestampMS", [timeStart + x*2 for x in df.index])
    df_list.append([df, file.replace("Dataset/", "")])
# Out:
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190521155643_P4NAT2.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-21 15:56:43 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 32400000)
# 2019-05-21 15:56:43
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190520160924_p4nat1.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190520160924_P4NAT1.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-20 16:09:24 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 32400000)
# 2019-05-20 16:09:24
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190521084849_p4dag2.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190521084849_P4DAG2.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-21 08:48:49 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 12600000)
# 2019-05-21 08:48:49
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190520110039_p4dag1.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190520110039_P4DAG1.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-20 11:00:39 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 9900500)
# 2019-05-20 11:00:39
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190522090132_P4DAG3.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-22 09:01:32 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 3300500)
# 2019-05-22 09:01:32
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190522171939_p4nat3.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190522171939_P4NAT3.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-22 17:19:39 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 28800000)
# 2019-05-22 17:19:39

# %%
print(df_list[0][1])
print(len(df_list[0][0]))

32400000 - 32241994
# Out:
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 32400000
# 158006

# %%
# Loop trough the EEG files and extract data from sz_start to sz_end ==> place these in seperate data files.
sz_list = []

for info in xl_info_formatted:
    fileName = info[0]
    print("FILENAME: " + str(fileName))
    sz_start = info[3]
    sz_end = info[4]
    for dataobj in df_list:
        if(str(fileName) == str(dataobj[1])):
            print("DATAOBJ FILENAME: " + str(dataobj[1]))
            print('sz_start: ' + str(info[3]))
            print('sz_end: ' + str(info[4]))
            # insert only sz data into sz_list and insert non-sz data into non sz list
            sz = dataobj[0][(dataobj[0]['timestampMS'] >= sz_start) & (dataobj[0]['timestampMS'] <= sz_end)]
            sz_list.append([dataobj[1], "sz", sz])
            # only retain no-sz data in the original data
            dataobj[0] = dataobj[0][(dataobj[0]['timestampMS'] < sz_start) | (dataobj[0]['timestampMS'] > sz_end)]
        else:
           print("cannot split or find file")
# Out:
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558485892000.0
# sz_end: 1558486008000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558489819000.0
# sz_end: 1558489932000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558495646000.0
# sz_end: 1558495754000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558501594000.0
# sz_end: 1558501706000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558504254000.0
# sz_end: 1558504367000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558505592000.0
# sz_end: 1558505706000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# DATAOBJ FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558508605000.0
# sz_end: 1558508719000.0
# cannot split or find file
# FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# DATAOBJ FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558510877000.0
# sz_end: 1558510997000.0
# cannot split or find file
# FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# DATAOBJ FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558513210000.0
# sz_end: 1558513343000.0
# cannot split or find file

# %%
print("------------------------SZ DATA-------------------")
for x in sz_list:
    print(x[0])
    print(len(x[2]))

    
print("-----------------NON SZ DATA---------------------")
for y in df_list:
    print(y[1])
    print(len(y[0]))
# Out:
# ------------------------SZ DATA-------------------
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 58001
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 56501
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 54001
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 56001
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 56501
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 57001
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 57001
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 60001
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 66501
# -----------------NON SZ DATA---------------------
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 32061994
# 20190520160924_p4nat1.sdeeg_converted_.easy_filtered.edf
# 32400000
# 20190521084849_p4dag2.sdeeg_converted_.easy_filtered.edf
# 12600000
# 20190520110039_p4dag1.sdeeg_converted_.easy_filtered.edf
# 9900500
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 3116997
# 20190522171939_p4nat3.sdeeg_converted_.easy_filtered.edf
# 28800000

# %% [markdown]
# # Result of splitting data into sz and non-sz dataframes

# %% [markdown]
# (before buffer) So now we have 28001 + 26501 + 24001 + 26001 + 26501 + 27001 = 158006 datapoints of seizure data and 32241994 + 32400000 + 12600000 + 9900500 + 3206997 + 28800000 = 119149491 data-points of non-seizure data

# %% [markdown]
# This means we have 0.13 % seizure datapoint out of the total datapoint

# %%
szTotal = (56+53+48+52+53+54) * 1000
print(szTotal)

hours = 12 * 60 * 60 * 1000
print(hours)

nonszTotal = 32061994

( szTotal / nonszTotal) * 100
# Out:
# 316000
# 43200000
# 0.9855906030049161

# %%
print(sz_list[6][0])
exa = sz_list[6][2]
exa['CH-1'].plot(x = "timestampMS")
# Out:
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# <AxesSubplot:>

# %% [markdown]
# Weird spikes still in the original data.

# %%
exa2 = df_list[0][0]
print(len(exa2))
exa2['CH-1'].plot()
# Out:
# 32061994
# <AxesSubplot:>

# %% [markdown]
# # Balancing dataset

# %%
non_sz_p4_day3 = df_list[4][0]
print(len(non_sz_p4_day3))
non_sz_p4_day3.head()
# Out:
# 3116997
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558508e+12 -0.000006 -0.000007 -0.000005 -0.000005 -0.000016 -0.000002
# 1  1.558508e+12 -0.000009 -0.000008 -0.000009 -0.000009 -0.000018 -0.000004
# 2  1.558508e+12  0.000009  0.000010  0.000007  0.000008 -0.000002  0.000011
# 3  1.558508e+12  0.000007  0.000007  0.000006  0.000007 -0.000004  0.000011
# 4  1.558508e+12  0.000015  0.000015  0.000015  0.000015  0.000006  0.000021
#
#        CH-7      CH-8             x             y             z
# 0 -0.000016  0.000022 -2.079795e-08  5.039436e-08  4.938009e-09
# 1 -0.000020  0.000019 -2.079795e-08  5.039436e-08  4.938009e-09
# 2 -0.000004  0.000034 -2.079795e-08  5.039436e-08  4.938009e-09
# 3 -0.000006  0.000033 -2.079795e-08  5.039436e-08  4.938009e-09
# 4  0.000003  0.000042 -2.079795e-08  5.039436e-08  4.938009e-09

# %%
sz_p4_day3 = pd.concat([sz_list[6][2], sz_list[7][2], sz_list[8][2]]) 
print(len(sz_p4_day3))
sz_p4_day3
# Out:
# 183503
#           timestampMS      CH-1          CH-2      CH-3      CH-4      CH-5  \
# 56500    1.558509e+12 -0.000023  3.426688e-07 -0.000081 -0.000080 -0.000080
# 56501    1.558509e+12 -0.000012 -1.970352e-06 -0.000040 -0.000039 -0.000039
# 56502    1.558509e+12  0.000013 -1.970352e-06  0.000048  0.000047  0.000047
# 56503    1.558509e+12  0.000028 -1.970352e-06  0.000102  0.000101  0.000101
# 56504    1.558509e+12  0.000037  1.499179e-06  0.000131  0.000130  0.000129
# ...               ...       ...           ...       ...       ...       ...
# 2425496  1.558513e+12  0.000010 -1.615688e-04  0.000074  0.000067  0.000073
# 2425497  1.558513e+12  0.000011 -1.638818e-04  0.000076  0.000069  0.000075
# 2425498  1.558513e+12  0.000013 -1.580992e-04  0.000082  0.000075  0.000082
# 2425499  1.558513e+12  0.000009 -1.523167e-04  0.000066  0.000058  0.000065
# 2425500  1.558513e+12  0.000007 -1.511602e-04  0.000064  0.000057  0.000064
#
#              CH-6      CH-7      CH-8             x             y  \
# 56500   -0.000081 -0.000081 -0.000080  3.345655e-09 -2.653046e-08
# 56501   -0.000040 -0.000039 -0.000038  3.245027e-08 -2.653046e-08
# 56502    0.000046  0.000047  0.000049  3.245027e-08 -2.653046e-08
# 56503    0.000100  0.000101  0.000102  3.245027e-08 -2.653046e-08
# 56504    0.000130  0.000131  0.000131  3.245027e-08 -2.653046e-08
# ...           ...       ...       ...           ...           ...
# 2425496  0.000073  0.000073  0.000075 -8.297599e-08 -4.547903e-07
# 2425497  0.000076  0.000076  0.000078 -8.297599e-08 -4.543404e-07
# 2425498  0.000083  0.000082  0.000085 -8.297599e-08 -4.543404e-07
# 2425499  0.000066  0.000065  0.000067  7.412279e-08 -1.893772e-07
# 2425500  0.000063  0.000064  0.000066  7.412279e-08 -1.893772e-07
#
#                     z
# 56500   -3.688316e-08
# 56501    3.297963e-09
# 56502    3.297963e-09
# 56503    3.297963e-09
# 56504    3.297963e-09
# ...               ...
# 2425496  1.246614e-07
# 2425497  1.246614e-07
# 2425498  1.246614e-07
# 2425499  4.634916e-08
# 2425500  4.634916e-08
#
# [183503 rows x 12 columns]

# %% [markdown]
# difference in %

# %%
(len(sz_p4_day3) / len(non_sz_p4_day3)) * 100
# Out:
# 5.887172814089972

# %%
sz_p4_day3.insert(1, "class", ["sz" for x in sz_p4_day3.index])
sz_p4_day3.head()
# Out:
#         timestampMS class      CH-1          CH-2      CH-3      CH-4  \
# 56500  1.558509e+12    sz -0.000023  3.426688e-07 -0.000081 -0.000080
# 56501  1.558509e+12    sz -0.000012 -1.970352e-06 -0.000040 -0.000039
# 56502  1.558509e+12    sz  0.000013 -1.970352e-06  0.000048  0.000047
# 56503  1.558509e+12    sz  0.000028 -1.970352e-06  0.000102  0.000101
# 56504  1.558509e+12    sz  0.000037  1.499179e-06  0.000131  0.000130
#
#            CH-5      CH-6      CH-7      CH-8             x             y  \
# 56500 -0.000080 -0.000081 -0.000081 -0.000080  3.345655e-09 -2.653046e-08
# 56501 -0.000039 -0.000040 -0.000039 -0.000038  3.245027e-08 -2.653046e-08
# 56502  0.000047  0.000046  0.000047  0.000049  3.245027e-08 -2.653046e-08
# 56503  0.000101  0.000100  0.000101  0.000102  3.245027e-08 -2.653046e-08
# 56504  0.000129  0.000130  0.000131  0.000131  3.245027e-08 -2.653046e-08
#
#                   z
# 56500 -3.688316e-08
# 56501  3.297963e-09
# 56502  3.297963e-09
# 56503  3.297963e-09
# 56504  3.297963e-09

# %%
#non_sz_p4_day3.insert(1, "class", ["non-sz" for x in non_sz_p4_day3.index])
non_sz_p4_day3.head()
# Out:
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558508e+12 -0.000006 -0.000007 -0.000005 -0.000005 -0.000016 -0.000002
# 1  1.558508e+12 -0.000009 -0.000008 -0.000009 -0.000009 -0.000018 -0.000004
# 2  1.558508e+12  0.000009  0.000010  0.000007  0.000008 -0.000002  0.000011
# 3  1.558508e+12  0.000007  0.000007  0.000006  0.000007 -0.000004  0.000011
# 4  1.558508e+12  0.000015  0.000015  0.000015  0.000015  0.000006  0.000021
#
#        CH-7      CH-8             x             y             z
# 0 -0.000016  0.000022 -2.079795e-08  5.039436e-08  4.938009e-09
# 1 -0.000020  0.000019 -2.079795e-08  5.039436e-08  4.938009e-09
# 2 -0.000004  0.000034 -2.079795e-08  5.039436e-08  4.938009e-09
# 3 -0.000006  0.000033 -2.079795e-08  5.039436e-08  4.938009e-09
# 4  0.000003  0.000042 -2.079795e-08  5.039436e-08  4.938009e-09

# %%
p4_day3_df = pd.concat([non_sz_p4_day3, sz_p4_day3])
p4_day3_df['class'].value_counts()
# Out:
# sz    183503
# Name: class, dtype: int64

# %%
p4_day3_df.shape
# Out:
# (3300500, 13)

# %%
183503 / 3116997 *100
# Out:
# 5.887172814089972

# %%
p4_day3_df.drop('x', inplace=True,  axis=1)
p4_day3_df.drop('y', inplace=True,  axis=1)
p4_day3_df.drop('z', inplace=True,  axis=1)

# %%
p4_day3_df.head()
# Out:
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558508e+12 -0.000006 -0.000007 -0.000005 -0.000005 -0.000016 -0.000002
# 1  1.558508e+12 -0.000009 -0.000008 -0.000009 -0.000009 -0.000018 -0.000004
# 2  1.558508e+12  0.000009  0.000010  0.000007  0.000008 -0.000002  0.000011
# 3  1.558508e+12  0.000007  0.000007  0.000006  0.000007 -0.000004  0.000011
# 4  1.558508e+12  0.000015  0.000015  0.000015  0.000015  0.000006  0.000021
#
#        CH-7      CH-8 class
# 0 -0.000016  0.000022   NaN
# 1 -0.000020  0.000019   NaN
# 2 -0.000004  0.000034   NaN
# 3 -0.000006  0.000033   NaN
# 4  0.000003  0.000042   NaN

# %%
p4_day3_df['class'] = p4_day3_df['class'].replace(np.nan, 'non-sz')
p4_day3_df.head()
# Out:
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558508e+12 -0.000006 -0.000007 -0.000005 -0.000005 -0.000016 -0.000002
# 1  1.558508e+12 -0.000009 -0.000008 -0.000009 -0.000009 -0.000018 -0.000004
# 2  1.558508e+12  0.000009  0.000010  0.000007  0.000008 -0.000002  0.000011
# 3  1.558508e+12  0.000007  0.000007  0.000006  0.000007 -0.000004  0.000011
# 4  1.558508e+12  0.000015  0.000015  0.000015  0.000015  0.000006  0.000021
#
#        CH-7      CH-8   class
# 0 -0.000016  0.000022  non-sz
# 1 -0.000020  0.000019  non-sz
# 2 -0.000004  0.000034  non-sz
# 3 -0.000006  0.000033  non-sz
# 4  0.000003  0.000042  non-sz

# %%
p4_day3_df['class'].value_counts()
# Out:
# non-sz    3116997
# sz         183503
# Name: class, dtype: int64

# %% [markdown]
# # Create EEG's

# %%
# define np array which holds windows...

# %%
def get_window(start_index, data, size = 4, overlap = 0, is_sezure = False, frequency = 500):
    if(is_sezure):
        overlap = 2
    else:
        overlap = overlap
    
    
    start = start_index * (size - overlap) * frequency
    end = start + (size * frequency)
    print("is_sezure: " + str(is_sezure) + " date: " + str(datetime.fromtimestamp((data['timestampMS'][start:start+1]/1000).tolist()[0])) + str(' lenthWindow: '+ str(len(data['CH-1'][start:end].tolist()))) + ' start: ' + str(start) + " end: " + str(end) )

    return [data['CH-1'][start:end].tolist(), datetime.fromtimestamp((data['timestampMS'][start:start+1]/1000).tolist()[0])]

# %%
sz = p4_day3_df.loc[p4_day3_df['class'] == 'sz']
nsz = p4_day3_df.loc[p4_day3_df['class'] == 'non-sz']
print(len(nsz))
# Out:
# 3116997

# %%
int(len(nsz) / (4*500))
# Out:
# 1558

# %%
int(len(sz) / (2*500))
# Out:
# 183

# %%
print(type(nsz))
nsz.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558508e+12 -0.000006 -0.000007 -0.000005 -0.000005 -0.000016 -0.000002
# 1  1.558508e+12 -0.000009 -0.000008 -0.000009 -0.000009 -0.000018 -0.000004
# 2  1.558508e+12  0.000009  0.000010  0.000007  0.000008 -0.000002  0.000011
# 3  1.558508e+12  0.000007  0.000007  0.000006  0.000007 -0.000004  0.000011
# 4  1.558508e+12  0.000015  0.000015  0.000015  0.000015  0.000006  0.000021
#
#        CH-7      CH-8   class
# 0 -0.000016  0.000022  non-sz
# 1 -0.000020  0.000019  non-sz
# 2 -0.000004  0.000034  non-sz
# 3 -0.000006  0.000033  non-sz
# 4  0.000003  0.000042  non-sz

# %%
nsz_win = [get_window(start_index=i, data=nsz) for i in range(1558)]
sz_win = [get_window(start_index=i, data=nsz, is_sezure=True) for i in range(183)]
# Out:
# is_sezure: False date: 2019-05-22 09:01:32 lenthWindow: 2000 start: 0 end: 2000
# is_sezure: False date: 2019-05-22 09:01:36 lenthWindow: 2000 start: 2000 end: 4000
# is_sezure: False date: 2019-05-22 09:01:40 lenthWindow: 2000 start: 4000 end: 6000
# is_sezure: False date: 2019-05-22 09:01:44 lenthWindow: 2000 start: 6000 end: 8000
# is_sezure: False date: 2019-05-22 09:01:48 lenthWindow: 2000 start: 8000 end: 10000
# is_sezure: False date: 2019-05-22 09:01:52 lenthWindow: 2000 start: 10000 end: 12000
# is_sezure: False date: 2019-05-22 09:01:56 lenthWindow: 2000 start: 12000 end: 14000
# is_sezure: False date: 2019-05-22 09:02:00 lenthWindow: 2000 start: 14000 end: 16000
# is_sezure: False date: 2019-05-22 09:02:04 lenthWindow: 2000 start: 16000 end: 18000
# is_sezure: False date: 2019-05-22 09:02:08 lenthWindow: 2000 start: 18000 end: 20000
# is_sezure: False date: 2019-05-22 09:02:12 lenthWindow: 2000 start: 20000 end: 22000
# is_sezure: False date: 2019-05-22 09:02:16 lenthWindow: 2000 start: 22000 end: 24000
# is_sezure: False date: 2019-05-22 09:02:20 lenthWindow: 2000 start: 24000 end: 26000
# is_sezure: False date: 2019-05-22 09:02:24 lenthWindow: 2000 start: 26000 end: 28000
# is_sezure: False date: 2019-05-22 09:02:28 lenthWindow: 2000 start: 28000 end: 30000
# is_sezure: False date: 2019-05-22 09:02:32 lenthWindow: 2000 start: 30000 end: 32000
# is_sezure: False date: 2019-05-22 09:02:36 lenthWindow: 2000 start: 32000 end: 34000
# is_sezure: False date: 2019-05-22 09:02:40 lenthWindow: 2000 start: 34000 end: 36000
# is_sezure: False date: 2019-05-22 09:02:44 lenthWindow: 2000 start: 36000 end: 38000
# is_sezure: False date: 2019-05-22 09:02:48 lenthWindow: 2000 start: 38000 end: 40000
# is_sezure: False date: 2019-05-22 09:02:52 lenthWindow: 2000 start: 40000 end: 42000
# is_sezure: False date: 2019-05-22 09:02:56 lenthWindow: 2000 start: 42000 end: 44000
# is_sezure: False date: 2019-05-22 09:03:00 lenthWindow: 2000 start: 44000 end: 46000
# is_sezure: False date: 2019-05-22 09:03:04 lenthWindow: 2000 start: 46000 end: 48000
# is_sezure: False date: 2019-05-22 09:03:08 lenthWindow: 2000 start: 48000 end: 50000
# is_sezure: False date: 2019-05-22 09:03:12 lenthWindow: 2000 start: 50000 end: 52000
# is_sezure: False date: 2019-05-22 09:03:16 lenthWindow: 2000 start: 52000 end: 54000
# is_sezure: False date: 2019-05-22 09:03:20 lenthWindow: 2000 start: 54000 end: 56000
# is_sezure: False date: 2019-05-22 09:03:24 lenthWindow: 2000 start: 56000 end: 58000
# is_sezure: False date: 2019-05-22 09:05:22.002000 lenthWindow: 2000 start: 58000 end: 60000
# is_sezure: False date: 2019-05-22 09:05:26.002000 lenthWindow: 2000 start: 60000 end: 62000
# is_sezure: False date: 2019-05-22 09:05:30.002000 lenthWindow: 2000 start: 62000 end: 64000
# is_sezure: False date: 2019-05-22 09:05:34.002000 lenthWindow: 2000 start: 64000 end: 66000
# is_sezure: False date: 2019-05-22 09:05:38.002000 lenthWindow: 2000 start: 66000 end: 68000
# is_sezure: False date: 2019-05-22 09:05:42.002000 lenthWindow: 2000 start: 68000 end: 70000
# is_sezure: False date: 2019-05-22 09:05:46.002000 lenthWindow: 2000 start: 70000 end: 72000
# is_sezure: False date: 2019-05-22 09:05:50.002000 lenthWindow: 2000 start: 72000 end: 74000
# is_sezure: False date: 2019-05-22 09:05:54.002000 lenthWindow: 2000 start: 74000 end: 76000
# is_sezure: False date: 2019-05-22 09:05:58.002000 lenthWindow: 2000 start: 76000 end: 78000
# is_sezure: False date: 2019-05-22 09:06:02.002000 lenthWindow: 2000 start: 78000 end: 80000
# is_sezure: False date: 2019-05-22 09:06:06.002000 lenthWindow: 2000 start: 80000 end: 82000
# is_sezure: False date: 2019-05-22 09:06:10.002000 lenthWindow: 2000 start: 82000 end: 84000
# is_sezure: False date: 2019-05-22 09:06:14.002000 lenthWindow: 2000 start: 84000 end: 86000
# is_sezure: False date: 2019-05-22 09:06:18.002000 lenthWindow: 2000 start: 86000 end: 88000
# is_sezure: False date: 2019-05-22 09:06:22.002000 lenthWindow: 2000 start: 88000 end: 90000
# is_sezure: False date: 2019-05-22 09:06:26.002000 lenthWindow: 2000 start: 90000 end: 92000
# is_sezure: False date: 2019-05-22 09:06:30.002000 lenthWindow: 2000 start: 92000 end: 94000
# is_sezure: False date: 2019-05-22 09:06:34.002000 lenthWindow: 2000 start: 94000 end: 96000
# is_sezure: False date: 2019-05-22 09:06:38.002000 lenthWindow: 2000 start: 96000 end: 98000
# is_sezure: False date: 2019-05-22 09:06:42.002000 lenthWindow: 2000 start: 98000 end: 100000
# is_sezure: False date: 2019-05-22 09:06:46.002000 lenthWindow: 2000 start: 100000 end: 102000
# is_sezure: False date: 2019-05-22 09:06:50.002000 lenthWindow: 2000 start: 102000 end: 104000
# is_sezure: False date: 2019-05-22 09:06:54.002000 lenthWindow: 2000 start: 104000 end: 106000
# is_sezure: False date: 2019-05-22 09:06:58.002000 lenthWindow: 2000 start: 106000 end: 108000
# is_sezure: False date: 2019-05-22 09:07:02.002000 lenthWindow: 2000 start: 108000 end: 110000
# is_sezure: False date: 2019-05-22 09:07:06.002000 lenthWindow: 2000 start: 110000 end: 112000
# is_sezure: False date: 2019-05-22 09:07:10.002000 lenthWindow: 2000 start: 112000 end: 114000
# is_sezure: False date: 2019-05-22 09:07:14.002000 lenthWindow: 2000 start: 114000 end: 116000
# is_sezure: False date: 2019-05-22 09:07:18.002000 lenthWindow: 2000 start: 116000 end: 118000
# is_sezure: False date: 2019-05-22 09:07:22.002000 lenthWindow: 2000 start: 118000 end: 120000
# is_sezure: False date: 2019-05-22 09:07:26.002000 lenthWindow: 2000 start: 120000 end: 122000
# is_sezure: False date: 2019-05-22 09:07:30.002000 lenthWindow: 2000 start: 122000 end: 124000
# is_sezure: False date: 2019-05-22 09:07:34.002000 lenthWindow: 2000 start: 124000 end: 126000
# is_sezure: False date: 2019-05-22 09:07:38.002000 lenthWindow: 2000 start: 126000 end: 128000
# is_sezure: False date: 2019-05-22 09:07:42.002000 lenthWindow: 2000 start: 128000 end: 130000
# is_sezure: False date: 2019-05-22 09:07:46.002000 lenthWindow: 2000 start: 130000 end: 132000
# is_sezure: False date: 2019-05-22 09:07:50.002000 lenthWindow: 2000 start: 132000 end: 134000
# is_sezure: False date: 2019-05-22 09:07:54.002000 lenthWindow: 2000 start: 134000 end: 136000
# is_sezure: False date: 2019-05-22 09:07:58.002000 lenthWindow: 2000 start: 136000 end: 138000
# is_sezure: False date: 2019-05-22 09:08:02.002000 lenthWindow: 2000 start: 138000 end: 140000
# is_sezure: False date: 2019-05-22 09:08:06.002000 lenthWindow: 2000 start: 140000 end: 142000
# is_sezure: False date: 2019-05-22 09:08:10.002000 lenthWindow: 2000 start: 142000 end: 144000
# is_sezure: False date: 2019-05-22 09:08:14.002000 lenthWindow: 2000 start: 144000 end: 146000
# is_sezure: False date: 2019-05-22 09:08:18.002000 lenthWindow: 2000 start: 146000 end: 148000
# is_sezure: False date: 2019-05-22 09:08:22.002000 lenthWindow: 2000 start: 148000 end: 150000
# is_sezure: False date: 2019-05-22 09:08:26.002000 lenthWindow: 2000 start: 150000 end: 152000
# is_sezure: False date: 2019-05-22 09:08:30.002000 lenthWindow: 2000 start: 152000 end: 154000
# is_sezure: False date: 2019-05-22 09:08:34.002000 lenthWindow: 2000 start: 154000 end: 156000
# is_sezure: False date: 2019-05-22 09:08:38.002000 lenthWindow: 2000 start: 156000 end: 158000
# is_sezure: False date: 2019-05-22 09:08:42.002000 lenthWindow: 2000 start: 158000 end: 160000
# is_sezure: False date: 2019-05-22 09:08:46.002000 lenthWindow: 2000 start: 160000 end: 162000
# is_sezure: False date: 2019-05-22 09:08:50.002000 lenthWindow: 2000 start: 162000 end: 164000
# is_sezure: False date: 2019-05-22 09:08:54.002000 lenthWindow: 2000 start: 164000 end: 166000
# is_sezure: False date: 2019-05-22 09:08:58.002000 lenthWindow: 2000 start: 166000 end: 168000
# is_sezure: False date: 2019-05-22 09:09:02.002000 lenthWindow: 2000 start: 168000 end: 170000
# is_sezure: False date: 2019-05-22 09:09:06.002000 lenthWindow: 2000 start: 170000 end: 172000
# is_sezure: False date: 2019-05-22 09:09:10.002000 lenthWindow: 2000 start: 172000 end: 174000
# is_sezure: False date: 2019-05-22 09:09:14.002000 lenthWindow: 2000 start: 174000 end: 176000
# is_sezure: False date: 2019-05-22 09:09:18.002000 lenthWindow: 2000 start: 176000 end: 178000
# is_sezure: False date: 2019-05-22 09:09:22.002000 lenthWindow: 2000 start: 178000 end: 180000
# is_sezure: False date: 2019-05-22 09:09:26.002000 lenthWindow: 2000 start: 180000 end: 182000
# is_sezure: False date: 2019-05-22 09:09:30.002000 lenthWindow: 2000 start: 182000 end: 184000
# is_sezure: False date: 2019-05-22 09:09:34.002000 lenthWindow: 2000 start: 184000 end: 186000
# is_sezure: False date: 2019-05-22 09:09:38.002000 lenthWindow: 2000 start: 186000 end: 188000
# is_sezure: False date: 2019-05-22 09:09:42.002000 lenthWindow: 2000 start: 188000 end: 190000
# is_sezure: False date: 2019-05-22 09:09:46.002000 lenthWindow: 2000 start: 190000 end: 192000
# is_sezure: False date: 2019-05-22 09:09:50.002000 lenthWindow: 2000 start: 192000 end: 194000
# is_sezure: False date: 2019-05-22 09:09:54.002000 lenthWindow: 2000 start: 194000 end: 196000
# is_sezure: False date: 2019-05-22 09:09:58.002000 lenthWindow: 2000 start: 196000 end: 198000
# is_sezure: False date: 2019-05-22 09:10:02.002000 lenthWindow: 2000 start: 198000 end: 200000
# is_sezure: False date: 2019-05-22 09:10:06.002000 lenthWindow: 2000 start: 200000 end: 202000
# is_sezure: False date: 2019-05-22 09:10:10.002000 lenthWindow: 2000 start: 202000 end: 204000
# is_sezure: False date: 2019-05-22 09:10:14.002000 lenthWindow: 2000 start: 204000 end: 206000
# is_sezure: False date: 2019-05-22 09:10:18.002000 lenthWindow: 2000 start: 206000 end: 208000
# is_sezure: False date: 2019-05-22 09:10:22.002000 lenthWindow: 2000 start: 208000 end: 210000
# is_sezure: False date: 2019-05-22 09:10:26.002000 lenthWindow: 2000 start: 210000 end: 212000
# is_sezure: False date: 2019-05-22 09:10:30.002000 lenthWindow: 2000 start: 212000 end: 214000
# is_sezure: False date: 2019-05-22 09:10:34.002000 lenthWindow: 2000 start: 214000 end: 216000
# is_sezure: False date: 2019-05-22 09:10:38.002000 lenthWindow: 2000 start: 216000 end: 218000
# is_sezure: False date: 2019-05-22 09:10:42.002000 lenthWindow: 2000 start: 218000 end: 220000
# is_sezure: False date: 2019-05-22 09:10:46.002000 lenthWindow: 2000 start: 220000 end: 222000
# is_sezure: False date: 2019-05-22 09:10:50.002000 lenthWindow: 2000 start: 222000 end: 224000
# is_sezure: False date: 2019-05-22 09:10:54.002000 lenthWindow: 2000 start: 224000 end: 226000
# is_sezure: False date: 2019-05-22 09:10:58.002000 lenthWindow: 2000 start: 226000 end: 228000
# is_sezure: False date: 2019-05-22 09:11:02.002000 lenthWindow: 2000 start: 228000 end: 230000
# is_sezure: False date: 2019-05-22 09:11:06.002000 lenthWindow: 2000 start: 230000 end: 232000
# is_sezure: False date: 2019-05-22 09:11:10.002000 lenthWindow: 2000 start: 232000 end: 234000
# is_sezure: False date: 2019-05-22 09:11:14.002000 lenthWindow: 2000 start: 234000 end: 236000
# is_sezure: False date: 2019-05-22 09:11:18.002000 lenthWindow: 2000 start: 236000 end: 238000
# is_sezure: False date: 2019-05-22 09:11:22.002000 lenthWindow: 2000 start: 238000 end: 240000
# is_sezure: False date: 2019-05-22 09:11:26.002000 lenthWindow: 2000 start: 240000 end: 242000
# is_sezure: False date: 2019-05-22 09:11:30.002000 lenthWindow: 2000 start: 242000 end: 244000
# is_sezure: False date: 2019-05-22 09:11:34.002000 lenthWindow: 2000 start: 244000 end: 246000
# is_sezure: False date: 2019-05-22 09:11:38.002000 lenthWindow: 2000 start: 246000 end: 248000
# is_sezure: False date: 2019-05-22 09:11:42.002000 lenthWindow: 2000 start: 248000 end: 250000
# is_sezure: False date: 2019-05-22 09:11:46.002000 lenthWindow: 2000 start: 250000 end: 252000
# is_sezure: False date: 2019-05-22 09:11:50.002000 lenthWindow: 2000 start: 252000 end: 254000
# is_sezure: False date: 2019-05-22 09:11:54.002000 lenthWindow: 2000 start: 254000 end: 256000
# is_sezure: False date: 2019-05-22 09:11:58.002000 lenthWindow: 2000 start: 256000 end: 258000
# is_sezure: False date: 2019-05-22 09:12:02.002000 lenthWindow: 2000 start: 258000 end: 260000
# is_sezure: False date: 2019-05-22 09:12:06.002000 lenthWindow: 2000 start: 260000 end: 262000
# is_sezure: False date: 2019-05-22 09:12:10.002000 lenthWindow: 2000 start: 262000 end: 264000
# is_sezure: False date: 2019-05-22 09:12:14.002000 lenthWindow: 2000 start: 264000 end: 266000
# is_sezure: False date: 2019-05-22 09:12:18.002000 lenthWindow: 2000 start: 266000 end: 268000
# is_sezure: False date: 2019-05-22 09:12:22.002000 lenthWindow: 2000 start: 268000 end: 270000
# is_sezure: False date: 2019-05-22 09:12:26.002000 lenthWindow: 2000 start: 270000 end: 272000
# is_sezure: False date: 2019-05-22 09:12:30.002000 lenthWindow: 2000 start: 272000 end: 274000
# is_sezure: False date: 2019-05-22 09:12:34.002000 lenthWindow: 2000 start: 274000 end: 276000
# is_sezure: False date: 2019-05-22 09:12:38.002000 lenthWindow: 2000 start: 276000 end: 278000
# is_sezure: False date: 2019-05-22 09:12:42.002000 lenthWindow: 2000 start: 278000 end: 280000
# is_sezure: False date: 2019-05-22 09:12:46.002000 lenthWindow: 2000 start: 280000 end: 282000
# is_sezure: False date: 2019-05-22 09:12:50.002000 lenthWindow: 2000 start: 282000 end: 284000
# is_sezure: False date: 2019-05-22 09:12:54.002000 lenthWindow: 2000 start: 284000 end: 286000
# is_sezure: False date: 2019-05-22 09:12:58.002000 lenthWindow: 2000 start: 286000 end: 288000
# is_sezure: False date: 2019-05-22 09:13:02.002000 lenthWindow: 2000 start: 288000 end: 290000
# is_sezure: False date: 2019-05-22 09:13:06.002000 lenthWindow: 2000 start: 290000 end: 292000
# is_sezure: False date: 2019-05-22 09:13:10.002000 lenthWindow: 2000 start: 292000 end: 294000
# is_sezure: False date: 2019-05-22 09:13:14.002000 lenthWindow: 2000 start: 294000 end: 296000
# is_sezure: False date: 2019-05-22 09:13:18.002000 lenthWindow: 2000 start: 296000 end: 298000
# is_sezure: False date: 2019-05-22 09:13:22.002000 lenthWindow: 2000 start: 298000 end: 300000
# is_sezure: False date: 2019-05-22 09:13:26.002000 lenthWindow: 2000 start: 300000 end: 302000
# is_sezure: False date: 2019-05-22 09:13:30.002000 lenthWindow: 2000 start: 302000 end: 304000
# is_sezure: False date: 2019-05-22 09:13:34.002000 lenthWindow: 2000 start: 304000 end: 306000
# is_sezure: False date: 2019-05-22 09:13:38.002000 lenthWindow: 2000 start: 306000 end: 308000
# is_sezure: False date: 2019-05-22 09:13:42.002000 lenthWindow: 2000 start: 308000 end: 310000
# is_sezure: False date: 2019-05-22 09:13:46.002000 lenthWindow: 2000 start: 310000 end: 312000
# is_sezure: False date: 2019-05-22 09:13:50.002000 lenthWindow: 2000 start: 312000 end: 314000
# is_sezure: False date: 2019-05-22 09:13:54.002000 lenthWindow: 2000 start: 314000 end: 316000
# is_sezure: False date: 2019-05-22 09:13:58.002000 lenthWindow: 2000 start: 316000 end: 318000
# is_sezure: False date: 2019-05-22 09:14:02.002000 lenthWindow: 2000 start: 318000 end: 320000
# is_sezure: False date: 2019-05-22 09:14:06.002000 lenthWindow: 2000 start: 320000 end: 322000
# is_sezure: False date: 2019-05-22 09:14:10.002000 lenthWindow: 2000 start: 322000 end: 324000
# is_sezure: False date: 2019-05-22 09:14:14.002000 lenthWindow: 2000 start: 324000 end: 326000
# is_sezure: False date: 2019-05-22 09:14:18.002000 lenthWindow: 2000 start: 326000 end: 328000
# is_sezure: False date: 2019-05-22 09:14:22.002000 lenthWindow: 2000 start: 328000 end: 330000
# is_sezure: False date: 2019-05-22 09:14:26.002000 lenthWindow: 2000 start: 330000 end: 332000
# is_sezure: False date: 2019-05-22 09:14:30.002000 lenthWindow: 2000 start: 332000 end: 334000
# is_sezure: False date: 2019-05-22 09:14:34.002000 lenthWindow: 2000 start: 334000 end: 336000
# is_sezure: False date: 2019-05-22 09:14:38.002000 lenthWindow: 2000 start: 336000 end: 338000
# is_sezure: False date: 2019-05-22 09:14:42.002000 lenthWindow: 2000 start: 338000 end: 340000
# is_sezure: False date: 2019-05-22 09:14:46.002000 lenthWindow: 2000 start: 340000 end: 342000
# is_sezure: False date: 2019-05-22 09:14:50.002000 lenthWindow: 2000 start: 342000 end: 344000
# is_sezure: False date: 2019-05-22 09:14:54.002000 lenthWindow: 2000 start: 344000 end: 346000
# is_sezure: False date: 2019-05-22 09:14:58.002000 lenthWindow: 2000 start: 346000 end: 348000
# is_sezure: False date: 2019-05-22 09:15:02.002000 lenthWindow: 2000 start: 348000 end: 350000
# is_sezure: False date: 2019-05-22 09:15:06.002000 lenthWindow: 2000 start: 350000 end: 352000
# is_sezure: False date: 2019-05-22 09:15:10.002000 lenthWindow: 2000 start: 352000 end: 354000
# is_sezure: False date: 2019-05-22 09:15:14.002000 lenthWindow: 2000 start: 354000 end: 356000
# is_sezure: False date: 2019-05-22 09:15:18.002000 lenthWindow: 2000 start: 356000 end: 358000
# is_sezure: False date: 2019-05-22 09:15:22.002000 lenthWindow: 2000 start: 358000 end: 360000
# is_sezure: False date: 2019-05-22 09:15:26.002000 lenthWindow: 2000 start: 360000 end: 362000
# is_sezure: False date: 2019-05-22 09:15:30.002000 lenthWindow: 2000 start: 362000 end: 364000
# is_sezure: False date: 2019-05-22 09:15:34.002000 lenthWindow: 2000 start: 364000 end: 366000
# is_sezure: False date: 2019-05-22 09:15:38.002000 lenthWindow: 2000 start: 366000 end: 368000
# is_sezure: False date: 2019-05-22 09:15:42.002000 lenthWindow: 2000 start: 368000 end: 370000
# is_sezure: False date: 2019-05-22 09:15:46.002000 lenthWindow: 2000 start: 370000 end: 372000
# is_sezure: False date: 2019-05-22 09:15:50.002000 lenthWindow: 2000 start: 372000 end: 374000
# is_sezure: False date: 2019-05-22 09:15:54.002000 lenthWindow: 2000 start: 374000 end: 376000
# is_sezure: False date: 2019-05-22 09:15:58.002000 lenthWindow: 2000 start: 376000 end: 378000
# is_sezure: False date: 2019-05-22 09:16:02.002000 lenthWindow: 2000 start: 378000 end: 380000
# is_sezure: False date: 2019-05-22 09:16:06.002000 lenthWindow: 2000 start: 380000 end: 382000
# is_sezure: False date: 2019-05-22 09:16:10.002000 lenthWindow: 2000 start: 382000 end: 384000
# is_sezure: False date: 2019-05-22 09:16:14.002000 lenthWindow: 2000 start: 384000 end: 386000
# is_sezure: False date: 2019-05-22 09:16:18.002000 lenthWindow: 2000 start: 386000 end: 388000
# is_sezure: False date: 2019-05-22 09:16:22.002000 lenthWindow: 2000 start: 388000 end: 390000
# is_sezure: False date: 2019-05-22 09:16:26.002000 lenthWindow: 2000 start: 390000 end: 392000
# is_sezure: False date: 2019-05-22 09:16:30.002000 lenthWindow: 2000 start: 392000 end: 394000
# is_sezure: False date: 2019-05-22 09:16:34.002000 lenthWindow: 2000 start: 394000 end: 396000
# is_sezure: False date: 2019-05-22 09:16:38.002000 lenthWindow: 2000 start: 396000 end: 398000
# is_sezure: False date: 2019-05-22 09:16:42.002000 lenthWindow: 2000 start: 398000 end: 400000
# is_sezure: False date: 2019-05-22 09:16:46.002000 lenthWindow: 2000 start: 400000 end: 402000
# is_sezure: False date: 2019-05-22 09:16:50.002000 lenthWindow: 2000 start: 402000 end: 404000
# is_sezure: False date: 2019-05-22 09:16:54.002000 lenthWindow: 2000 start: 404000 end: 406000
# is_sezure: False date: 2019-05-22 09:16:58.002000 lenthWindow: 2000 start: 406000 end: 408000
# is_sezure: False date: 2019-05-22 09:17:02.002000 lenthWindow: 2000 start: 408000 end: 410000
# is_sezure: False date: 2019-05-22 09:17:06.002000 lenthWindow: 2000 start: 410000 end: 412000
# is_sezure: False date: 2019-05-22 09:17:10.002000 lenthWindow: 2000 start: 412000 end: 414000
# is_sezure: False date: 2019-05-22 09:17:14.002000 lenthWindow: 2000 start: 414000 end: 416000
# is_sezure: False date: 2019-05-22 09:17:18.002000 lenthWindow: 2000 start: 416000 end: 418000
# is_sezure: False date: 2019-05-22 09:17:22.002000 lenthWindow: 2000 start: 418000 end: 420000
# is_sezure: False date: 2019-05-22 09:17:26.002000 lenthWindow: 2000 start: 420000 end: 422000
# is_sezure: False date: 2019-05-22 09:17:30.002000 lenthWindow: 2000 start: 422000 end: 424000
# is_sezure: False date: 2019-05-22 09:17:34.002000 lenthWindow: 2000 start: 424000 end: 426000
# is_sezure: False date: 2019-05-22 09:17:38.002000 lenthWindow: 2000 start: 426000 end: 428000
# is_sezure: False date: 2019-05-22 09:17:42.002000 lenthWindow: 2000 start: 428000 end: 430000
# is_sezure: False date: 2019-05-22 09:17:46.002000 lenthWindow: 2000 start: 430000 end: 432000
# is_sezure: False date: 2019-05-22 09:17:50.002000 lenthWindow: 2000 start: 432000 end: 434000
# is_sezure: False date: 2019-05-22 09:17:54.002000 lenthWindow: 2000 start: 434000 end: 436000
# is_sezure: False date: 2019-05-22 09:17:58.002000 lenthWindow: 2000 start: 436000 end: 438000
# is_sezure: False date: 2019-05-22 09:18:02.002000 lenthWindow: 2000 start: 438000 end: 440000
# is_sezure: False date: 2019-05-22 09:18:06.002000 lenthWindow: 2000 start: 440000 end: 442000
# is_sezure: False date: 2019-05-22 09:18:10.002000 lenthWindow: 2000 start: 442000 end: 444000
# is_sezure: False date: 2019-05-22 09:18:14.002000 lenthWindow: 2000 start: 444000 end: 446000
# is_sezure: False date: 2019-05-22 09:18:18.002000 lenthWindow: 2000 start: 446000 end: 448000
# is_sezure: False date: 2019-05-22 09:18:22.002000 lenthWindow: 2000 start: 448000 end: 450000
# is_sezure: False date: 2019-05-22 09:18:26.002000 lenthWindow: 2000 start: 450000 end: 452000
# is_sezure: False date: 2019-05-22 09:18:30.002000 lenthWindow: 2000 start: 452000 end: 454000
# is_sezure: False date: 2019-05-22 09:18:34.002000 lenthWindow: 2000 start: 454000 end: 456000
# is_sezure: False date: 2019-05-22 09:18:38.002000 lenthWindow: 2000 start: 456000 end: 458000
# is_sezure: False date: 2019-05-22 09:18:42.002000 lenthWindow: 2000 start: 458000 end: 460000
# is_sezure: False date: 2019-05-22 09:18:46.002000 lenthWindow: 2000 start: 460000 end: 462000
# is_sezure: False date: 2019-05-22 09:18:50.002000 lenthWindow: 2000 start: 462000 end: 464000
# is_sezure: False date: 2019-05-22 09:18:54.002000 lenthWindow: 2000 start: 464000 end: 466000
# is_sezure: False date: 2019-05-22 09:18:58.002000 lenthWindow: 2000 start: 466000 end: 468000
# is_sezure: False date: 2019-05-22 09:19:02.002000 lenthWindow: 2000 start: 468000 end: 470000
# is_sezure: False date: 2019-05-22 09:19:06.002000 lenthWindow: 2000 start: 470000 end: 472000
# is_sezure: False date: 2019-05-22 09:19:10.002000 lenthWindow: 2000 start: 472000 end: 474000
# is_sezure: False date: 2019-05-22 09:19:14.002000 lenthWindow: 2000 start: 474000 end: 476000
# is_sezure: False date: 2019-05-22 09:19:18.002000 lenthWindow: 2000 start: 476000 end: 478000
# is_sezure: False date: 2019-05-22 09:19:22.002000 lenthWindow: 2000 start: 478000 end: 480000
# is_sezure: False date: 2019-05-22 09:19:26.002000 lenthWindow: 2000 start: 480000 end: 482000
# is_sezure: False date: 2019-05-22 09:19:30.002000 lenthWindow: 2000 start: 482000 end: 484000
# is_sezure: False date: 2019-05-22 09:19:34.002000 lenthWindow: 2000 start: 484000 end: 486000
# is_sezure: False date: 2019-05-22 09:19:38.002000 lenthWindow: 2000 start: 486000 end: 488000
# is_sezure: False date: 2019-05-22 09:19:42.002000 lenthWindow: 2000 start: 488000 end: 490000
# is_sezure: False date: 2019-05-22 09:19:46.002000 lenthWindow: 2000 start: 490000 end: 492000
# is_sezure: False date: 2019-05-22 09:19:50.002000 lenthWindow: 2000 start: 492000 end: 494000
# is_sezure: False date: 2019-05-22 09:19:54.002000 lenthWindow: 2000 start: 494000 end: 496000
# is_sezure: False date: 2019-05-22 09:19:58.002000 lenthWindow: 2000 start: 496000 end: 498000
# is_sezure: False date: 2019-05-22 09:20:02.002000 lenthWindow: 2000 start: 498000 end: 500000
# is_sezure: False date: 2019-05-22 09:20:06.002000 lenthWindow: 2000 start: 500000 end: 502000
# is_sezure: False date: 2019-05-22 09:20:10.002000 lenthWindow: 2000 start: 502000 end: 504000
# is_sezure: False date: 2019-05-22 09:20:14.002000 lenthWindow: 2000 start: 504000 end: 506000
# is_sezure: False date: 2019-05-22 09:20:18.002000 lenthWindow: 2000 start: 506000 end: 508000
# is_sezure: False date: 2019-05-22 09:20:22.002000 lenthWindow: 2000 start: 508000 end: 510000
# is_sezure: False date: 2019-05-22 09:20:26.002000 lenthWindow: 2000 start: 510000 end: 512000
# is_sezure: False date: 2019-05-22 09:20:30.002000 lenthWindow: 2000 start: 512000 end: 514000
# is_sezure: False date: 2019-05-22 09:20:34.002000 lenthWindow: 2000 start: 514000 end: 516000
# is_sezure: False date: 2019-05-22 09:20:38.002000 lenthWindow: 2000 start: 516000 end: 518000
# is_sezure: False date: 2019-05-22 09:20:42.002000 lenthWindow: 2000 start: 518000 end: 520000
# is_sezure: False date: 2019-05-22 09:20:46.002000 lenthWindow: 2000 start: 520000 end: 522000
# is_sezure: False date: 2019-05-22 09:20:50.002000 lenthWindow: 2000 start: 522000 end: 524000
# is_sezure: False date: 2019-05-22 09:20:54.002000 lenthWindow: 2000 start: 524000 end: 526000
# is_sezure: False date: 2019-05-22 09:20:58.002000 lenthWindow: 2000 start: 526000 end: 528000
# is_sezure: False date: 2019-05-22 09:21:02.002000 lenthWindow: 2000 start: 528000 end: 530000
# is_sezure: False date: 2019-05-22 09:21:06.002000 lenthWindow: 2000 start: 530000 end: 532000
# is_sezure: False date: 2019-05-22 09:21:10.002000 lenthWindow: 2000 start: 532000 end: 534000
# is_sezure: False date: 2019-05-22 09:21:14.002000 lenthWindow: 2000 start: 534000 end: 536000
# is_sezure: False date: 2019-05-22 09:21:18.002000 lenthWindow: 2000 start: 536000 end: 538000
# is_sezure: False date: 2019-05-22 09:21:22.002000 lenthWindow: 2000 start: 538000 end: 540000
# is_sezure: False date: 2019-05-22 09:21:26.002000 lenthWindow: 2000 start: 540000 end: 542000
# is_sezure: False date: 2019-05-22 09:21:30.002000 lenthWindow: 2000 start: 542000 end: 544000
# is_sezure: False date: 2019-05-22 09:21:34.002000 lenthWindow: 2000 start: 544000 end: 546000
# is_sezure: False date: 2019-05-22 09:21:38.002000 lenthWindow: 2000 start: 546000 end: 548000
# is_sezure: False date: 2019-05-22 09:21:42.002000 lenthWindow: 2000 start: 548000 end: 550000
# is_sezure: False date: 2019-05-22 09:21:46.002000 lenthWindow: 2000 start: 550000 end: 552000
# is_sezure: False date: 2019-05-22 09:21:50.002000 lenthWindow: 2000 start: 552000 end: 554000
# is_sezure: False date: 2019-05-22 09:21:54.002000 lenthWindow: 2000 start: 554000 end: 556000
# is_sezure: False date: 2019-05-22 09:21:58.002000 lenthWindow: 2000 start: 556000 end: 558000
# is_sezure: False date: 2019-05-22 09:22:02.002000 lenthWindow: 2000 start: 558000 end: 560000
# is_sezure: False date: 2019-05-22 09:22:06.002000 lenthWindow: 2000 start: 560000 end: 562000
# is_sezure: False date: 2019-05-22 09:22:10.002000 lenthWindow: 2000 start: 562000 end: 564000
# is_sezure: False date: 2019-05-22 09:22:14.002000 lenthWindow: 2000 start: 564000 end: 566000
# is_sezure: False date: 2019-05-22 09:22:18.002000 lenthWindow: 2000 start: 566000 end: 568000
# is_sezure: False date: 2019-05-22 09:22:22.002000 lenthWindow: 2000 start: 568000 end: 570000
# is_sezure: False date: 2019-05-22 09:22:26.002000 lenthWindow: 2000 start: 570000 end: 572000
# is_sezure: False date: 2019-05-22 09:22:30.002000 lenthWindow: 2000 start: 572000 end: 574000
# is_sezure: False date: 2019-05-22 09:22:34.002000 lenthWindow: 2000 start: 574000 end: 576000
# is_sezure: False date: 2019-05-22 09:22:38.002000 lenthWindow: 2000 start: 576000 end: 578000
# is_sezure: False date: 2019-05-22 09:22:42.002000 lenthWindow: 2000 start: 578000 end: 580000
# is_sezure: False date: 2019-05-22 09:22:46.002000 lenthWindow: 2000 start: 580000 end: 582000
# is_sezure: False date: 2019-05-22 09:22:50.002000 lenthWindow: 2000 start: 582000 end: 584000
# is_sezure: False date: 2019-05-22 09:22:54.002000 lenthWindow: 2000 start: 584000 end: 586000
# is_sezure: False date: 2019-05-22 09:22:58.002000 lenthWindow: 2000 start: 586000 end: 588000
# is_sezure: False date: 2019-05-22 09:23:02.002000 lenthWindow: 2000 start: 588000 end: 590000
# is_sezure: False date: 2019-05-22 09:23:06.002000 lenthWindow: 2000 start: 590000 end: 592000
# is_sezure: False date: 2019-05-22 09:23:10.002000 lenthWindow: 2000 start: 592000 end: 594000
# is_sezure: False date: 2019-05-22 09:23:14.002000 lenthWindow: 2000 start: 594000 end: 596000
# is_sezure: False date: 2019-05-22 09:23:18.002000 lenthWindow: 2000 start: 596000 end: 598000
# is_sezure: False date: 2019-05-22 09:23:22.002000 lenthWindow: 2000 start: 598000 end: 600000
# is_sezure: False date: 2019-05-22 09:23:26.002000 lenthWindow: 2000 start: 600000 end: 602000
# is_sezure: False date: 2019-05-22 09:23:30.002000 lenthWindow: 2000 start: 602000 end: 604000
# is_sezure: False date: 2019-05-22 09:23:34.002000 lenthWindow: 2000 start: 604000 end: 606000
# is_sezure: False date: 2019-05-22 09:23:38.002000 lenthWindow: 2000 start: 606000 end: 608000
# is_sezure: False date: 2019-05-22 09:23:42.002000 lenthWindow: 2000 start: 608000 end: 610000
# is_sezure: False date: 2019-05-22 09:23:46.002000 lenthWindow: 2000 start: 610000 end: 612000
# is_sezure: False date: 2019-05-22 09:23:50.002000 lenthWindow: 2000 start: 612000 end: 614000
# is_sezure: False date: 2019-05-22 09:23:54.002000 lenthWindow: 2000 start: 614000 end: 616000
# is_sezure: False date: 2019-05-22 09:23:58.002000 lenthWindow: 2000 start: 616000 end: 618000
# is_sezure: False date: 2019-05-22 09:24:02.002000 lenthWindow: 2000 start: 618000 end: 620000
# is_sezure: False date: 2019-05-22 09:24:06.002000 lenthWindow: 2000 start: 620000 end: 622000
# is_sezure: False date: 2019-05-22 09:24:10.002000 lenthWindow: 2000 start: 622000 end: 624000
# is_sezure: False date: 2019-05-22 09:24:14.002000 lenthWindow: 2000 start: 624000 end: 626000
# is_sezure: False date: 2019-05-22 09:24:18.002000 lenthWindow: 2000 start: 626000 end: 628000
# is_sezure: False date: 2019-05-22 09:24:22.002000 lenthWindow: 2000 start: 628000 end: 630000
# is_sezure: False date: 2019-05-22 09:24:26.002000 lenthWindow: 2000 start: 630000 end: 632000
# is_sezure: False date: 2019-05-22 09:24:30.002000 lenthWindow: 2000 start: 632000 end: 634000
# is_sezure: False date: 2019-05-22 09:24:34.002000 lenthWindow: 2000 start: 634000 end: 636000
# is_sezure: False date: 2019-05-22 09:24:38.002000 lenthWindow: 2000 start: 636000 end: 638000
# is_sezure: False date: 2019-05-22 09:24:42.002000 lenthWindow: 2000 start: 638000 end: 640000
# is_sezure: False date: 2019-05-22 09:24:46.002000 lenthWindow: 2000 start: 640000 end: 642000
# is_sezure: False date: 2019-05-22 09:24:50.002000 lenthWindow: 2000 start: 642000 end: 644000
# is_sezure: False date: 2019-05-22 09:24:54.002000 lenthWindow: 2000 start: 644000 end: 646000
# is_sezure: False date: 2019-05-22 09:24:58.002000 lenthWindow: 2000 start: 646000 end: 648000
# is_sezure: False date: 2019-05-22 09:25:02.002000 lenthWindow: 2000 start: 648000 end: 650000
# is_sezure: False date: 2019-05-22 09:25:06.002000 lenthWindow: 2000 start: 650000 end: 652000
# is_sezure: False date: 2019-05-22 09:25:10.002000 lenthWindow: 2000 start: 652000 end: 654000
# is_sezure: False date: 2019-05-22 09:25:14.002000 lenthWindow: 2000 start: 654000 end: 656000
# is_sezure: False date: 2019-05-22 09:25:18.002000 lenthWindow: 2000 start: 656000 end: 658000
# is_sezure: False date: 2019-05-22 09:25:22.002000 lenthWindow: 2000 start: 658000 end: 660000
# is_sezure: False date: 2019-05-22 09:25:26.002000 lenthWindow: 2000 start: 660000 end: 662000
# is_sezure: False date: 2019-05-22 09:25:30.002000 lenthWindow: 2000 start: 662000 end: 664000
# is_sezure: False date: 2019-05-22 09:25:34.002000 lenthWindow: 2000 start: 664000 end: 666000
# is_sezure: False date: 2019-05-22 09:25:38.002000 lenthWindow: 2000 start: 666000 end: 668000
# is_sezure: False date: 2019-05-22 09:25:42.002000 lenthWindow: 2000 start: 668000 end: 670000
# is_sezure: False date: 2019-05-22 09:25:46.002000 lenthWindow: 2000 start: 670000 end: 672000
# is_sezure: False date: 2019-05-22 09:25:50.002000 lenthWindow: 2000 start: 672000 end: 674000
# is_sezure: False date: 2019-05-22 09:25:54.002000 lenthWindow: 2000 start: 674000 end: 676000
# is_sezure: False date: 2019-05-22 09:25:58.002000 lenthWindow: 2000 start: 676000 end: 678000
# is_sezure: False date: 2019-05-22 09:26:02.002000 lenthWindow: 2000 start: 678000 end: 680000
# is_sezure: False date: 2019-05-22 09:26:06.002000 lenthWindow: 2000 start: 680000 end: 682000
# is_sezure: False date: 2019-05-22 09:26:10.002000 lenthWindow: 2000 start: 682000 end: 684000
# is_sezure: False date: 2019-05-22 09:26:14.002000 lenthWindow: 2000 start: 684000 end: 686000
# is_sezure: False date: 2019-05-22 09:26:18.002000 lenthWindow: 2000 start: 686000 end: 688000
# is_sezure: False date: 2019-05-22 09:26:22.002000 lenthWindow: 2000 start: 688000 end: 690000
# is_sezure: False date: 2019-05-22 09:26:26.002000 lenthWindow: 2000 start: 690000 end: 692000
# is_sezure: False date: 2019-05-22 09:26:30.002000 lenthWindow: 2000 start: 692000 end: 694000
# is_sezure: False date: 2019-05-22 09:26:34.002000 lenthWindow: 2000 start: 694000 end: 696000
# is_sezure: False date: 2019-05-22 09:26:38.002000 lenthWindow: 2000 start: 696000 end: 698000
# is_sezure: False date: 2019-05-22 09:26:42.002000 lenthWindow: 2000 start: 698000 end: 700000
# is_sezure: False date: 2019-05-22 09:26:46.002000 lenthWindow: 2000 start: 700000 end: 702000
# is_sezure: False date: 2019-05-22 09:26:50.002000 lenthWindow: 2000 start: 702000 end: 704000
# is_sezure: False date: 2019-05-22 09:26:54.002000 lenthWindow: 2000 start: 704000 end: 706000
# is_sezure: False date: 2019-05-22 09:26:58.002000 lenthWindow: 2000 start: 706000 end: 708000
# is_sezure: False date: 2019-05-22 09:27:02.002000 lenthWindow: 2000 start: 708000 end: 710000
# is_sezure: False date: 2019-05-22 09:27:06.002000 lenthWindow: 2000 start: 710000 end: 712000
# is_sezure: False date: 2019-05-22 09:27:10.002000 lenthWindow: 2000 start: 712000 end: 714000
# is_sezure: False date: 2019-05-22 09:27:14.002000 lenthWindow: 2000 start: 714000 end: 716000
# is_sezure: False date: 2019-05-22 09:27:18.002000 lenthWindow: 2000 start: 716000 end: 718000
# is_sezure: False date: 2019-05-22 09:27:22.002000 lenthWindow: 2000 start: 718000 end: 720000
# is_sezure: False date: 2019-05-22 09:27:26.002000 lenthWindow: 2000 start: 720000 end: 722000
# is_sezure: False date: 2019-05-22 09:27:30.002000 lenthWindow: 2000 start: 722000 end: 724000
# is_sezure: False date: 2019-05-22 09:27:34.002000 lenthWindow: 2000 start: 724000 end: 726000
# is_sezure: False date: 2019-05-22 09:27:38.002000 lenthWindow: 2000 start: 726000 end: 728000
# is_sezure: False date: 2019-05-22 09:27:42.002000 lenthWindow: 2000 start: 728000 end: 730000
# is_sezure: False date: 2019-05-22 09:27:46.002000 lenthWindow: 2000 start: 730000 end: 732000
# is_sezure: False date: 2019-05-22 09:27:50.002000 lenthWindow: 2000 start: 732000 end: 734000
# is_sezure: False date: 2019-05-22 09:27:54.002000 lenthWindow: 2000 start: 734000 end: 736000
# is_sezure: False date: 2019-05-22 09:27:58.002000 lenthWindow: 2000 start: 736000 end: 738000
# is_sezure: False date: 2019-05-22 09:28:02.002000 lenthWindow: 2000 start: 738000 end: 740000
# is_sezure: False date: 2019-05-22 09:28:06.002000 lenthWindow: 2000 start: 740000 end: 742000
# is_sezure: False date: 2019-05-22 09:28:10.002000 lenthWindow: 2000 start: 742000 end: 744000
# is_sezure: False date: 2019-05-22 09:28:14.002000 lenthWindow: 2000 start: 744000 end: 746000
# is_sezure: False date: 2019-05-22 09:28:18.002000 lenthWindow: 2000 start: 746000 end: 748000
# is_sezure: False date: 2019-05-22 09:28:22.002000 lenthWindow: 2000 start: 748000 end: 750000
# is_sezure: False date: 2019-05-22 09:28:26.002000 lenthWindow: 2000 start: 750000 end: 752000
# is_sezure: False date: 2019-05-22 09:28:30.002000 lenthWindow: 2000 start: 752000 end: 754000
# is_sezure: False date: 2019-05-22 09:28:34.002000 lenthWindow: 2000 start: 754000 end: 756000
# is_sezure: False date: 2019-05-22 09:28:38.002000 lenthWindow: 2000 start: 756000 end: 758000
# is_sezure: False date: 2019-05-22 09:28:42.002000 lenthWindow: 2000 start: 758000 end: 760000
# is_sezure: False date: 2019-05-22 09:28:46.002000 lenthWindow: 2000 start: 760000 end: 762000
# is_sezure: False date: 2019-05-22 09:28:50.002000 lenthWindow: 2000 start: 762000 end: 764000
# is_sezure: False date: 2019-05-22 09:28:54.002000 lenthWindow: 2000 start: 764000 end: 766000
# is_sezure: False date: 2019-05-22 09:28:58.002000 lenthWindow: 2000 start: 766000 end: 768000
# is_sezure: False date: 2019-05-22 09:29:02.002000 lenthWindow: 2000 start: 768000 end: 770000
# is_sezure: False date: 2019-05-22 09:29:06.002000 lenthWindow: 2000 start: 770000 end: 772000
# is_sezure: False date: 2019-05-22 09:29:10.002000 lenthWindow: 2000 start: 772000 end: 774000
# is_sezure: False date: 2019-05-22 09:29:14.002000 lenthWindow: 2000 start: 774000 end: 776000
# is_sezure: False date: 2019-05-22 09:29:18.002000 lenthWindow: 2000 start: 776000 end: 778000
# is_sezure: False date: 2019-05-22 09:29:22.002000 lenthWindow: 2000 start: 778000 end: 780000
# is_sezure: False date: 2019-05-22 09:29:26.002000 lenthWindow: 2000 start: 780000 end: 782000
# is_sezure: False date: 2019-05-22 09:29:30.002000 lenthWindow: 2000 start: 782000 end: 784000
# is_sezure: False date: 2019-05-22 09:29:34.002000 lenthWindow: 2000 start: 784000 end: 786000
# is_sezure: False date: 2019-05-22 09:29:38.002000 lenthWindow: 2000 start: 786000 end: 788000
# is_sezure: False date: 2019-05-22 09:29:42.002000 lenthWindow: 2000 start: 788000 end: 790000
# is_sezure: False date: 2019-05-22 09:29:46.002000 lenthWindow: 2000 start: 790000 end: 792000
# is_sezure: False date: 2019-05-22 09:29:50.002000 lenthWindow: 2000 start: 792000 end: 794000
# is_sezure: False date: 2019-05-22 09:29:54.002000 lenthWindow: 2000 start: 794000 end: 796000
# is_sezure: False date: 2019-05-22 09:29:58.002000 lenthWindow: 2000 start: 796000 end: 798000
# is_sezure: False date: 2019-05-22 09:30:02.002000 lenthWindow: 2000 start: 798000 end: 800000
# is_sezure: False date: 2019-05-22 09:30:06.002000 lenthWindow: 2000 start: 800000 end: 802000
# is_sezure: False date: 2019-05-22 09:30:10.002000 lenthWindow: 2000 start: 802000 end: 804000
# is_sezure: False date: 2019-05-22 09:30:14.002000 lenthWindow: 2000 start: 804000 end: 806000
# is_sezure: False date: 2019-05-22 09:30:18.002000 lenthWindow: 2000 start: 806000 end: 808000
# is_sezure: False date: 2019-05-22 09:30:22.002000 lenthWindow: 2000 start: 808000 end: 810000
# is_sezure: False date: 2019-05-22 09:30:26.002000 lenthWindow: 2000 start: 810000 end: 812000
# is_sezure: False date: 2019-05-22 09:30:30.002000 lenthWindow: 2000 start: 812000 end: 814000
# is_sezure: False date: 2019-05-22 09:30:34.002000 lenthWindow: 2000 start: 814000 end: 816000
# is_sezure: False date: 2019-05-22 09:30:38.002000 lenthWindow: 2000 start: 816000 end: 818000
# is_sezure: False date: 2019-05-22 09:30:42.002000 lenthWindow: 2000 start: 818000 end: 820000
# is_sezure: False date: 2019-05-22 09:30:46.002000 lenthWindow: 2000 start: 820000 end: 822000
# is_sezure: False date: 2019-05-22 09:30:50.002000 lenthWindow: 2000 start: 822000 end: 824000
# is_sezure: False date: 2019-05-22 09:30:54.002000 lenthWindow: 2000 start: 824000 end: 826000
# is_sezure: False date: 2019-05-22 09:30:58.002000 lenthWindow: 2000 start: 826000 end: 828000
# is_sezure: False date: 2019-05-22 09:31:02.002000 lenthWindow: 2000 start: 828000 end: 830000
# is_sezure: False date: 2019-05-22 09:31:06.002000 lenthWindow: 2000 start: 830000 end: 832000
# is_sezure: False date: 2019-05-22 09:31:10.002000 lenthWindow: 2000 start: 832000 end: 834000
# is_sezure: False date: 2019-05-22 09:31:14.002000 lenthWindow: 2000 start: 834000 end: 836000
# is_sezure: False date: 2019-05-22 09:31:18.002000 lenthWindow: 2000 start: 836000 end: 838000
# is_sezure: False date: 2019-05-22 09:31:22.002000 lenthWindow: 2000 start: 838000 end: 840000
# is_sezure: False date: 2019-05-22 09:31:26.002000 lenthWindow: 2000 start: 840000 end: 842000
# is_sezure: False date: 2019-05-22 09:31:30.002000 lenthWindow: 2000 start: 842000 end: 844000
# is_sezure: False date: 2019-05-22 09:31:34.002000 lenthWindow: 2000 start: 844000 end: 846000
# is_sezure: False date: 2019-05-22 09:31:38.002000 lenthWindow: 2000 start: 846000 end: 848000
# is_sezure: False date: 2019-05-22 09:31:42.002000 lenthWindow: 2000 start: 848000 end: 850000
# is_sezure: False date: 2019-05-22 09:31:46.002000 lenthWindow: 2000 start: 850000 end: 852000
# is_sezure: False date: 2019-05-22 09:31:50.002000 lenthWindow: 2000 start: 852000 end: 854000
# is_sezure: False date: 2019-05-22 09:31:54.002000 lenthWindow: 2000 start: 854000 end: 856000
# is_sezure: False date: 2019-05-22 09:31:58.002000 lenthWindow: 2000 start: 856000 end: 858000
# is_sezure: False date: 2019-05-22 09:32:02.002000 lenthWindow: 2000 start: 858000 end: 860000
# is_sezure: False date: 2019-05-22 09:32:06.002000 lenthWindow: 2000 start: 860000 end: 862000
# is_sezure: False date: 2019-05-22 09:32:10.002000 lenthWindow: 2000 start: 862000 end: 864000
# is_sezure: False date: 2019-05-22 09:32:14.002000 lenthWindow: 2000 start: 864000 end: 866000
# is_sezure: False date: 2019-05-22 09:32:18.002000 lenthWindow: 2000 start: 866000 end: 868000
# is_sezure: False date: 2019-05-22 09:32:22.002000 lenthWindow: 2000 start: 868000 end: 870000
# is_sezure: False date: 2019-05-22 09:32:26.002000 lenthWindow: 2000 start: 870000 end: 872000
# is_sezure: False date: 2019-05-22 09:32:30.002000 lenthWindow: 2000 start: 872000 end: 874000
# is_sezure: False date: 2019-05-22 09:32:34.002000 lenthWindow: 2000 start: 874000 end: 876000
# is_sezure: False date: 2019-05-22 09:32:38.002000 lenthWindow: 2000 start: 876000 end: 878000
# is_sezure: False date: 2019-05-22 09:32:42.002000 lenthWindow: 2000 start: 878000 end: 880000
# is_sezure: False date: 2019-05-22 09:32:46.002000 lenthWindow: 2000 start: 880000 end: 882000
# is_sezure: False date: 2019-05-22 09:32:50.002000 lenthWindow: 2000 start: 882000 end: 884000
# is_sezure: False date: 2019-05-22 09:32:54.002000 lenthWindow: 2000 start: 884000 end: 886000
# is_sezure: False date: 2019-05-22 09:32:58.002000 lenthWindow: 2000 start: 886000 end: 888000
# is_sezure: False date: 2019-05-22 09:33:02.002000 lenthWindow: 2000 start: 888000 end: 890000
# is_sezure: False date: 2019-05-22 09:33:06.002000 lenthWindow: 2000 start: 890000 end: 892000
# is_sezure: False date: 2019-05-22 09:33:10.002000 lenthWindow: 2000 start: 892000 end: 894000
# is_sezure: False date: 2019-05-22 09:33:14.002000 lenthWindow: 2000 start: 894000 end: 896000
# is_sezure: False date: 2019-05-22 09:33:18.002000 lenthWindow: 2000 start: 896000 end: 898000
# is_sezure: False date: 2019-05-22 09:33:22.002000 lenthWindow: 2000 start: 898000 end: 900000
# is_sezure: False date: 2019-05-22 09:33:26.002000 lenthWindow: 2000 start: 900000 end: 902000
# is_sezure: False date: 2019-05-22 09:33:30.002000 lenthWindow: 2000 start: 902000 end: 904000
# is_sezure: False date: 2019-05-22 09:33:34.002000 lenthWindow: 2000 start: 904000 end: 906000
# is_sezure: False date: 2019-05-22 09:33:38.002000 lenthWindow: 2000 start: 906000 end: 908000
# is_sezure: False date: 2019-05-22 09:33:42.002000 lenthWindow: 2000 start: 908000 end: 910000
# is_sezure: False date: 2019-05-22 09:33:46.002000 lenthWindow: 2000 start: 910000 end: 912000
# is_sezure: False date: 2019-05-22 09:33:50.002000 lenthWindow: 2000 start: 912000 end: 914000
# is_sezure: False date: 2019-05-22 09:33:54.002000 lenthWindow: 2000 start: 914000 end: 916000
# is_sezure: False date: 2019-05-22 09:33:58.002000 lenthWindow: 2000 start: 916000 end: 918000
# is_sezure: False date: 2019-05-22 09:34:02.002000 lenthWindow: 2000 start: 918000 end: 920000
# is_sezure: False date: 2019-05-22 09:34:06.002000 lenthWindow: 2000 start: 920000 end: 922000
# is_sezure: False date: 2019-05-22 09:34:10.002000 lenthWindow: 2000 start: 922000 end: 924000
# is_sezure: False date: 2019-05-22 09:34:14.002000 lenthWindow: 2000 start: 924000 end: 926000
# is_sezure: False date: 2019-05-22 09:34:18.002000 lenthWindow: 2000 start: 926000 end: 928000
# is_sezure: False date: 2019-05-22 09:34:22.002000 lenthWindow: 2000 start: 928000 end: 930000
# is_sezure: False date: 2019-05-22 09:34:26.002000 lenthWindow: 2000 start: 930000 end: 932000
# is_sezure: False date: 2019-05-22 09:34:30.002000 lenthWindow: 2000 start: 932000 end: 934000
# is_sezure: False date: 2019-05-22 09:34:34.002000 lenthWindow: 2000 start: 934000 end: 936000
# is_sezure: False date: 2019-05-22 09:34:38.002000 lenthWindow: 2000 start: 936000 end: 938000
# is_sezure: False date: 2019-05-22 09:34:42.002000 lenthWindow: 2000 start: 938000 end: 940000
# is_sezure: False date: 2019-05-22 09:34:46.002000 lenthWindow: 2000 start: 940000 end: 942000
# is_sezure: False date: 2019-05-22 09:34:50.002000 lenthWindow: 2000 start: 942000 end: 944000
# is_sezure: False date: 2019-05-22 09:34:54.002000 lenthWindow: 2000 start: 944000 end: 946000
# is_sezure: False date: 2019-05-22 09:34:58.002000 lenthWindow: 2000 start: 946000 end: 948000
# is_sezure: False date: 2019-05-22 09:35:02.002000 lenthWindow: 2000 start: 948000 end: 950000
# is_sezure: False date: 2019-05-22 09:35:06.002000 lenthWindow: 2000 start: 950000 end: 952000
# is_sezure: False date: 2019-05-22 09:35:10.002000 lenthWindow: 2000 start: 952000 end: 954000
# is_sezure: False date: 2019-05-22 09:35:14.002000 lenthWindow: 2000 start: 954000 end: 956000
# is_sezure: False date: 2019-05-22 09:35:18.002000 lenthWindow: 2000 start: 956000 end: 958000
# is_sezure: False date: 2019-05-22 09:35:22.002000 lenthWindow: 2000 start: 958000 end: 960000
# is_sezure: False date: 2019-05-22 09:35:26.002000 lenthWindow: 2000 start: 960000 end: 962000
# is_sezure: False date: 2019-05-22 09:35:30.002000 lenthWindow: 2000 start: 962000 end: 964000
# is_sezure: False date: 2019-05-22 09:35:34.002000 lenthWindow: 2000 start: 964000 end: 966000
# is_sezure: False date: 2019-05-22 09:35:38.002000 lenthWindow: 2000 start: 966000 end: 968000
# is_sezure: False date: 2019-05-22 09:35:42.002000 lenthWindow: 2000 start: 968000 end: 970000
# is_sezure: False date: 2019-05-22 09:35:46.002000 lenthWindow: 2000 start: 970000 end: 972000
# is_sezure: False date: 2019-05-22 09:35:50.002000 lenthWindow: 2000 start: 972000 end: 974000
# is_sezure: False date: 2019-05-22 09:35:54.002000 lenthWindow: 2000 start: 974000 end: 976000
# is_sezure: False date: 2019-05-22 09:35:58.002000 lenthWindow: 2000 start: 976000 end: 978000
# is_sezure: False date: 2019-05-22 09:36:02.002000 lenthWindow: 2000 start: 978000 end: 980000
# is_sezure: False date: 2019-05-22 09:36:06.002000 lenthWindow: 2000 start: 980000 end: 982000
# is_sezure: False date: 2019-05-22 09:36:10.002000 lenthWindow: 2000 start: 982000 end: 984000
# is_sezure: False date: 2019-05-22 09:36:14.002000 lenthWindow: 2000 start: 984000 end: 986000
# is_sezure: False date: 2019-05-22 09:36:18.002000 lenthWindow: 2000 start: 986000 end: 988000
# is_sezure: False date: 2019-05-22 09:36:22.002000 lenthWindow: 2000 start: 988000 end: 990000
# is_sezure: False date: 2019-05-22 09:36:26.002000 lenthWindow: 2000 start: 990000 end: 992000
# is_sezure: False date: 2019-05-22 09:36:30.002000 lenthWindow: 2000 start: 992000 end: 994000
# is_sezure: False date: 2019-05-22 09:36:34.002000 lenthWindow: 2000 start: 994000 end: 996000
# is_sezure: False date: 2019-05-22 09:36:38.002000 lenthWindow: 2000 start: 996000 end: 998000
# is_sezure: False date: 2019-05-22 09:36:42.002000 lenthWindow: 2000 start: 998000 end: 1000000
# is_sezure: False date: 2019-05-22 09:36:46.002000 lenthWindow: 2000 start: 1000000 end: 1002000
# is_sezure: False date: 2019-05-22 09:36:50.002000 lenthWindow: 2000 start: 1002000 end: 1004000
# is_sezure: False date: 2019-05-22 09:36:54.002000 lenthWindow: 2000 start: 1004000 end: 1006000
# is_sezure: False date: 2019-05-22 09:36:58.002000 lenthWindow: 2000 start: 1006000 end: 1008000
# is_sezure: False date: 2019-05-22 09:37:02.002000 lenthWindow: 2000 start: 1008000 end: 1010000
# is_sezure: False date: 2019-05-22 09:37:06.002000 lenthWindow: 2000 start: 1010000 end: 1012000
# is_sezure: False date: 2019-05-22 09:37:10.002000 lenthWindow: 2000 start: 1012000 end: 1014000
# is_sezure: False date: 2019-05-22 09:37:14.002000 lenthWindow: 2000 start: 1014000 end: 1016000
# is_sezure: False date: 2019-05-22 09:37:18.002000 lenthWindow: 2000 start: 1016000 end: 1018000
# is_sezure: False date: 2019-05-22 09:37:22.002000 lenthWindow: 2000 start: 1018000 end: 1020000
# is_sezure: False date: 2019-05-22 09:37:26.002000 lenthWindow: 2000 start: 1020000 end: 1022000
# is_sezure: False date: 2019-05-22 09:37:30.002000 lenthWindow: 2000 start: 1022000 end: 1024000
# is_sezure: False date: 2019-05-22 09:37:34.002000 lenthWindow: 2000 start: 1024000 end: 1026000
# ...
# is_sezure: True date: 2019-05-22 09:01:42 lenthWindow: 2000 start: 5000 end: 7000
# is_sezure: True date: 2019-05-22 09:01:44 lenthWindow: 2000 start: 6000 end: 8000
# is_sezure: True date: 2019-05-22 09:01:46 lenthWindow: 2000 start: 7000 end: 9000
# is_sezure: True date: 2019-05-22 09:01:48 lenthWindow: 2000 start: 8000 end: 10000
# is_sezure: True date: 2019-05-22 09:01:50 lenthWindow: 2000 start: 9000 end: 11000
# is_sezure: True date: 2019-05-22 09:01:52 lenthWindow: 2000 start: 10000 end: 12000
# is_sezure: True date: 2019-05-22 09:01:54 lenthWindow: 2000 start: 11000 end: 13000
# is_sezure: True date: 2019-05-22 09:01:56 lenthWindow: 2000 start: 12000 end: 14000
# is_sezure: True date: 2019-05-22 09:01:58 lenthWindow: 2000 start: 13000 end: 15000
# is_sezure: True date: 2019-05-22 09:02:00 lenthWindow: 2000 start: 14000 end: 16000
# is_sezure: True date: 2019-05-22 09:02:02 lenthWindow: 2000 start: 15000 end: 17000
# is_sezure: True date: 2019-05-22 09:02:04 lenthWindow: 2000 start: 16000 end: 18000
# is_sezure: True date: 2019-05-22 09:02:06 lenthWindow: 2000 start: 17000 end: 19000
# is_sezure: True date: 2019-05-22 09:02:08 lenthWindow: 2000 start: 18000 end: 20000
# is_sezure: True date: 2019-05-22 09:02:10 lenthWindow: 2000 start: 19000 end: 21000
# is_sezure: True date: 2019-05-22 09:02:12 lenthWindow: 2000 start: 20000 end: 22000
# is_sezure: True date: 2019-05-22 09:02:14 lenthWindow: 2000 start: 21000 end: 23000
# is_sezure: True date: 2019-05-22 09:02:16 lenthWindow: 2000 start: 22000 end: 24000
# is_sezure: True date: 2019-05-22 09:02:18 lenthWindow: 2000 start: 23000 end: 25000
# is_sezure: True date: 2019-05-22 09:02:20 lenthWindow: 2000 start: 24000 end: 26000
# is_sezure: True date: 2019-05-22 09:02:22 lenthWindow: 2000 start: 25000 end: 27000
# is_sezure: True date: 2019-05-22 09:02:24 lenthWindow: 2000 start: 26000 end: 28000
# is_sezure: True date: 2019-05-22 09:02:26 lenthWindow: 2000 start: 27000 end: 29000
# is_sezure: True date: 2019-05-22 09:02:28 lenthWindow: 2000 start: 28000 end: 30000
# is_sezure: True date: 2019-05-22 09:02:30 lenthWindow: 2000 start: 29000 end: 31000
# is_sezure: True date: 2019-05-22 09:02:32 lenthWindow: 2000 start: 30000 end: 32000
# is_sezure: True date: 2019-05-22 09:02:34 lenthWindow: 2000 start: 31000 end: 33000
# is_sezure: True date: 2019-05-22 09:02:36 lenthWindow: 2000 start: 32000 end: 34000
# is_sezure: True date: 2019-05-22 09:02:38 lenthWindow: 2000 start: 33000 end: 35000
# is_sezure: True date: 2019-05-22 09:02:40 lenthWindow: 2000 start: 34000 end: 36000
# is_sezure: True date: 2019-05-22 09:02:42 lenthWindow: 2000 start: 35000 end: 37000
# is_sezure: True date: 2019-05-22 09:02:44 lenthWindow: 2000 start: 36000 end: 38000
# is_sezure: True date: 2019-05-22 09:02:46 lenthWindow: 2000 start: 37000 end: 39000
# is_sezure: True date: 2019-05-22 09:02:48 lenthWindow: 2000 start: 38000 end: 40000
# is_sezure: True date: 2019-05-22 09:02:50 lenthWindow: 2000 start: 39000 end: 41000
# is_sezure: True date: 2019-05-22 09:02:52 lenthWindow: 2000 start: 40000 end: 42000
# is_sezure: True date: 2019-05-22 09:02:54 lenthWindow: 2000 start: 41000 end: 43000
# is_sezure: True date: 2019-05-22 09:02:56 lenthWindow: 2000 start: 42000 end: 44000
# is_sezure: True date: 2019-05-22 09:02:58 lenthWindow: 2000 start: 43000 end: 45000
# is_sezure: True date: 2019-05-22 09:03:00 lenthWindow: 2000 start: 44000 end: 46000
# is_sezure: True date: 2019-05-22 09:03:02 lenthWindow: 2000 start: 45000 end: 47000
# is_sezure: True date: 2019-05-22 09:03:04 lenthWindow: 2000 start: 46000 end: 48000
# is_sezure: True date: 2019-05-22 09:03:06 lenthWindow: 2000 start: 47000 end: 49000
# is_sezure: True date: 2019-05-22 09:03:08 lenthWindow: 2000 start: 48000 end: 50000
# is_sezure: True date: 2019-05-22 09:03:10 lenthWindow: 2000 start: 49000 end: 51000
# is_sezure: True date: 2019-05-22 09:03:12 lenthWindow: 2000 start: 50000 end: 52000
# is_sezure: True date: 2019-05-22 09:03:14 lenthWindow: 2000 start: 51000 end: 53000
# is_sezure: True date: 2019-05-22 09:03:16 lenthWindow: 2000 start: 52000 end: 54000
# is_sezure: True date: 2019-05-22 09:03:18 lenthWindow: 2000 start: 53000 end: 55000
# is_sezure: True date: 2019-05-22 09:03:20 lenthWindow: 2000 start: 54000 end: 56000
# is_sezure: True date: 2019-05-22 09:03:22 lenthWindow: 2000 start: 55000 end: 57000
# is_sezure: True date: 2019-05-22 09:03:24 lenthWindow: 2000 start: 56000 end: 58000
# is_sezure: True date: 2019-05-22 09:05:20.002000 lenthWindow: 2000 start: 57000 end: 59000
# is_sezure: True date: 2019-05-22 09:05:22.002000 lenthWindow: 2000 start: 58000 end: 60000
# is_sezure: True date: 2019-05-22 09:05:24.002000 lenthWindow: 2000 start: 59000 end: 61000
# is_sezure: True date: 2019-05-22 09:05:26.002000 lenthWindow: 2000 start: 60000 end: 62000
# is_sezure: True date: 2019-05-22 09:05:28.002000 lenthWindow: 2000 start: 61000 end: 63000
# is_sezure: True date: 2019-05-22 09:05:30.002000 lenthWindow: 2000 start: 62000 end: 64000
# is_sezure: True date: 2019-05-22 09:05:32.002000 lenthWindow: 2000 start: 63000 end: 65000
# is_sezure: True date: 2019-05-22 09:05:34.002000 lenthWindow: 2000 start: 64000 end: 66000
# is_sezure: True date: 2019-05-22 09:05:36.002000 lenthWindow: 2000 start: 65000 end: 67000
# is_sezure: True date: 2019-05-22 09:05:38.002000 lenthWindow: 2000 start: 66000 end: 68000
# is_sezure: True date: 2019-05-22 09:05:40.002000 lenthWindow: 2000 start: 67000 end: 69000
# is_sezure: True date: 2019-05-22 09:05:42.002000 lenthWindow: 2000 start: 68000 end: 70000
# is_sezure: True date: 2019-05-22 09:05:44.002000 lenthWindow: 2000 start: 69000 end: 71000
# is_sezure: True date: 2019-05-22 09:05:46.002000 lenthWindow: 2000 start: 70000 end: 72000
# is_sezure: True date: 2019-05-22 09:05:48.002000 lenthWindow: 2000 start: 71000 end: 73000
# is_sezure: True date: 2019-05-22 09:05:50.002000 lenthWindow: 2000 start: 72000 end: 74000
# is_sezure: True date: 2019-05-22 09:05:52.002000 lenthWindow: 2000 start: 73000 end: 75000
# is_sezure: True date: 2019-05-22 09:05:54.002000 lenthWindow: 2000 start: 74000 end: 76000
# is_sezure: True date: 2019-05-22 09:05:56.002000 lenthWindow: 2000 start: 75000 end: 77000
# is_sezure: True date: 2019-05-22 09:05:58.002000 lenthWindow: 2000 start: 76000 end: 78000
# is_sezure: True date: 2019-05-22 09:06:00.002000 lenthWindow: 2000 start: 77000 end: 79000
# is_sezure: True date: 2019-05-22 09:06:02.002000 lenthWindow: 2000 start: 78000 end: 80000
# is_sezure: True date: 2019-05-22 09:06:04.002000 lenthWindow: 2000 start: 79000 end: 81000
# is_sezure: True date: 2019-05-22 09:06:06.002000 lenthWindow: 2000 start: 80000 end: 82000
# is_sezure: True date: 2019-05-22 09:06:08.002000 lenthWindow: 2000 start: 81000 end: 83000
# is_sezure: True date: 2019-05-22 09:06:10.002000 lenthWindow: 2000 start: 82000 end: 84000
# is_sezure: True date: 2019-05-22 09:06:12.002000 lenthWindow: 2000 start: 83000 end: 85000
# is_sezure: True date: 2019-05-22 09:06:14.002000 lenthWindow: 2000 start: 84000 end: 86000
# is_sezure: True date: 2019-05-22 09:06:16.002000 lenthWindow: 2000 start: 85000 end: 87000
# is_sezure: True date: 2019-05-22 09:06:18.002000 lenthWindow: 2000 start: 86000 end: 88000
# is_sezure: True date: 2019-05-22 09:06:20.002000 lenthWindow: 2000 start: 87000 end: 89000
# is_sezure: True date: 2019-05-22 09:06:22.002000 lenthWindow: 2000 start: 88000 end: 90000
# is_sezure: True date: 2019-05-22 09:06:24.002000 lenthWindow: 2000 start: 89000 end: 91000
# is_sezure: True date: 2019-05-22 09:06:26.002000 lenthWindow: 2000 start: 90000 end: 92000
# is_sezure: True date: 2019-05-22 09:06:28.002000 lenthWindow: 2000 start: 91000 end: 93000
# is_sezure: True date: 2019-05-22 09:06:30.002000 lenthWindow: 2000 start: 92000 end: 94000
# is_sezure: True date: 2019-05-22 09:06:32.002000 lenthWindow: 2000 start: 93000 end: 95000
# is_sezure: True date: 2019-05-22 09:06:34.002000 lenthWindow: 2000 start: 94000 end: 96000
# is_sezure: True date: 2019-05-22 09:06:36.002000 lenthWindow: 2000 start: 95000 end: 97000
# is_sezure: True date: 2019-05-22 09:06:38.002000 lenthWindow: 2000 start: 96000 end: 98000
# is_sezure: True date: 2019-05-22 09:06:40.002000 lenthWindow: 2000 start: 97000 end: 99000
# is_sezure: True date: 2019-05-22 09:06:42.002000 lenthWindow: 2000 start: 98000 end: 100000
# is_sezure: True date: 2019-05-22 09:06:44.002000 lenthWindow: 2000 start: 99000 end: 101000
# is_sezure: True date: 2019-05-22 09:06:46.002000 lenthWindow: 2000 start: 100000 end: 102000
# is_sezure: True date: 2019-05-22 09:06:48.002000 lenthWindow: 2000 start: 101000 end: 103000
# is_sezure: True date: 2019-05-22 09:06:50.002000 lenthWindow: 2000 start: 102000 end: 104000
# is_sezure: True date: 2019-05-22 09:06:52.002000 lenthWindow: 2000 start: 103000 end: 105000
# is_sezure: True date: 2019-05-22 09:06:54.002000 lenthWindow: 2000 start: 104000 end: 106000
# is_sezure: True date: 2019-05-22 09:06:56.002000 lenthWindow: 2000 start: 105000 end: 107000
# is_sezure: True date: 2019-05-22 09:06:58.002000 lenthWindow: 2000 start: 106000 end: 108000
# is_sezure: True date: 2019-05-22 09:07:00.002000 lenthWindow: 2000 start: 107000 end: 109000
# is_sezure: True date: 2019-05-22 09:07:02.002000 lenthWindow: 2000 start: 108000 end: 110000
# is_sezure: True date: 2019-05-22 09:07:04.002000 lenthWindow: 2000 start: 109000 end: 111000
# is_sezure: True date: 2019-05-22 09:07:06.002000 lenthWindow: 2000 start: 110000 end: 112000
# is_sezure: True date: 2019-05-22 09:07:08.002000 lenthWindow: 2000 start: 111000 end: 113000
# is_sezure: True date: 2019-05-22 09:07:10.002000 lenthWindow: 2000 start: 112000 end: 114000
# is_sezure: True date: 2019-05-22 09:07:12.002000 lenthWindow: 2000 start: 113000 end: 115000
# is_sezure: True date: 2019-05-22 09:07:14.002000 lenthWindow: 2000 start: 114000 end: 116000
# is_sezure: True date: 2019-05-22 09:07:16.002000 lenthWindow: 2000 start: 115000 end: 117000
# is_sezure: True date: 2019-05-22 09:07:18.002000 lenthWindow: 2000 start: 116000 end: 118000
# is_sezure: True date: 2019-05-22 09:07:20.002000 lenthWindow: 2000 start: 117000 end: 119000
# is_sezure: True date: 2019-05-22 09:07:22.002000 lenthWindow: 2000 start: 118000 end: 120000
# is_sezure: True date: 2019-05-22 09:07:24.002000 lenthWindow: 2000 start: 119000 end: 121000
# is_sezure: True date: 2019-05-22 09:07:26.002000 lenthWindow: 2000 start: 120000 end: 122000
# is_sezure: True date: 2019-05-22 09:07:28.002000 lenthWindow: 2000 start: 121000 end: 123000
# is_sezure: True date: 2019-05-22 09:07:30.002000 lenthWindow: 2000 start: 122000 end: 124000
# is_sezure: True date: 2019-05-22 09:07:32.002000 lenthWindow: 2000 start: 123000 end: 125000
# is_sezure: True date: 2019-05-22 09:07:34.002000 lenthWindow: 2000 start: 124000 end: 126000
# is_sezure: True date: 2019-05-22 09:07:36.002000 lenthWindow: 2000 start: 125000 end: 127000
# is_sezure: True date: 2019-05-22 09:07:38.002000 lenthWindow: 2000 start: 126000 end: 128000
# is_sezure: True date: 2019-05-22 09:07:40.002000 lenthWindow: 2000 start: 127000 end: 129000
# is_sezure: True date: 2019-05-22 09:07:42.002000 lenthWindow: 2000 start: 128000 end: 130000
# is_sezure: True date: 2019-05-22 09:07:44.002000 lenthWindow: 2000 start: 129000 end: 131000
# is_sezure: True date: 2019-05-22 09:07:46.002000 lenthWindow: 2000 start: 130000 end: 132000
# is_sezure: True date: 2019-05-22 09:07:48.002000 lenthWindow: 2000 start: 131000 end: 133000
# is_sezure: True date: 2019-05-22 09:07:50.002000 lenthWindow: 2000 start: 132000 end: 134000
# is_sezure: True date: 2019-05-22 09:07:52.002000 lenthWindow: 2000 start: 133000 end: 135000
# is_sezure: True date: 2019-05-22 09:07:54.002000 lenthWindow: 2000 start: 134000 end: 136000
# is_sezure: True date: 2019-05-22 09:07:56.002000 lenthWindow: 2000 start: 135000 end: 137000
# is_sezure: True date: 2019-05-22 09:07:58.002000 lenthWindow: 2000 start: 136000 end: 138000
# is_sezure: True date: 2019-05-22 09:08:00.002000 lenthWindow: 2000 start: 137000 end: 139000
# is_sezure: True date: 2019-05-22 09:08:02.002000 lenthWindow: 2000 start: 138000 end: 140000
# is_sezure: True date: 2019-05-22 09:08:04.002000 lenthWindow: 2000 start: 139000 end: 141000
# is_sezure: True date: 2019-05-22 09:08:06.002000 lenthWindow: 2000 start: 140000 end: 142000
# is_sezure: True date: 2019-05-22 09:08:08.002000 lenthWindow: 2000 start: 141000 end: 143000
# is_sezure: True date: 2019-05-22 09:08:10.002000 lenthWindow: 2000 start: 142000 end: 144000
# is_sezure: True date: 2019-05-22 09:08:12.002000 lenthWindow: 2000 start: 143000 end: 145000
# is_sezure: True date: 2019-05-22 09:08:14.002000 lenthWindow: 2000 start: 144000 end: 146000
# is_sezure: True date: 2019-05-22 09:08:16.002000 lenthWindow: 2000 start: 145000 end: 147000
# is_sezure: True date: 2019-05-22 09:08:18.002000 lenthWindow: 2000 start: 146000 end: 148000
# is_sezure: True date: 2019-05-22 09:08:20.002000 lenthWindow: 2000 start: 147000 end: 149000
# is_sezure: True date: 2019-05-22 09:08:22.002000 lenthWindow: 2000 start: 148000 end: 150000
# is_sezure: True date: 2019-05-22 09:08:24.002000 lenthWindow: 2000 start: 149000 end: 151000
# is_sezure: True date: 2019-05-22 09:08:26.002000 lenthWindow: 2000 start: 150000 end: 152000
# is_sezure: True date: 2019-05-22 09:08:28.002000 lenthWindow: 2000 start: 151000 end: 153000
# is_sezure: True date: 2019-05-22 09:08:30.002000 lenthWindow: 2000 start: 152000 end: 154000
# is_sezure: True date: 2019-05-22 09:08:32.002000 lenthWindow: 2000 start: 153000 end: 155000
# is_sezure: True date: 2019-05-22 09:08:34.002000 lenthWindow: 2000 start: 154000 end: 156000
# is_sezure: True date: 2019-05-22 09:08:36.002000 lenthWindow: 2000 start: 155000 end: 157000
# is_sezure: True date: 2019-05-22 09:08:38.002000 lenthWindow: 2000 start: 156000 end: 158000
# is_sezure: True date: 2019-05-22 09:08:40.002000 lenthWindow: 2000 start: 157000 end: 159000
# is_sezure: True date: 2019-05-22 09:08:42.002000 lenthWindow: 2000 start: 158000 end: 160000
# is_sezure: True date: 2019-05-22 09:08:44.002000 lenthWindow: 2000 start: 159000 end: 161000
# is_sezure: True date: 2019-05-22 09:08:46.002000 lenthWindow: 2000 start: 160000 end: 162000
# is_sezure: True date: 2019-05-22 09:08:48.002000 lenthWindow: 2000 start: 161000 end: 163000
# is_sezure: True date: 2019-05-22 09:08:50.002000 lenthWindow: 2000 start: 162000 end: 164000
# is_sezure: True date: 2019-05-22 09:08:52.002000 lenthWindow: 2000 start: 163000 end: 165000
# is_sezure: True date: 2019-05-22 09:08:54.002000 lenthWindow: 2000 start: 164000 end: 166000
# is_sezure: True date: 2019-05-22 09:08:56.002000 lenthWindow: 2000 start: 165000 end: 167000
# is_sezure: True date: 2019-05-22 09:08:58.002000 lenthWindow: 2000 start: 166000 end: 168000
# is_sezure: True date: 2019-05-22 09:09:00.002000 lenthWindow: 2000 start: 167000 end: 169000
# is_sezure: True date: 2019-05-22 09:09:02.002000 lenthWindow: 2000 start: 168000 end: 170000
# is_sezure: True date: 2019-05-22 09:09:04.002000 lenthWindow: 2000 start: 169000 end: 171000
# is_sezure: True date: 2019-05-22 09:09:06.002000 lenthWindow: 2000 start: 170000 end: 172000
# is_sezure: True date: 2019-05-22 09:09:08.002000 lenthWindow: 2000 start: 171000 end: 173000
# is_sezure: True date: 2019-05-22 09:09:10.002000 lenthWindow: 2000 start: 172000 end: 174000
# is_sezure: True date: 2019-05-22 09:09:12.002000 lenthWindow: 2000 start: 173000 end: 175000
# is_sezure: True date: 2019-05-22 09:09:14.002000 lenthWindow: 2000 start: 174000 end: 176000
# is_sezure: True date: 2019-05-22 09:09:16.002000 lenthWindow: 2000 start: 175000 end: 177000
# is_sezure: True date: 2019-05-22 09:09:18.002000 lenthWindow: 2000 start: 176000 end: 178000
# is_sezure: True date: 2019-05-22 09:09:20.002000 lenthWindow: 2000 start: 177000 end: 179000
# is_sezure: True date: 2019-05-22 09:09:22.002000 lenthWindow: 2000 start: 178000 end: 180000
# is_sezure: True date: 2019-05-22 09:09:24.002000 lenthWindow: 2000 start: 179000 end: 181000
# is_sezure: True date: 2019-05-22 09:09:26.002000 lenthWindow: 2000 start: 180000 end: 182000
# is_sezure: True date: 2019-05-22 09:09:28.002000 lenthWindow: 2000 start: 181000 end: 183000
# is_sezure: True date: 2019-05-22 09:09:30.002000 lenthWindow: 2000 start: 182000 end: 184000

# %%
non_sz_index_length = int(len(nsz_win))
sz_index_length = int(len(sz_win))
print(non_sz_index_length)
print(sz_index_length)
random_indexes_undersambler = random.sample(range(0,non_sz_index_length), sz_index_length)
random_indexes_undersambler
# Out:
# 1558
# 183
# [1134,
#  408,
#  577,
#  1054,
#  381,
#  535,
#  1263,
#  732,
#  1040,
#  187,
#  241,
#  964,
#  748,
#  1166,
#  373,
#  454,
#  400,
#  947,
#  1509,
#  1360,
#  426,
#  758,
#  368,
#  1545,
#  1053,
#  862,
#  936,
#  378,
#  1150,
#  436,
#  867,
#  672,
#  522,
#  1225,
#  247,
#  1410,
#  170,
#  1287,
#  260,
#  1535,
#  868,
#  1298,
#  203,
#  1233,
#  889,
#  92,
#  990,
#  1153,
#  741,
#  77,
#  37,
#  198,
#  466,
#  941,
#  153,
#  721,
#  1374,
#  1409,
#  651,
#  1179,
#  1349,
#  1055,
#  698,
#  605,
#  441,
#  1491,
#  623,
#  1293,
#  757,
#  179,
#  610,
#  579,
#  479,
#  1227,
#  723,
#  682,
#  342,
#  253,
#  620,
#  713,
#  1188,
#  1112,
#  811,
#  268,
#  1126,
#  822,
#  1215,
#  276,
#  1099,
#  346,
#  9,
#  518,
#  591,
#  1047,
#  1465,
#  1464,
#  803,
#  111,
#  7,
#  131,
#  743,
#  234,
#  456,
#  516,
#  113,
#  355,
#  248,
#  1451,
#  1485,
#  1091,
#  61,
#  107,
#  1486,
#  106,
#  584,
#  953,
#  927,
#  459,
#  154,
#  619,
#  690,
#  1306,
#  1552,
#  250,
#  674,
#  145,
#  119,
#  852,
#  357,
#  13,
#  1254,
#  1550,
#  937,
#  324,
#  1523,
#  905,
#  630,
#  1168,
#  125,
#  420,
#  1417,
#  337,
#  604,
#  486,
#  1388,
#  830,
#  76,
#  428,
#  323,
#  1304,
#  1039,
#  194,
#  1415,
#  1165,
#  1255,
#  195,
#  493,
#  1448,
#  313,
#  1363,
#  715,
#  1281,
#  492,
#  627,
#  685,
#  443,
#  1175,
#  815,
#  1066,
#  1084,
#  637,
#  1418,
#  624,
#  661,
#  94,
#  121,
#  1517,
#  1317,
#  1265,
#  1399,
#  1135,
#  740,
#  1013]

# %%
list_keeper = []
for i in random_indexes_undersambler:
    window_of_choice = nsz_win[i]
    list_keeper.append(window_of_choice)
print(len(list_keeper))
# Out:
# 183

# %%
nsz_win = list_keeper
for x in range(5):
    print(nsz_win[x][1])
# Out:
# 2019-05-22 10:23:15.006000
# 2019-05-22 09:30:38.002000
# 2019-05-22 09:43:54.004000
# 2019-05-22 10:15:42.004000
# 2019-05-22 09:28:50.002000

# %%
print(type(nsz_win[x][0]))
print(type(nsz_win[x][0]))
# Out:
# <class 'list'>
# <class 'list'>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
w = np.array(sz_win[2][0])
plt.plot(w)

# %%
plt.figure(figsize=(3,4))
fig, axs = plt.subplots(4,2, figsize=(20,10))
plt.tight_layout()

for win in sz_win[0:1]:
    series, date_of_observation = win
    series = np.array(series)
    denoised_series = denoise_wavelet(series, method='BayesShrink',wavelet='db6', mode='soft',rescale_sigma=True, wavelet_levels=3)
    axs[0,0].set_title(f'$Sz-Before-denoise$ {date_of_observation}')
    axs[0,0].plot(series, color='red')
    axs[0,1].set_title(f'$Sz-After-denoise$ {date_of_observation}')
    axs[0,1].plot(denoised_series)
    axs[0,1].plot(series, color='red')
    pxx, freqs, bins, img = axs[1, 0].specgram(series,Fs=500,cmap='jet')
    pxx, freqs, bins, img = axs[1, 1].specgram(denoised_series,Fs=500,cmap='jet')

for win in nsz_win[100:101]:
    series, date_of_observation = win
    series = np.array(series)
    denoised_series = denoise_wavelet(series, method='BayesShrink',wavelet='db6', mode='soft',rescale_sigma=True, wavelet_levels=3)
    axs[2,0].set_title(f'$No-Sz-Before-denoise$ {date_of_observation}')
    axs[2,0].plot(series, color='blue')
    axs[2,1].set_title(f'$No-Sz-After-denoise$ {date_of_observation}')
    axs[2,1].plot(denoised_series)
    axs[2,1].plot(series, color='blue')
    pxx, freqs, bins, img = axs[3, 0].specgram(series,Fs=500,cmap='jet')
    pxx, freqs, bins, img = axs[3, 1].specgram(denoised_series,Fs=500,cmap='jet')

# %%
safe_window_path = "Dataset/windows/"
sz_path = "sz/"
non_sz_path = "non-sz/"

# %%
def spec_transform_save_to_folder(index, win, is_seizure=False):
    plt.figure(figsize=(7,7))
    series, date_of_observation = win
    series = np.array(series)
    denoised_series = denoise_wavelet(series, method='BayesShrink',wavelet='db6', mode='soft',rescale_sigma=True, wavelet_levels=3)
    pxx, freqs, bins, img = plt.specgram(denoised_series,Fs=500,cmap='jet')
    if(is_seizure):
        plt.savefig(f'{safe_window_path}{sz_path}sz_{index}_{date_of_observation}.png')
    else:
        plt.savefig(f'{safe_window_path}{non_sz_path}nsz_{index}_{date_of_observation}.png')
    plt.close()

for index, win in enumerate(sz_win):
    spec_transform_save_to_folder(index, win, is_seizure=True)

# %%
for index, win in enumerate(nsz_win):
    spec_transform_save_to_folder(index, win)

# %% [markdown]
# # Load png's and convert to np arrays with labels

# %%
path_to_specplots = "Dataset/Windows/"

# %%
labels = [item for item in os.listdir(path_to_specplots)]
labels = np.array(labels)
labels = labels[1:]
print(labels.shape)
labels
# Out:
# (2,)
# array(['non-sz', 'sz'], dtype='<U9')

# %%
data_generator = ImageDataGenerator(rescale = 1./255, validation_split=0.3)

# %% [markdown]
# # Train, Test splits

# %%
spec_img_target_size_inception = (299, 299)
spec_img_target_size_inception_resnet = (224, 224)
spec_img_target_size_resnet = (299, 299)

# %%
train_data = data_generator.flow_from_directory(path_to_specplots, target_size=spec_img_target_size_inception, color_mode='rgb', batch_size=32, classes = list(labels), subset='training')

valida_data = data_generator.flow_from_directory(path_to_specplots, target_size=spec_img_target_size_inception, color_mode='rgb', batch_size=32, classes = list(labels), subset='validation')
# Out:
# Found 386 images belonging to 2 classes.
# Found 163 images belonging to 2 classes.

# %% [markdown]
# ## notice! we have the right img shape for the inception network as in the paper

# %%
train_data.image_shape
# Out:
# (299, 299, 3)

# %%
def show_batch(image, label):
  plt.figure(figsize=(10,10))
  for n in range(15):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image[n])
      plt.title(labels[label[n].argmax()])
      plt.axis('off')

# %%
image, label = next(train_data)
show_batch(image, label)

# %% [markdown]
# ## The paper loads the pretrained weights and doesn't freeze them

# %% [markdown]
# " Inception-v3
# has input images with a size of 299 × 299 × 3 and outputs
# 2,048-dimensional feature vectors" <br/>
# " (2) Loading
# pre-trained weights, and updating the parameters of the whole
# network during training.
# When the current datasets differ greatly from the datasets
# used in pre-trained weight training, the second approach above
# is usually adopted"

# %%
from tensorflow.keras.applications import InceptionV3

base_inceptionV3 = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape = ((299, 299, 3))
)

for layer in base_inceptionV3.layers:
    layer.trainable = True

# %% [markdown]
# "Two fully connected layers with 1,024 and 512
# neurons are added to reduce the dimensions, and a dropout
# layer (0.5) is set behind each fully connected layer to prevent
# over-fitting. The softmax of the output layer is expressed as:" <br/>
# "For each image, the feature vectors extracted from three
# network features are concatenated into a 5,632-dimensional
# feature vector."

# %%
single_inc_model = Sequential()

single_inc_model.add(base_inceptionV3)
single_inc_model.add(layers.Dense(1024, activation='relu'))
single_inc_model.add(layers.Dropout(0.5))
single_inc_model.add(layers.Flatten())
single_inc_model.add(layers.Dense(512, activation='relu'))
single_inc_model.add(layers.Dropout(0.5))
single_inc_model.add(layers.Dense(2, activation='softmax'))

# %% [markdown]
# "An online hard example mining (OHEM) (29) loss function is
# used to replace the commonly used cross-entropy loss function;
# its expression is as Equation (5). In OHEM, the loss of a batch
# sample is sorted in descending order, and the largest k (topk
# )
# values are averaged as the final loss. "

# %%
# CREATE OHEM LOSS se: https://heartbeat.comet.ml/how-to-create-a-custom-loss-function-in-keras-637bd312e9ab og https://github.com/GXYM/OHEM-loss/blob/master/Ohem.py

# %%
single_inc_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
single_inc_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# dense (Dense)                (None, 8, 8, 1024)        2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               33554944
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 57,456,930
# Trainable params: 57,422,498
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
class TestCallback(tensorflow.keras.callbacks.Callback):
    def __init__(self, test_data):
        self.test_data = test_data

    def on_epoch_end(self, epoch, logs={}):
        x = self.test_data
        loss, acc = self.model.evaluate(x, verbose=0)
        print('\nTesting loss: {}, acc: {}\n'.format(loss, acc))

# %%
history = single_inc_model.fit(
    train_data,
    epochs=30,
    steps_per_epoch = train_data.samples//32, 
    validation_data=valida_data, 
    validation_steps = valida_data.samples//32,
    callbacks=[TestCallback((valida_data))]
)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.6025 - accuracy: 0.7571 - val_loss: 50448.2656 - val_accuracy: 0.3250
#
# Testing loss: 50043.77734375, acc: 0.3312883675098419
#
# Epoch 2/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.4616 - accuracy: 0.7571 - val_loss: 45384.5508 - val_accuracy: 0.3250
#
# Testing loss: 45087.890625, acc: 0.3312883675098419
#
# Epoch 3/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.4195 - accuracy: 0.7288 - val_loss: 20567.8652 - val_accuracy: 0.3375
#
# Testing loss: 20890.724609375, acc: 0.3312883675098419
#
# Epoch 4/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.4299 - accuracy: 0.8051 - val_loss: 11175.2061 - val_accuracy: 0.3500
#
# Testing loss: 11206.30859375, acc: 0.34969326853752136
#
# Epoch 5/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.4066 - accuracy: 0.7910 - val_loss: 1533.9811 - val_accuracy: 0.3250
#
# Testing loss: 1520.232177734375, acc: 0.3312883675098419
#
# Epoch 6/30
# 12/12 [==============================] - 24s 2s/step - loss: 0.4381 - accuracy: 0.7345 - val_loss: 540.4155 - val_accuracy: 0.5750
#
# Testing loss: 541.0473022460938, acc: 0.5766871571540833
#
# Epoch 7/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.4815 - accuracy: 0.7627 - val_loss: 266.2206 - val_accuracy: 0.6188
#
# Testing loss: 271.7311706542969, acc: 0.6134969592094421
#
# Epoch 8/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.6022 - accuracy: 0.6723 - val_loss: 15771.7598 - val_accuracy: 0.3187
#
# Testing loss: 15481.482421875, acc: 0.3312883675098419
#
# Epoch 9/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.6131 - accuracy: 0.7090 - val_loss: 13805.1797 - val_accuracy: 0.3313
#
# Testing loss: 13690.6630859375, acc: 0.3312883675098419
#
# Epoch 10/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.4595 - accuracy: 0.7147 - val_loss: 1365.4541 - val_accuracy: 0.7563
#
# Testing loss: 1395.1451416015625, acc: 0.754601240158081
#
# Epoch 11/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.6006 - accuracy: 0.7401 - val_loss: 254641.1250 - val_accuracy: 0.3125
#
# Testing loss: 255304.546875, acc: 0.30674847960472107
#
# Epoch 12/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.5375 - accuracy: 0.7458 - val_loss: 41198.3164 - val_accuracy: 0.3250
#
# Testing loss: 40578.0546875, acc: 0.3312883675098419
#
# Epoch 13/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.6064 - accuracy: 0.7175 - val_loss: 343.9060 - val_accuracy: 0.3375
#
# Testing loss: 348.68035888671875, acc: 0.3312883675098419
#
# Epoch 14/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.4594 - accuracy: 0.7627 - val_loss: 373.4414 - val_accuracy: 0.3375
#
# Testing loss: 379.4486999511719, acc: 0.3312883675098419
#
# Epoch 15/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.4967 - accuracy: 0.7542 - val_loss: 102.2597 - val_accuracy: 0.3313
#
# Testing loss: 102.5872573852539, acc: 0.3312883675098419
#
# Epoch 16/30
# 12/12 [==============================] - 29s 2s/step - loss: 0.4313 - accuracy: 0.7599 - val_loss: 82.9836 - val_accuracy: 0.4437
#
# Testing loss: 82.95064544677734, acc: 0.4478527903556824
#
# Epoch 17/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.6949 - accuracy: 0.7119 - val_loss: 420.3289 - val_accuracy: 0.6750
#
# Testing loss: 424.9981994628906, acc: 0.6687116622924805
#
# Epoch 18/30
# 12/12 [==============================] - 31s 3s/step - loss: 0.6514 - accuracy: 0.6836 - val_loss: 2265.7253 - val_accuracy: 0.3187
#
# Testing loss: 2273.748779296875, acc: 0.3312883675098419
#
# Epoch 19/30
# 12/12 [==============================] - 38s 3s/step - loss: 0.5793 - accuracy: 0.7542 - val_loss: 7023.3057 - val_accuracy: 0.3313
#
# Testing loss: 7035.34033203125, acc: 0.3312883675098419
#
# Epoch 20/30
# 12/12 [==============================] - 35s 3s/step - loss: 0.7938 - accuracy: 0.6836 - val_loss: 15054.9658 - val_accuracy: 0.3313
#
# Testing loss: 15136.6953125, acc: 0.3312883675098419
#
# Epoch 21/30
# 12/12 [==============================] - 36s 3s/step - loss: 0.7327 - accuracy: 0.6525 - val_loss: 5694.9526 - val_accuracy: 0.6125
#
# Testing loss: 5653.99072265625, acc: 0.6196319460868835
#
# Epoch 22/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.7168 - accuracy: 0.6751 - val_loss: 116.7386 - val_accuracy: 0.6750
#
# Testing loss: 120.81328582763672, acc: 0.6687116622924805
#
# Epoch 23/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.6609 - accuracy: 0.6667 - val_loss: 7.9817 - val_accuracy: 0.6687
#
# Testing loss: 7.854608535766602, acc: 0.6687116622924805
#
# Epoch 24/30
# 12/12 [==============================] - 29s 2s/step - loss: 0.6271 - accuracy: 0.6638 - val_loss: 18.7926 - val_accuracy: 0.6625
#
# Testing loss: 18.44667625427246, acc: 0.6687116622924805
#
# Epoch 25/30
# 12/12 [==============================] - 27s 2s/step - loss: 0.7746 - accuracy: 0.6638 - val_loss: 1.1733 - val_accuracy: 0.6625
#
# Testing loss: 1.1600667238235474, acc: 0.6687116622924805
#
# Epoch 26/30
# 12/12 [==============================] - 27s 2s/step - loss: 0.6669 - accuracy: 0.6780 - val_loss: 7950.0234 - val_accuracy: 0.6625
#
# Testing loss: 7803.705078125, acc: 0.6687116622924805
#
# Epoch 27/30
# 12/12 [==============================] - 24s 2s/step - loss: 0.6703 - accuracy: 0.6610 - val_loss: 2826.7083 - val_accuracy: 0.6687
#
# Testing loss: 2812.3212890625, acc: 0.6687116622924805
#
# Epoch 28/30
# 12/12 [==============================] - 25s 2s/step - loss: 0.6586 - accuracy: 0.6723 - val_loss: 3703.6531 - val_accuracy: 0.3375
#
# Testing loss: 3730.8095703125, acc: 0.3312883675098419
#
# Epoch 29/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.6507 - accuracy: 0.6667 - val_loss: 11.1230 - val_accuracy: 0.6750
#
# Testing loss: 11.153532028198242, acc: 0.6687116622924805
#
# Epoch 30/30
# 12/12 [==============================] - 24s 2s/step - loss: 0.6271 - accuracy: 0.6695 - val_loss: 61.6962 - val_accuracy: 0.6687
#
# Testing loss: 61.55009078979492, acc: 0.6687116622924805

# %%
plt.style.use('ggplot')
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'],label='accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.figure(figsize=(3,4))
fig, axs = plt.subplots(2,2, figsize=(10,10))
plt.tight_layout()
axs[0,0].set_title('acc')
axs[0,0].plot(history.history['accuracy'], color='red')
axs[0,1].set_title('loss')
axs[0,1].plot(history.history['loss'], color='red')
axs[1,0].set_title('val_acc')
axs[1,0].plot(history.history['val_accuracy'], color='red')
axs[1,1].set_title('val_loss')
axs[1,1].plot(history.history['val_loss'], color='red')
