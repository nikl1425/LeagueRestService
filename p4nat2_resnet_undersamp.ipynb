# %%
# What version of Python do you have?
import sys
import os
import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import numpy as np
import mne
import pathlib
import openpyxl
from datetime import datetime
import pytz
import random
from skimage.restoration import (denoise_wavelet, estimate_sigma)
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, Sequential
# %matplotlib inline

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.5.0
# Keras Version: 2.5.0
#
# Python 3.9.7 (default, Sep 16 2021, 23:53:23)
# [Clang 12.0.0 ]
# Pandas 1.3.1
# Scikit-Learn 0.24.2
# GPU is available

# %% [markdown]
# # Reading data and data-details

# %% [markdown]
# Read in the eeg timestamps + details.
# Then format it so we can use the timestamps for automatic processing of the .EDF files

# %%
# Read data detail sheet

print(type(str(pathlib.Path().resolve())))
print(os.getcwd())

currentPath = str(pathlib.Path().resolve())

EEG_details = pd.ExcelFile("Dataset/Data_detail.xlsx", engine="openpyxl")
# Out:
# <class 'str'>
# /Users/niklashjort/Desktop/Notes/Speciale/projects

# %%
#Sheets to dataframes:

print(EEG_details.sheet_names)


xl_detailDf = EEG_details.parse("Ark1")
print(type(xl_detailDf))
xl_detailDf
# Out:
# ['Ark1']
# <class 'pandas.core.frame.DataFrame'>
#     sync  seizure      time_trial_eeg             time_emu      delay  \
# 0      1        0                 NaT                  NaN        NaN
# 1      1        0 2019-05-20 19:33:54  20-05-2019 19:32:37  77.000000
# 2      1        0 2019-05-21 13:00:59  21-05-2019 12:59:36  83.000000
# 3      0        1 2019-05-22 02:46:45  2019-05-22 02:45:22  83.000001
# 4      1        0 2019-05-22 02:47:01  2019-05-22 02:45:37  84.000000
# 5      0        2                 NaT  2019-05-22 03:50:49        NaN
# 6      1        0 2019-05-22 03:52:16  2019-05-22 03:50:53  83.000000
# 7      0        3                 NaT  2019-05-22 05:27:56        NaN
# 8      1        0 2019-05-22 05:29:18  2019-05-22 05:27:57  81.000000
# 9      0        4                 NaT  2019-05-22 07:07:04        NaN
# 10     1        0 2019-05-22 07:08:37  2019-05-22 07:07:16  81.000000
# 11     0        5                 NaT  2019-05-22 07:51:24        NaN
# 12     1        0 2019-05-22 07:29:29  2019-05-22 07:28:08  81.000000
# 13     0        6                 NaT  2019-05-22 08:13:42        NaN
# 14     1        0 2019-05-22 08:15:03  2019-05-22 08:13:43  80.000000
# 15     0        7                 NaT  2019-05-22 09:03:55        NaN
# 16     1        0 2019-05-22 09:05:28  2019-05-22 09:04:00  88.000000
# 17     0        8                 NaT  2019-05-22 09:41:47        NaN
# 18     1        0 2019-05-22 09:41:01  2019-05-22 09:39:34  87.000000
# 19     0        9                 NaT  2019-05-22 10:20:40        NaN
# 20     1        0 2019-05-22 10:22:27  2019-05-22 10:20:59  88.000000
# 21     1        0 2019-05-22 20:21:46  2019-05-22 20:20:23  83.000000
#
#     seiz_duration                                      file_name_EEG
# 0             NaN  20190520110039_p4dag1.sdeeg_converted_.easy_fi...
# 1             NaN  20190520160924_p4nat1.sdeeg_converted_.easy_fi...
# 2             NaN  20190521084849_p4dag2.sdeeg_converted_.easy_fi...
# 3            56.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 4             NaN                                        Ny Sync-tid
# 5            53.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 6             NaN                                        Ny Sync-tid
# 7            48.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 8             NaN                                        Ny Sync-tid
# 9            52.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 10            NaN                                        Ny Sync-tid
# 11           53.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 12            NaN                                        Ny Sync-tid
# 13           54.0  20190521155643_p4Nat2.sdeeg_converted_.easy_fi...
# 14            NaN                                        Ny Sync-tid
# 15           54.0  20190522090132_p4dag3.sdeeg_converted_.easy_fi...
# 16            NaN                                        Ny Sync-tid
# 17           60.0  20190522090132_p4dag3.sdeeg_converted_.easy_fi...
# 18            NaN                                        Ny Sync-tid
# 19           73.0  20190522090132_p4dag3.sdeeg_converted_.easy_fi...
# 20            NaN                                        Ny Sync-tid
# 21            NaN  20190522171939_p4nat3.sdeeg_converted_.easy_fi...

# %%
def get(file):
    dt = datetime.strptime( file[0:file.index('_')], '%Y%m%d%H%M%S')
    return dt.timestamp()*1000

def get2(data):
    dt = datetime.strptime(data, '%Y-%m-%d %H:%M:%S').timestamp() * 1000;
    return dt # convert seconds til miliseconds

x = datetime.strptime( "22-05-2019 03:50:49", '%d-%m-%Y %H:%M:%S').timestamp()*1000

y = get2("2019-05-22 09:03:55")

y = y - 30 * 1000

print(x)
print(y)
# Out:
# 1558489849000.0
# 1558508605000.0

# %% [markdown]
# Read .EDF file

# %%
# Get seizure timestamps, filenames to array

'''
# %m Month as a zero-padded decimal number.
# %H	Hour (24-hour clock) as a zero-padded decimal number.
# %Y	Year with century as a decimal number.
# %S	Second as a zero-padded decimal number.
# %M	Minute as a zero-padded decimal number.
# %d - Represents the day of the month. Example: 01, 02, ..., 31
'''

def get_sz_time_in_ms(data):
    dt = datetime.strptime(data, '%Y-%m-%d %H:%M:%S').timestamp() * 1000;
    return dt # convert seconds til miliseconds

"""
1. if sz duration != null pass hele rækken til df
2. fil navn, duration og starttid til liste
3. returner liste
"""

buffer = 30 # ONLY USE THIS IF PRED IS BAD

def get_sz_info(xlDataFrame):
    xl_info_list = []
    for index, row in xlDataFrame.iterrows():
        if(str(row.seiz_duration) != 'nan'):
            xl_info_list.append([row['file_name_EEG'], row['time_emu'], row['seiz_duration']])
            
    for row in xl_info_list:
        sz_duration = row[2]
        sz_start = get_sz_time_in_ms(str(row[1])) - (buffer * 1000)
        sz_end = sz_start + ((row[2] + buffer + buffer) * 1000)
        row.append(sz_start)
        row.append(sz_end)
    return xl_info_list
            
        
        
xl_info_formatted = get_sz_info(xl_detailDf)
xl_info_formatted
# Out:
# [['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 2, 45, 22),
#   56.0,
#   1558485892000.0,
#   1558486008000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 3, 50, 49),
#   53.0,
#   1558489819000.0,
#   1558489932000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 5, 27, 56),
#   48.0,
#   1558495646000.0,
#   1558495754000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 7, 7, 4),
#   52.0,
#   1558501594000.0,
#   1558501706000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 7, 51, 24),
#   53.0,
#   1558504254000.0,
#   1558504367000.0],
#  ['20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 8, 13, 42),
#   54.0,
#   1558505592000.0,
#   1558505706000.0],
#  ['20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 9, 3, 55),
#   54.0,
#   1558508605000.0,
#   1558508719000.0],
#  ['20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 9, 41, 47),
#   60.0,
#   1558510877000.0,
#   1558510997000.0],
#  ['20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf',
#   datetime.datetime(2019, 5, 22, 10, 20, 40),
#   73.0,
#   1558513210000.0,
#   1558513343000.0]]

# %%
def GetAllEdfFileNames(directory):
    fileType = ".edf"
    files = os.listdir(directory)
    edfFileNameList = [(directory + "/" + x) for x in files if x.endswith(fileType)]
    return edfFileNameList

EEG_dataset= GetAllEdfFileNames("Dataset")

for file in EEG_dataset:
    print(file)

def ReadEdfFile(FileName):
    data = mne.io.read_raw_edf(FileName)
    raw_data = data.get_data()
    print("\n" + FileName.upper())
    print(data.info)
    print(type(raw_data)) # Numpy
    print(raw_data.shape)
    return raw_data, data.ch_names
# Out:
# Dataset/20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# Dataset/20190520160924_p4nat1.sdeeg_converted_.easy_filtered.edf
# Dataset/20190521084849_p4dag2.sdeeg_converted_.easy_filtered.edf
# Dataset/20190520110039_p4dag1.sdeeg_converted_.easy_filtered.edf
# Dataset/20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# Dataset/20190522171939_p4nat3.sdeeg_converted_.easy_filtered.edf

# %% [markdown]
# 1 / samplerate(500) = 2 ms

# %%
# Insert time stamp col in all dataframes function.

def get_time_in_ms(file):
    print(datetime.strptime( file[0:file.index('_')], '%Y%m%d%H%M%S'))
    dt = datetime.strptime( file[0:file.index('_')], '%Y%m%d%H%M%S')
    return dt.timestamp() * 1000 # convert seconds til miliseconds

df_list = list()

# Create dataframes, add col=timestamps, insert into df list

for file in EEG_dataset:
    currentEDF, channel = ReadEdfFile(file)
    df = pd.DataFrame(currentEDF.transpose(), columns=channel)
    timeStart = get_time_in_ms(file.replace("Dataset/", ""))
    df.insert(0, "timestampMS", [timeStart + x*2 for x in df.index])
    df_list.append([df, file.replace("Dataset/", "")])
# Out:
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190521155643_P4NAT2.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-21 15:56:43 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 32400000)
# 2019-05-21 15:56:43
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190520160924_p4nat1.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190520160924_P4NAT1.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-20 16:09:24 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 32400000)
# 2019-05-20 16:09:24
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190521084849_p4dag2.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190521084849_P4DAG2.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-21 08:48:49 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 12600000)
# 2019-05-21 08:48:49
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190520110039_p4dag1.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190520110039_P4DAG1.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-20 11:00:39 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 9900500)
# 2019-05-20 11:00:39
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190522090132_P4DAG3.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-22 09:01:32 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 3300500)
# 2019-05-22 09:01:32
# Extracting EDF parameters from /Users/niklashjort/Desktop/Notes/Speciale/projects/Dataset/20190522171939_p4nat3.sdeeg_converted_.easy_filtered.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# DATASET/20190522171939_P4NAT3.SDEEG_CONVERTED_.EASY_FILTERED.EDF
# <Info | 7 non-empty values
#  bads: []
#  ch_names: CH-1, CH-2, CH-3, CH-4, CH-5, CH-6, CH-7, CH-8, x, y, z
#  chs: 11 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2019-05-22 17:19:39 UTC
#  nchan: 11
#  projs: []
#  sfreq: 500.0 Hz
# >
# <class 'numpy.ndarray'>
# (11, 28800000)
# 2019-05-22 17:19:39

# %%
# Loop trough the EEG files and extract data from sz_start to sz_end ==> place these in seperate data files.
sz_list = []

for info in xl_info_formatted:
    fileName = info[0]
    print("FILENAME: " + str(fileName))
    sz_start = info[3]
    sz_end = info[4]
    for dataobj in df_list:
        if(str(fileName) == str(dataobj[1])):
            print("DATAOBJ FILENAME: " + str(dataobj[1]))
            print('sz_start: ' + str(info[3]))
            print('sz_end: ' + str(info[4]))
            # insert only sz data into sz_list and insert non-sz data into non sz list
            sz = dataobj[0][(dataobj[0]['timestampMS'] >= sz_start) & (dataobj[0]['timestampMS'] <= sz_end)]
            sz_list.append([dataobj[1], "sz", sz])
            # only retain no-sz data in the original data
            dataobj[0] = dataobj[0][(dataobj[0]['timestampMS'] < sz_start) | (dataobj[0]['timestampMS'] > sz_end)]
        else:
           print("cannot split or find file")
# Out:
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558485892000.0
# sz_end: 1558486008000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558489819000.0
# sz_end: 1558489932000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558495646000.0
# sz_end: 1558495754000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558501594000.0
# sz_end: 1558501706000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558504254000.0
# sz_end: 1558504367000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# DATAOBJ FILENAME: 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558505592000.0
# sz_end: 1558505706000.0
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# DATAOBJ FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558508605000.0
# sz_end: 1558508719000.0
# cannot split or find file
# FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# DATAOBJ FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558510877000.0
# sz_end: 1558510997000.0
# cannot split or find file
# FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# cannot split or find file
# cannot split or find file
# cannot split or find file
# cannot split or find file
# DATAOBJ FILENAME: 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# sz_start: 1558513210000.0
# sz_end: 1558513343000.0
# cannot split or find file

# %%
print("------------------------SZ DATA-------------------")
for x in sz_list:
    print(x[0])
    print(len(x[2]))

    
print("-----------------NON SZ DATA---------------------")
for y in df_list:
    print(y[1])
    print(len(y[0]))
# Out:
# ------------------------SZ DATA-------------------
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 58001
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 56501
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 54001
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 56001
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 56501
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 57001
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 57001
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 60001
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 66501
# -----------------NON SZ DATA---------------------
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 32061994
# 20190520160924_p4nat1.sdeeg_converted_.easy_filtered.edf
# 32400000
# 20190521084849_p4dag2.sdeeg_converted_.easy_filtered.edf
# 12600000
# 20190520110039_p4dag1.sdeeg_converted_.easy_filtered.edf
# 9900500
# 20190522090132_p4dag3.sdeeg_converted_.easy_filtered.edf
# 3116997
# 20190522171939_p4nat3.sdeeg_converted_.easy_filtered.edf
# 28800000

# %% [markdown]
# # Result of splitting data into sz and non-sz dataframes

# %% [markdown]
# (before buffer) So now we have 28001 + 26501 + 24001 + 26001 + 26501 + 27001 = 158006 datapoints of seizure data and 32241994 + 32400000 + 12600000 + 9900500 + 3206997 + 28800000 = 119149491 data-points of non-seizure data

# %% [markdown]
# This means we have 0.13 % seizure datapoint out of the total datapoint

# %%
print(sz_list[5][0])
print(len(sz_list[5][2]))
exa = sz_list[5][2]
exa['CH-1'].plot(x = "timestampMS")
# Out:
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 57001
# <AxesSubplot:>

# %% [markdown]
# Weird spikes still in the original data.

# %%
print(df_list[0][1])
exa2 = df_list[0][0]
print(len(exa2))
exa2['CH-1'].plot()
# Out:
# 20190521155643_p4Nat2.sdeeg_converted_.easy_filtered.edf
# 32061994
# <AxesSubplot:>

# %% [markdown]
# # Balancing dataset

# %%
non_sz_p4_nat2 = df_list[0][0]
print(len(non_sz_p4_nat2))
non_sz_p4_nat2.head()
# Out:
# 32061994
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558447e+12  0.000017  0.000058  0.001171  0.001181 -0.000045 -0.000051
# 1  1.558447e+12  0.000011  0.000053  0.001170  0.001180 -0.000051 -0.000057
# 2  1.558447e+12  0.000036  0.000079  0.001169  0.001180 -0.000026 -0.000032
# 3  1.558447e+12  0.000038  0.000079  0.001168  0.001179 -0.000025 -0.000032
# 4  1.558447e+12  0.000064  0.000105  0.001167  0.001178  0.000003 -0.000005
#
#        CH-7      CH-8             x             y             z
# 0 -0.000065  0.000008  8.610537e-08  3.069114e-08  4.796582e-08
# 1 -0.000070  0.000003  8.610537e-08  3.069114e-08  4.796582e-08
# 2 -0.000045  0.000029  8.610537e-08  3.069114e-08  4.796582e-08
# 3 -0.000045  0.000029  8.610537e-08  3.069114e-08  4.796582e-08
# 4 -0.000017  0.000056  8.610537e-08  3.069114e-08  4.796582e-08

# %%
sz_p4_nat2 = pd.concat([sz_list[0][2], sz_list[1][2], sz_list[2][2], sz_list[3][2], sz_list[4][2], sz_list[5][2]]) 
print(len(sz_p4_nat2))
sz_p4_nat2
# Out:
# 338006
#            timestampMS      CH-1          CH-2      CH-3      CH-4      CH-5  \
# 19444500  1.558486e+12  0.000005  2.881900e-06  0.000011  0.000012  0.000011
# 19444501  1.558486e+12 -0.000023  3.990707e-07 -0.000085 -0.000084 -0.000085
# 19444502  1.558486e+12 -0.000042 -2.083758e-06 -0.000151 -0.000150 -0.000152
# 19444503  1.558486e+12 -0.000038 -4.566587e-06 -0.000132 -0.000132 -0.000134
# 19444504  1.558486e+12 -0.000026 -7.049416e-06 -0.000092 -0.000092 -0.000093
# ...                ...       ...           ...       ...       ...       ...
# 29351496  1.558506e+12  0.000016 -3.325173e-06  0.000058  0.000058  0.000059
# 29351497  1.558506e+12  0.000026 -2.083758e-06  0.000089  0.000088  0.000090
# 29351498  1.558506e+12  0.000023  3.990707e-07  0.000077  0.000078  0.000080
# 29351499  1.558506e+12  0.000012  2.881900e-06  0.000035  0.000036  0.000036
# 29351500  1.558506e+12  0.000001  5.364729e-06  0.000001  0.000001  0.000003
#
#               CH-6      CH-7      CH-8             x             y  \
# 19444500  0.000011  0.000011  0.000012 -1.594670e-07  3.111999e-07
# 19444501 -0.000084 -0.000084 -0.000083 -1.594670e-07  3.111999e-07
# 19444502 -0.000150 -0.000150 -0.000150 -1.594670e-07  1.936214e-07
# 19444503 -0.000132 -0.000133 -0.000133 -1.594670e-07  1.936214e-07
# 19444504 -0.000092 -0.000092 -0.000092 -1.594670e-07  1.936214e-07
# ...            ...       ...       ...           ...           ...
# 29351496  0.000060  0.000059  0.000060 -1.617910e-07  2.776061e-07
# 29351497  0.000090  0.000089  0.000090 -1.617910e-07  2.776061e-07
# 29351498  0.000080  0.000080  0.000081 -1.617910e-07  2.776061e-07
# 29351499  0.000038  0.000036  0.000037 -1.617910e-07  2.776061e-07
# 29351500  0.000005  0.000004  0.000003 -1.617910e-07  2.776061e-07
#
#                      z
# 19444500 -2.690678e-08
# 19444501 -2.690678e-08
# 19444502 -5.685582e-08
# 19444503 -5.685582e-08
# 19444504 -5.685582e-08
# ...                ...
# 29351496  1.340693e-07
# 29351497  1.340693e-07
# 29351498  1.340693e-07
# 29351499  1.340693e-07
# 29351500  1.340693e-07
#
# [338006 rows x 12 columns]

# %% [markdown]
# difference in %

# %%
(len(sz_p4_nat2) / len(non_sz_p4_nat2)) * 100
# Out:
# 1.0542263840483532

# %%
sz_p4_nat2.insert(1, "class", ["sz" for x in sz_p4_nat2.index])
sz_p4_nat2.head()
# Out:
#            timestampMS class      CH-1          CH-2      CH-3      CH-4  \
# 19444500  1.558486e+12    sz  0.000005  2.881900e-06  0.000011  0.000012
# 19444501  1.558486e+12    sz -0.000023  3.990707e-07 -0.000085 -0.000084
# 19444502  1.558486e+12    sz -0.000042 -2.083758e-06 -0.000151 -0.000150
# 19444503  1.558486e+12    sz -0.000038 -4.566587e-06 -0.000132 -0.000132
# 19444504  1.558486e+12    sz -0.000026 -7.049416e-06 -0.000092 -0.000092
#
#               CH-5      CH-6      CH-7      CH-8             x             y  \
# 19444500  0.000011  0.000011  0.000011  0.000012 -1.594670e-07  3.111999e-07
# 19444501 -0.000085 -0.000084 -0.000084 -0.000083 -1.594670e-07  3.111999e-07
# 19444502 -0.000152 -0.000150 -0.000150 -0.000150 -1.594670e-07  1.936214e-07
# 19444503 -0.000134 -0.000132 -0.000133 -0.000133 -1.594670e-07  1.936214e-07
# 19444504 -0.000093 -0.000092 -0.000092 -0.000092 -1.594670e-07  1.936214e-07
#
#                      z
# 19444500 -2.690678e-08
# 19444501 -2.690678e-08
# 19444502 -5.685582e-08
# 19444503 -5.685582e-08
# 19444504 -5.685582e-08

# %%
print(len(non_sz_p4_nat2) + len(sz_p4_nat2))
# Out:
# 32400000

# %%
p4_nat2_df = pd.concat([non_sz_p4_nat2, sz_p4_nat2])
p4_nat2_df['class'].value_counts()
# Out:
# sz    338006
# Name: class, dtype: int64

# %%
p4_nat2_df.shape
# Out:
# (32400000, 13)

# %%
p4_nat2_df.drop('x', inplace=True,  axis=1)
p4_nat2_df.drop('y', inplace=True,  axis=1)
p4_nat2_df.drop('z', inplace=True,  axis=1)

# %%
p4_nat2_df.head()
# Out:
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558447e+12  0.000017  0.000058  0.001171  0.001181 -0.000045 -0.000051
# 1  1.558447e+12  0.000011  0.000053  0.001170  0.001180 -0.000051 -0.000057
# 2  1.558447e+12  0.000036  0.000079  0.001169  0.001180 -0.000026 -0.000032
# 3  1.558447e+12  0.000038  0.000079  0.001168  0.001179 -0.000025 -0.000032
# 4  1.558447e+12  0.000064  0.000105  0.001167  0.001178  0.000003 -0.000005
#
#        CH-7      CH-8 class
# 0 -0.000065  0.000008   NaN
# 1 -0.000070  0.000003   NaN
# 2 -0.000045  0.000029   NaN
# 3 -0.000045  0.000029   NaN
# 4 -0.000017  0.000056   NaN

# %%
p4_nat2_df['class'] = p4_nat2_df['class'].replace(np.nan, 'non-sz')
p4_nat2_df.head()
# Out:
#     timestampMS      CH-1      CH-2      CH-3      CH-4      CH-5      CH-6  \
# 0  1.558447e+12  0.000017  0.000058  0.001171  0.001181 -0.000045 -0.000051
# 1  1.558447e+12  0.000011  0.000053  0.001170  0.001180 -0.000051 -0.000057
# 2  1.558447e+12  0.000036  0.000079  0.001169  0.001180 -0.000026 -0.000032
# 3  1.558447e+12  0.000038  0.000079  0.001168  0.001179 -0.000025 -0.000032
# 4  1.558447e+12  0.000064  0.000105  0.001167  0.001178  0.000003 -0.000005
#
#        CH-7      CH-8   class
# 0 -0.000065  0.000008  non-sz
# 1 -0.000070  0.000003  non-sz
# 2 -0.000045  0.000029  non-sz
# 3 -0.000045  0.000029  non-sz
# 4 -0.000017  0.000056  non-sz

# %%
p4_nat2_df['class'].value_counts()
# Out:
# non-sz    32061994
# sz          338006
# Name: class, dtype: int64

# %% [markdown]
# # Create EEG's

# %%
def get_window(start_index, data, size = 4, overlap = 0, is_sezure = False, frequency = 500):
    if(is_sezure):
        overlap = 2
    else:
        overlap = overlap
    
    
    start = start_index * (size - overlap) * frequency
    end = start + (size * frequency)
    print("is_sezure: " + str(is_sezure) + " date: " + str(datetime.fromtimestamp((data['timestampMS'][start:start+1]/1000).tolist()[0])) + str(' lenthWindow: '+ str(len(data['CH-1'][start:end].tolist()))) + ' start: ' + str(start) + " end: " + str(end) )

    return [data['CH-1'][start:end].tolist(), datetime.fromtimestamp((data['timestampMS'][start:start+1]/1000).tolist()[0])]

# %%
sz = p4_nat2_df.loc[p4_nat2_df['class'] == 'sz']
nsz = p4_nat2_df.loc[p4_nat2_df['class'] == 'non-sz']

# %%
nosz_len = int(len(nsz) / (4*500))

# %%
sz_len = int(len(sz) / (2*500))

# %%
nsz_win = [get_window(start_index=i, data=nsz) for i in range(nosz_len)]
sz_win = [get_window(start_index=i, data=nsz, is_sezure=True) for i in range(sz_len)]
# Out:
# is_sezure: False date: 2019-05-21 15:56:43 lenthWindow: 2000 start: 0 end: 2000
# is_sezure: False date: 2019-05-21 15:56:47 lenthWindow: 2000 start: 2000 end: 4000
# is_sezure: False date: 2019-05-21 15:56:51 lenthWindow: 2000 start: 4000 end: 6000
# is_sezure: False date: 2019-05-21 15:56:55 lenthWindow: 2000 start: 6000 end: 8000
# is_sezure: False date: 2019-05-21 15:56:59 lenthWindow: 2000 start: 8000 end: 10000
# is_sezure: False date: 2019-05-21 15:57:03 lenthWindow: 2000 start: 10000 end: 12000
# is_sezure: False date: 2019-05-21 15:57:07 lenthWindow: 2000 start: 12000 end: 14000
# is_sezure: False date: 2019-05-21 15:57:11 lenthWindow: 2000 start: 14000 end: 16000
# is_sezure: False date: 2019-05-21 15:57:15 lenthWindow: 2000 start: 16000 end: 18000
# is_sezure: False date: 2019-05-21 15:57:19 lenthWindow: 2000 start: 18000 end: 20000
# is_sezure: False date: 2019-05-21 15:57:23 lenthWindow: 2000 start: 20000 end: 22000
# is_sezure: False date: 2019-05-21 15:57:27 lenthWindow: 2000 start: 22000 end: 24000
# is_sezure: False date: 2019-05-21 15:57:31 lenthWindow: 2000 start: 24000 end: 26000
# is_sezure: False date: 2019-05-21 15:57:35 lenthWindow: 2000 start: 26000 end: 28000
# is_sezure: False date: 2019-05-21 15:57:39 lenthWindow: 2000 start: 28000 end: 30000
# is_sezure: False date: 2019-05-21 15:57:43 lenthWindow: 2000 start: 30000 end: 32000
# is_sezure: False date: 2019-05-21 15:57:47 lenthWindow: 2000 start: 32000 end: 34000
# is_sezure: False date: 2019-05-21 15:57:51 lenthWindow: 2000 start: 34000 end: 36000
# is_sezure: False date: 2019-05-21 15:57:55 lenthWindow: 2000 start: 36000 end: 38000
# is_sezure: False date: 2019-05-21 15:57:59 lenthWindow: 2000 start: 38000 end: 40000
# is_sezure: False date: 2019-05-21 15:58:03 lenthWindow: 2000 start: 40000 end: 42000
# is_sezure: False date: 2019-05-21 15:58:07 lenthWindow: 2000 start: 42000 end: 44000
# is_sezure: False date: 2019-05-21 15:58:11 lenthWindow: 2000 start: 44000 end: 46000
# is_sezure: False date: 2019-05-21 15:58:15 lenthWindow: 2000 start: 46000 end: 48000
# is_sezure: False date: 2019-05-21 15:58:19 lenthWindow: 2000 start: 48000 end: 50000
# is_sezure: False date: 2019-05-21 15:58:23 lenthWindow: 2000 start: 50000 end: 52000
# is_sezure: False date: 2019-05-21 15:58:27 lenthWindow: 2000 start: 52000 end: 54000
# is_sezure: False date: 2019-05-21 15:58:31 lenthWindow: 2000 start: 54000 end: 56000
# is_sezure: False date: 2019-05-21 15:58:35 lenthWindow: 2000 start: 56000 end: 58000
# is_sezure: False date: 2019-05-21 15:58:39 lenthWindow: 2000 start: 58000 end: 60000
# is_sezure: False date: 2019-05-21 15:58:43 lenthWindow: 2000 start: 60000 end: 62000
# is_sezure: False date: 2019-05-21 15:58:47 lenthWindow: 2000 start: 62000 end: 64000
# is_sezure: False date: 2019-05-21 15:58:51 lenthWindow: 2000 start: 64000 end: 66000
# is_sezure: False date: 2019-05-21 15:58:55 lenthWindow: 2000 start: 66000 end: 68000
# is_sezure: False date: 2019-05-21 15:58:59 lenthWindow: 2000 start: 68000 end: 70000
# is_sezure: False date: 2019-05-21 15:59:03 lenthWindow: 2000 start: 70000 end: 72000
# is_sezure: False date: 2019-05-21 15:59:07 lenthWindow: 2000 start: 72000 end: 74000
# is_sezure: False date: 2019-05-21 15:59:11 lenthWindow: 2000 start: 74000 end: 76000
# is_sezure: False date: 2019-05-21 15:59:15 lenthWindow: 2000 start: 76000 end: 78000
# is_sezure: False date: 2019-05-21 15:59:19 lenthWindow: 2000 start: 78000 end: 80000
# is_sezure: False date: 2019-05-21 15:59:23 lenthWindow: 2000 start: 80000 end: 82000
# is_sezure: False date: 2019-05-21 15:59:27 lenthWindow: 2000 start: 82000 end: 84000
# is_sezure: False date: 2019-05-21 15:59:31 lenthWindow: 2000 start: 84000 end: 86000
# is_sezure: False date: 2019-05-21 15:59:35 lenthWindow: 2000 start: 86000 end: 88000
# is_sezure: False date: 2019-05-21 15:59:39 lenthWindow: 2000 start: 88000 end: 90000
# is_sezure: False date: 2019-05-21 15:59:43 lenthWindow: 2000 start: 90000 end: 92000
# is_sezure: False date: 2019-05-21 15:59:47 lenthWindow: 2000 start: 92000 end: 94000
# is_sezure: False date: 2019-05-21 15:59:51 lenthWindow: 2000 start: 94000 end: 96000
# is_sezure: False date: 2019-05-21 15:59:55 lenthWindow: 2000 start: 96000 end: 98000
# is_sezure: False date: 2019-05-21 15:59:59 lenthWindow: 2000 start: 98000 end: 100000
# is_sezure: False date: 2019-05-21 16:00:03 lenthWindow: 2000 start: 100000 end: 102000
# is_sezure: False date: 2019-05-21 16:00:07 lenthWindow: 2000 start: 102000 end: 104000
# is_sezure: False date: 2019-05-21 16:00:11 lenthWindow: 2000 start: 104000 end: 106000
# is_sezure: False date: 2019-05-21 16:00:15 lenthWindow: 2000 start: 106000 end: 108000
# is_sezure: False date: 2019-05-21 16:00:19 lenthWindow: 2000 start: 108000 end: 110000
# is_sezure: False date: 2019-05-21 16:00:23 lenthWindow: 2000 start: 110000 end: 112000
# is_sezure: False date: 2019-05-21 16:00:27 lenthWindow: 2000 start: 112000 end: 114000
# is_sezure: False date: 2019-05-21 16:00:31 lenthWindow: 2000 start: 114000 end: 116000
# is_sezure: False date: 2019-05-21 16:00:35 lenthWindow: 2000 start: 116000 end: 118000
# is_sezure: False date: 2019-05-21 16:00:39 lenthWindow: 2000 start: 118000 end: 120000
# is_sezure: False date: 2019-05-21 16:00:43 lenthWindow: 2000 start: 120000 end: 122000
# is_sezure: False date: 2019-05-21 16:00:47 lenthWindow: 2000 start: 122000 end: 124000
# is_sezure: False date: 2019-05-21 16:00:51 lenthWindow: 2000 start: 124000 end: 126000
# is_sezure: False date: 2019-05-21 16:00:55 lenthWindow: 2000 start: 126000 end: 128000
# is_sezure: False date: 2019-05-21 16:00:59 lenthWindow: 2000 start: 128000 end: 130000
# is_sezure: False date: 2019-05-21 16:01:03 lenthWindow: 2000 start: 130000 end: 132000
# is_sezure: False date: 2019-05-21 16:01:07 lenthWindow: 2000 start: 132000 end: 134000
# is_sezure: False date: 2019-05-21 16:01:11 lenthWindow: 2000 start: 134000 end: 136000
# is_sezure: False date: 2019-05-21 16:01:15 lenthWindow: 2000 start: 136000 end: 138000
# is_sezure: False date: 2019-05-21 16:01:19 lenthWindow: 2000 start: 138000 end: 140000
# is_sezure: False date: 2019-05-21 16:01:23 lenthWindow: 2000 start: 140000 end: 142000
# is_sezure: False date: 2019-05-21 16:01:27 lenthWindow: 2000 start: 142000 end: 144000
# is_sezure: False date: 2019-05-21 16:01:31 lenthWindow: 2000 start: 144000 end: 146000
# is_sezure: False date: 2019-05-21 16:01:35 lenthWindow: 2000 start: 146000 end: 148000
# is_sezure: False date: 2019-05-21 16:01:39 lenthWindow: 2000 start: 148000 end: 150000
# is_sezure: False date: 2019-05-21 16:01:43 lenthWindow: 2000 start: 150000 end: 152000
# is_sezure: False date: 2019-05-21 16:01:47 lenthWindow: 2000 start: 152000 end: 154000
# is_sezure: False date: 2019-05-21 16:01:51 lenthWindow: 2000 start: 154000 end: 156000
# is_sezure: False date: 2019-05-21 16:01:55 lenthWindow: 2000 start: 156000 end: 158000
# is_sezure: False date: 2019-05-21 16:01:59 lenthWindow: 2000 start: 158000 end: 160000
# is_sezure: False date: 2019-05-21 16:02:03 lenthWindow: 2000 start: 160000 end: 162000
# is_sezure: False date: 2019-05-21 16:02:07 lenthWindow: 2000 start: 162000 end: 164000
# is_sezure: False date: 2019-05-21 16:02:11 lenthWindow: 2000 start: 164000 end: 166000
# is_sezure: False date: 2019-05-21 16:02:15 lenthWindow: 2000 start: 166000 end: 168000
# is_sezure: False date: 2019-05-21 16:02:19 lenthWindow: 2000 start: 168000 end: 170000
# is_sezure: False date: 2019-05-21 16:02:23 lenthWindow: 2000 start: 170000 end: 172000
# is_sezure: False date: 2019-05-21 16:02:27 lenthWindow: 2000 start: 172000 end: 174000
# is_sezure: False date: 2019-05-21 16:02:31 lenthWindow: 2000 start: 174000 end: 176000
# is_sezure: False date: 2019-05-21 16:02:35 lenthWindow: 2000 start: 176000 end: 178000
# is_sezure: False date: 2019-05-21 16:02:39 lenthWindow: 2000 start: 178000 end: 180000
# is_sezure: False date: 2019-05-21 16:02:43 lenthWindow: 2000 start: 180000 end: 182000
# is_sezure: False date: 2019-05-21 16:02:47 lenthWindow: 2000 start: 182000 end: 184000
# is_sezure: False date: 2019-05-21 16:02:51 lenthWindow: 2000 start: 184000 end: 186000
# is_sezure: False date: 2019-05-21 16:02:55 lenthWindow: 2000 start: 186000 end: 188000
# is_sezure: False date: 2019-05-21 16:02:59 lenthWindow: 2000 start: 188000 end: 190000
# is_sezure: False date: 2019-05-21 16:03:03 lenthWindow: 2000 start: 190000 end: 192000
# is_sezure: False date: 2019-05-21 16:03:07 lenthWindow: 2000 start: 192000 end: 194000
# is_sezure: False date: 2019-05-21 16:03:11 lenthWindow: 2000 start: 194000 end: 196000
# is_sezure: False date: 2019-05-21 16:03:15 lenthWindow: 2000 start: 196000 end: 198000
# is_sezure: False date: 2019-05-21 16:03:19 lenthWindow: 2000 start: 198000 end: 200000
# is_sezure: False date: 2019-05-21 16:03:23 lenthWindow: 2000 start: 200000 end: 202000
# is_sezure: False date: 2019-05-21 16:03:27 lenthWindow: 2000 start: 202000 end: 204000
# is_sezure: False date: 2019-05-21 16:03:31 lenthWindow: 2000 start: 204000 end: 206000
# is_sezure: False date: 2019-05-21 16:03:35 lenthWindow: 2000 start: 206000 end: 208000
# is_sezure: False date: 2019-05-21 16:03:39 lenthWindow: 2000 start: 208000 end: 210000
# is_sezure: False date: 2019-05-21 16:03:43 lenthWindow: 2000 start: 210000 end: 212000
# is_sezure: False date: 2019-05-21 16:03:47 lenthWindow: 2000 start: 212000 end: 214000
# is_sezure: False date: 2019-05-21 16:03:51 lenthWindow: 2000 start: 214000 end: 216000
# is_sezure: False date: 2019-05-21 16:03:55 lenthWindow: 2000 start: 216000 end: 218000
# is_sezure: False date: 2019-05-21 16:03:59 lenthWindow: 2000 start: 218000 end: 220000
# is_sezure: False date: 2019-05-21 16:04:03 lenthWindow: 2000 start: 220000 end: 222000
# is_sezure: False date: 2019-05-21 16:04:07 lenthWindow: 2000 start: 222000 end: 224000
# is_sezure: False date: 2019-05-21 16:04:11 lenthWindow: 2000 start: 224000 end: 226000
# is_sezure: False date: 2019-05-21 16:04:15 lenthWindow: 2000 start: 226000 end: 228000
# is_sezure: False date: 2019-05-21 16:04:19 lenthWindow: 2000 start: 228000 end: 230000
# is_sezure: False date: 2019-05-21 16:04:23 lenthWindow: 2000 start: 230000 end: 232000
# is_sezure: False date: 2019-05-21 16:04:27 lenthWindow: 2000 start: 232000 end: 234000
# is_sezure: False date: 2019-05-21 16:04:31 lenthWindow: 2000 start: 234000 end: 236000
# is_sezure: False date: 2019-05-21 16:04:35 lenthWindow: 2000 start: 236000 end: 238000
# is_sezure: False date: 2019-05-21 16:04:39 lenthWindow: 2000 start: 238000 end: 240000
# is_sezure: False date: 2019-05-21 16:04:43 lenthWindow: 2000 start: 240000 end: 242000
# is_sezure: False date: 2019-05-21 16:04:47 lenthWindow: 2000 start: 242000 end: 244000
# is_sezure: False date: 2019-05-21 16:04:51 lenthWindow: 2000 start: 244000 end: 246000
# is_sezure: False date: 2019-05-21 16:04:55 lenthWindow: 2000 start: 246000 end: 248000
# is_sezure: False date: 2019-05-21 16:04:59 lenthWindow: 2000 start: 248000 end: 250000
# is_sezure: False date: 2019-05-21 16:05:03 lenthWindow: 2000 start: 250000 end: 252000
# is_sezure: False date: 2019-05-21 16:05:07 lenthWindow: 2000 start: 252000 end: 254000
# is_sezure: False date: 2019-05-21 16:05:11 lenthWindow: 2000 start: 254000 end: 256000
# is_sezure: False date: 2019-05-21 16:05:15 lenthWindow: 2000 start: 256000 end: 258000
# is_sezure: False date: 2019-05-21 16:05:19 lenthWindow: 2000 start: 258000 end: 260000
# is_sezure: False date: 2019-05-21 16:05:23 lenthWindow: 2000 start: 260000 end: 262000
# is_sezure: False date: 2019-05-21 16:05:27 lenthWindow: 2000 start: 262000 end: 264000
# is_sezure: False date: 2019-05-21 16:05:31 lenthWindow: 2000 start: 264000 end: 266000
# is_sezure: False date: 2019-05-21 16:05:35 lenthWindow: 2000 start: 266000 end: 268000
# is_sezure: False date: 2019-05-21 16:05:39 lenthWindow: 2000 start: 268000 end: 270000
# is_sezure: False date: 2019-05-21 16:05:43 lenthWindow: 2000 start: 270000 end: 272000
# is_sezure: False date: 2019-05-21 16:05:47 lenthWindow: 2000 start: 272000 end: 274000
# is_sezure: False date: 2019-05-21 16:05:51 lenthWindow: 2000 start: 274000 end: 276000
# is_sezure: False date: 2019-05-21 16:05:55 lenthWindow: 2000 start: 276000 end: 278000
# is_sezure: False date: 2019-05-21 16:05:59 lenthWindow: 2000 start: 278000 end: 280000
# is_sezure: False date: 2019-05-21 16:06:03 lenthWindow: 2000 start: 280000 end: 282000
# is_sezure: False date: 2019-05-21 16:06:07 lenthWindow: 2000 start: 282000 end: 284000
# is_sezure: False date: 2019-05-21 16:06:11 lenthWindow: 2000 start: 284000 end: 286000
# is_sezure: False date: 2019-05-21 16:06:15 lenthWindow: 2000 start: 286000 end: 288000
# is_sezure: False date: 2019-05-21 16:06:19 lenthWindow: 2000 start: 288000 end: 290000
# is_sezure: False date: 2019-05-21 16:06:23 lenthWindow: 2000 start: 290000 end: 292000
# is_sezure: False date: 2019-05-21 16:06:27 lenthWindow: 2000 start: 292000 end: 294000
# is_sezure: False date: 2019-05-21 16:06:31 lenthWindow: 2000 start: 294000 end: 296000
# is_sezure: False date: 2019-05-21 16:06:35 lenthWindow: 2000 start: 296000 end: 298000
# is_sezure: False date: 2019-05-21 16:06:39 lenthWindow: 2000 start: 298000 end: 300000
# is_sezure: False date: 2019-05-21 16:06:43 lenthWindow: 2000 start: 300000 end: 302000
# is_sezure: False date: 2019-05-21 16:06:47 lenthWindow: 2000 start: 302000 end: 304000
# is_sezure: False date: 2019-05-21 16:06:51 lenthWindow: 2000 start: 304000 end: 306000
# is_sezure: False date: 2019-05-21 16:06:55 lenthWindow: 2000 start: 306000 end: 308000
# is_sezure: False date: 2019-05-21 16:06:59 lenthWindow: 2000 start: 308000 end: 310000
# is_sezure: False date: 2019-05-21 16:07:03 lenthWindow: 2000 start: 310000 end: 312000
# is_sezure: False date: 2019-05-21 16:07:07 lenthWindow: 2000 start: 312000 end: 314000
# is_sezure: False date: 2019-05-21 16:07:11 lenthWindow: 2000 start: 314000 end: 316000
# is_sezure: False date: 2019-05-21 16:07:15 lenthWindow: 2000 start: 316000 end: 318000
# is_sezure: False date: 2019-05-21 16:07:19 lenthWindow: 2000 start: 318000 end: 320000
# is_sezure: False date: 2019-05-21 16:07:23 lenthWindow: 2000 start: 320000 end: 322000
# is_sezure: False date: 2019-05-21 16:07:27 lenthWindow: 2000 start: 322000 end: 324000
# is_sezure: False date: 2019-05-21 16:07:31 lenthWindow: 2000 start: 324000 end: 326000
# is_sezure: False date: 2019-05-21 16:07:35 lenthWindow: 2000 start: 326000 end: 328000
# is_sezure: False date: 2019-05-21 16:07:39 lenthWindow: 2000 start: 328000 end: 330000
# is_sezure: False date: 2019-05-21 16:07:43 lenthWindow: 2000 start: 330000 end: 332000
# is_sezure: False date: 2019-05-21 16:07:47 lenthWindow: 2000 start: 332000 end: 334000
# is_sezure: False date: 2019-05-21 16:10:03 lenthWindow: 2000 start: 400000 end: 402000
# is_sezure: False date: 2019-05-21 16:10:07 lenthWindow: 2000 start: 402000 end: 404000
# is_sezure: False date: 2019-05-21 16:10:11 lenthWindow: 2000 start: 404000 end: 406000
# is_sezure: False date: 2019-05-21 16:10:15 lenthWindow: 2000 start: 406000 end: 408000
# is_sezure: False date: 2019-05-21 16:10:19 lenthWindow: 2000 start: 408000 end: 410000
# is_sezure: False date: 2019-05-21 16:10:23 lenthWindow: 2000 start: 410000 end: 412000
# is_sezure: False date: 2019-05-21 16:10:27 lenthWindow: 2000 start: 412000 end: 414000
# is_sezure: False date: 2019-05-21 16:10:31 lenthWindow: 2000 start: 414000 end: 416000
# is_sezure: False date: 2019-05-21 16:10:35 lenthWindow: 2000 start: 416000 end: 418000
# is_sezure: False date: 2019-05-21 16:10:39 lenthWindow: 2000 start: 418000 end: 420000
# is_sezure: False date: 2019-05-21 16:10:43 lenthWindow: 2000 start: 420000 end: 422000
# is_sezure: False date: 2019-05-21 16:10:47 lenthWindow: 2000 start: 422000 end: 424000
# is_sezure: False date: 2019-05-21 16:10:51 lenthWindow: 2000 start: 424000 end: 426000
# is_sezure: False date: 2019-05-21 16:10:55 lenthWindow: 2000 start: 426000 end: 428000
# is_sezure: False date: 2019-05-21 16:10:59 lenthWindow: 2000 start: 428000 end: 430000
# is_sezure: False date: 2019-05-21 16:11:03 lenthWindow: 2000 start: 430000 end: 432000
# is_sezure: False date: 2019-05-21 16:11:07 lenthWindow: 2000 start: 432000 end: 434000
# is_sezure: False date: 2019-05-21 16:11:11 lenthWindow: 2000 start: 434000 end: 436000
# is_sezure: False date: 2019-05-21 16:11:15 lenthWindow: 2000 start: 436000 end: 438000
# is_sezure: False date: 2019-05-21 16:11:19 lenthWindow: 2000 start: 438000 end: 440000
# is_sezure: False date: 2019-05-21 16:11:23 lenthWindow: 2000 start: 440000 end: 442000
# is_sezure: False date: 2019-05-21 16:11:27 lenthWindow: 2000 start: 442000 end: 444000
# is_sezure: False date: 2019-05-21 16:11:31 lenthWindow: 2000 start: 444000 end: 446000
# is_sezure: False date: 2019-05-21 16:11:35 lenthWindow: 2000 start: 446000 end: 448000
# is_sezure: False date: 2019-05-21 16:11:39 lenthWindow: 2000 start: 448000 end: 450000
# is_sezure: False date: 2019-05-21 16:11:43 lenthWindow: 2000 start: 450000 end: 452000
# is_sezure: False date: 2019-05-21 16:11:47 lenthWindow: 2000 start: 452000 end: 454000
# is_sezure: False date: 2019-05-21 16:11:51 lenthWindow: 2000 start: 454000 end: 456000
# is_sezure: False date: 2019-05-21 16:11:55 lenthWindow: 2000 start: 456000 end: 458000
# is_sezure: False date: 2019-05-21 16:11:59 lenthWindow: 2000 start: 458000 end: 460000
# is_sezure: False date: 2019-05-21 16:12:03 lenthWindow: 2000 start: 460000 end: 462000
# is_sezure: False date: 2019-05-21 16:12:07 lenthWindow: 2000 start: 462000 end: 464000
# is_sezure: False date: 2019-05-21 16:14:23 lenthWindow: 2000 start: 530000 end: 532000
# is_sezure: False date: 2019-05-21 16:14:27 lenthWindow: 2000 start: 532000 end: 534000
# is_sezure: False date: 2019-05-21 16:14:31 lenthWindow: 2000 start: 534000 end: 536000
# is_sezure: False date: 2019-05-21 16:14:35 lenthWindow: 2000 start: 536000 end: 538000
# is_sezure: False date: 2019-05-21 16:14:39 lenthWindow: 2000 start: 538000 end: 540000
# is_sezure: False date: 2019-05-21 16:14:43 lenthWindow: 2000 start: 540000 end: 542000
# is_sezure: False date: 2019-05-21 16:14:47 lenthWindow: 2000 start: 542000 end: 544000
# is_sezure: False date: 2019-05-21 16:14:51 lenthWindow: 2000 start: 544000 end: 546000
# is_sezure: False date: 2019-05-21 16:14:55 lenthWindow: 2000 start: 546000 end: 548000
# is_sezure: False date: 2019-05-21 16:14:59 lenthWindow: 2000 start: 548000 end: 550000
# is_sezure: False date: 2019-05-21 16:15:03 lenthWindow: 2000 start: 550000 end: 552000
# is_sezure: False date: 2019-05-21 16:15:07 lenthWindow: 2000 start: 552000 end: 554000
# is_sezure: False date: 2019-05-21 16:15:11 lenthWindow: 2000 start: 554000 end: 556000
# is_sezure: False date: 2019-05-21 16:15:15 lenthWindow: 2000 start: 556000 end: 558000
# is_sezure: False date: 2019-05-21 16:15:19 lenthWindow: 2000 start: 558000 end: 560000
# is_sezure: False date: 2019-05-21 16:15:23 lenthWindow: 2000 start: 560000 end: 562000
# is_sezure: False date: 2019-05-21 16:15:27 lenthWindow: 2000 start: 562000 end: 564000
# is_sezure: False date: 2019-05-21 16:15:31 lenthWindow: 2000 start: 564000 end: 566000
# is_sezure: False date: 2019-05-21 16:15:35 lenthWindow: 2000 start: 566000 end: 568000
# is_sezure: False date: 2019-05-21 16:15:39 lenthWindow: 2000 start: 568000 end: 570000
# is_sezure: False date: 2019-05-21 16:15:43 lenthWindow: 2000 start: 570000 end: 572000
# is_sezure: False date: 2019-05-21 16:15:47 lenthWindow: 2000 start: 572000 end: 574000
# is_sezure: False date: 2019-05-21 16:15:51 lenthWindow: 2000 start: 574000 end: 576000
# is_sezure: False date: 2019-05-21 16:15:55 lenthWindow: 2000 start: 576000 end: 578000
# is_sezure: False date: 2019-05-21 16:15:59 lenthWindow: 2000 start: 578000 end: 580000
# is_sezure: False date: 2019-05-21 16:16:03 lenthWindow: 2000 start: 580000 end: 582000
# is_sezure: False date: 2019-05-21 16:16:07 lenthWindow: 2000 start: 582000 end: 584000
# is_sezure: False date: 2019-05-21 16:16:11 lenthWindow: 2000 start: 584000 end: 586000
# is_sezure: False date: 2019-05-21 16:16:15 lenthWindow: 2000 start: 586000 end: 588000
# is_sezure: False date: 2019-05-21 16:16:19 lenthWindow: 2000 start: 588000 end: 590000
# is_sezure: False date: 2019-05-21 16:16:23 lenthWindow: 2000 start: 590000 end: 592000
# is_sezure: False date: 2019-05-21 16:16:27 lenthWindow: 2000 start: 592000 end: 594000
# is_sezure: False date: 2019-05-21 16:16:31 lenthWindow: 2000 start: 594000 end: 596000
# is_sezure: False date: 2019-05-21 16:16:35 lenthWindow: 2000 start: 596000 end: 598000
# is_sezure: False date: 2019-05-21 16:16:39 lenthWindow: 2000 start: 598000 end: 600000
# is_sezure: False date: 2019-05-21 16:16:43 lenthWindow: 2000 start: 600000 end: 602000
# is_sezure: False date: 2019-05-21 16:16:47 lenthWindow: 2000 start: 602000 end: 604000
# is_sezure: False date: 2019-05-21 16:16:51 lenthWindow: 2000 start: 604000 end: 606000
# is_sezure: False date: 2019-05-21 16:16:55 lenthWindow: 2000 start: 606000 end: 608000
# is_sezure: False date: 2019-05-21 16:16:59 lenthWindow: 2000 start: 608000 end: 610000
# is_sezure: False date: 2019-05-21 16:17:03 lenthWindow: 2000 start: 610000 end: 612000
# is_sezure: False date: 2019-05-21 16:17:07 lenthWindow: 2000 start: 612000 end: 614000
# is_sezure: False date: 2019-05-21 16:17:11 lenthWindow: 2000 start: 614000 end: 616000
# is_sezure: False date: 2019-05-21 16:17:15 lenthWindow: 2000 start: 616000 end: 618000
# is_sezure: False date: 2019-05-21 16:17:19 lenthWindow: 2000 start: 618000 end: 620000
# is_sezure: False date: 2019-05-21 16:17:23 lenthWindow: 2000 start: 620000 end: 622000
# is_sezure: False date: 2019-05-21 16:17:27 lenthWindow: 2000 start: 622000 end: 624000
# is_sezure: False date: 2019-05-21 16:17:31 lenthWindow: 2000 start: 624000 end: 626000
# is_sezure: False date: 2019-05-21 16:17:35 lenthWindow: 2000 start: 626000 end: 628000
# is_sezure: False date: 2019-05-21 16:17:39 lenthWindow: 2000 start: 628000 end: 630000
# is_sezure: False date: 2019-05-21 16:17:43 lenthWindow: 2000 start: 630000 end: 632000
# is_sezure: False date: 2019-05-21 16:17:47 lenthWindow: 2000 start: 632000 end: 634000
# is_sezure: False date: 2019-05-21 16:17:51 lenthWindow: 2000 start: 634000 end: 636000
# is_sezure: False date: 2019-05-21 16:17:55 lenthWindow: 2000 start: 636000 end: 638000
# is_sezure: False date: 2019-05-21 16:17:59 lenthWindow: 2000 start: 638000 end: 640000
# is_sezure: False date: 2019-05-21 16:18:03 lenthWindow: 2000 start: 640000 end: 642000
# is_sezure: False date: 2019-05-21 16:18:07 lenthWindow: 2000 start: 642000 end: 644000
# is_sezure: False date: 2019-05-21 16:18:11 lenthWindow: 2000 start: 644000 end: 646000
# is_sezure: False date: 2019-05-21 16:18:15 lenthWindow: 2000 start: 646000 end: 648000
# is_sezure: False date: 2019-05-21 16:18:19 lenthWindow: 2000 start: 648000 end: 650000
# is_sezure: False date: 2019-05-21 16:18:23 lenthWindow: 2000 start: 650000 end: 652000
# is_sezure: False date: 2019-05-21 16:18:27 lenthWindow: 2000 start: 652000 end: 654000
# is_sezure: False date: 2019-05-21 16:18:31 lenthWindow: 2000 start: 654000 end: 656000
# is_sezure: False date: 2019-05-21 16:18:35 lenthWindow: 2000 start: 656000 end: 658000
# is_sezure: False date: 2019-05-21 16:18:39 lenthWindow: 2000 start: 658000 end: 660000
# is_sezure: False date: 2019-05-21 16:18:43 lenthWindow: 2000 start: 660000 end: 662000
# is_sezure: False date: 2019-05-21 16:18:47 lenthWindow: 2000 start: 662000 end: 664000
# is_sezure: False date: 2019-05-21 16:18:51 lenthWindow: 2000 start: 664000 end: 666000
# is_sezure: False date: 2019-05-21 16:18:55 lenthWindow: 2000 start: 666000 end: 668000
# is_sezure: False date: 2019-05-21 16:18:59 lenthWindow: 2000 start: 668000 end: 670000
# is_sezure: False date: 2019-05-21 16:19:03 lenthWindow: 2000 start: 670000 end: 672000
# is_sezure: False date: 2019-05-21 16:19:07 lenthWindow: 2000 start: 672000 end: 674000
# is_sezure: False date: 2019-05-21 16:19:11 lenthWindow: 2000 start: 674000 end: 676000
# is_sezure: False date: 2019-05-21 16:19:15 lenthWindow: 2000 start: 676000 end: 678000
# is_sezure: False date: 2019-05-21 16:19:19 lenthWindow: 2000 start: 678000 end: 680000
# is_sezure: False date: 2019-05-21 16:19:23 lenthWindow: 2000 start: 680000 end: 682000
# is_sezure: False date: 2019-05-21 16:19:27 lenthWindow: 2000 start: 682000 end: 684000
# is_sezure: False date: 2019-05-21 16:19:31 lenthWindow: 2000 start: 684000 end: 686000
# is_sezure: False date: 2019-05-21 16:19:35 lenthWindow: 2000 start: 686000 end: 688000
# is_sezure: False date: 2019-05-21 16:19:39 lenthWindow: 2000 start: 688000 end: 690000
# is_sezure: False date: 2019-05-21 16:19:43 lenthWindow: 2000 start: 690000 end: 692000
# is_sezure: False date: 2019-05-21 16:19:47 lenthWindow: 2000 start: 692000 end: 694000
# is_sezure: False date: 2019-05-21 16:19:51 lenthWindow: 2000 start: 694000 end: 696000
# is_sezure: False date: 2019-05-21 16:19:55 lenthWindow: 2000 start: 696000 end: 698000
# is_sezure: False date: 2019-05-21 16:19:59 lenthWindow: 2000 start: 698000 end: 700000
# is_sezure: False date: 2019-05-21 16:20:03 lenthWindow: 2000 start: 700000 end: 702000
# is_sezure: False date: 2019-05-21 16:20:07 lenthWindow: 2000 start: 702000 end: 704000
# is_sezure: False date: 2019-05-21 16:20:11 lenthWindow: 2000 start: 704000 end: 706000
# is_sezure: False date: 2019-05-21 16:20:15 lenthWindow: 2000 start: 706000 end: 708000
# is_sezure: False date: 2019-05-21 16:20:19 lenthWindow: 2000 start: 708000 end: 710000
# is_sezure: False date: 2019-05-21 16:20:23 lenthWindow: 2000 start: 710000 end: 712000
# is_sezure: False date: 2019-05-21 16:20:27 lenthWindow: 2000 start: 712000 end: 714000
# is_sezure: False date: 2019-05-21 16:20:31 lenthWindow: 2000 start: 714000 end: 716000
# is_sezure: False date: 2019-05-21 16:20:35 lenthWindow: 2000 start: 716000 end: 718000
# is_sezure: False date: 2019-05-21 16:20:39 lenthWindow: 2000 start: 718000 end: 720000
# is_sezure: False date: 2019-05-21 16:20:43 lenthWindow: 2000 start: 720000 end: 722000
# is_sezure: False date: 2019-05-21 16:20:47 lenthWindow: 2000 start: 722000 end: 724000
# is_sezure: False date: 2019-05-21 16:20:51 lenthWindow: 2000 start: 724000 end: 726000
# is_sezure: False date: 2019-05-21 16:20:55 lenthWindow: 2000 start: 726000 end: 728000
# is_sezure: False date: 2019-05-21 16:20:59 lenthWindow: 2000 start: 728000 end: 730000
# is_sezure: False date: 2019-05-21 16:21:03 lenthWindow: 2000 start: 730000 end: 732000
# is_sezure: False date: 2019-05-21 16:21:07 lenthWindow: 2000 start: 732000 end: 734000
# is_sezure: False date: 2019-05-21 16:21:11 lenthWindow: 2000 start: 734000 end: 736000
# is_sezure: False date: 2019-05-21 16:21:15 lenthWindow: 2000 start: 736000 end: 738000
# is_sezure: False date: 2019-05-21 16:21:19 lenthWindow: 2000 start: 738000 end: 740000
# is_sezure: False date: 2019-05-21 16:21:23 lenthWindow: 2000 start: 740000 end: 742000
# is_sezure: False date: 2019-05-21 16:21:27 lenthWindow: 2000 start: 742000 end: 744000
# is_sezure: False date: 2019-05-21 16:21:31 lenthWindow: 2000 start: 744000 end: 746000
# is_sezure: False date: 2019-05-21 16:21:35 lenthWindow: 2000 start: 746000 end: 748000
# is_sezure: False date: 2019-05-21 16:21:39 lenthWindow: 2000 start: 748000 end: 750000
# is_sezure: False date: 2019-05-21 16:21:43 lenthWindow: 2000 start: 750000 end: 752000
# is_sezure: False date: 2019-05-21 16:21:47 lenthWindow: 2000 start: 752000 end: 754000
# is_sezure: False date: 2019-05-21 16:21:51 lenthWindow: 2000 start: 754000 end: 756000
# is_sezure: False date: 2019-05-21 16:21:55 lenthWindow: 2000 start: 756000 end: 758000
# is_sezure: False date: 2019-05-21 16:21:59 lenthWindow: 2000 start: 758000 end: 760000
# is_sezure: False date: 2019-05-21 16:22:03 lenthWindow: 2000 start: 760000 end: 762000
# is_sezure: False date: 2019-05-21 16:22:07 lenthWindow: 2000 start: 762000 end: 764000
# is_sezure: False date: 2019-05-21 16:22:11 lenthWindow: 2000 start: 764000 end: 766000
# is_sezure: False date: 2019-05-21 16:22:15 lenthWindow: 2000 start: 766000 end: 768000
# is_sezure: False date: 2019-05-21 16:22:19 lenthWindow: 2000 start: 768000 end: 770000
# is_sezure: False date: 2019-05-21 16:22:23 lenthWindow: 2000 start: 770000 end: 772000
# is_sezure: False date: 2019-05-21 16:22:27 lenthWindow: 2000 start: 772000 end: 774000
# is_sezure: False date: 2019-05-21 16:22:31 lenthWindow: 2000 start: 774000 end: 776000
# is_sezure: False date: 2019-05-21 16:22:35 lenthWindow: 2000 start: 776000 end: 778000
# is_sezure: False date: 2019-05-21 16:22:39 lenthWindow: 2000 start: 778000 end: 780000
# is_sezure: False date: 2019-05-21 16:22:43 lenthWindow: 2000 start: 780000 end: 782000
# is_sezure: False date: 2019-05-21 16:22:47 lenthWindow: 2000 start: 782000 end: 784000
# is_sezure: False date: 2019-05-21 16:22:51 lenthWindow: 2000 start: 784000 end: 786000
# is_sezure: False date: 2019-05-21 16:22:55 lenthWindow: 2000 start: 786000 end: 788000
# is_sezure: False date: 2019-05-21 16:22:59 lenthWindow: 2000 start: 788000 end: 790000
# is_sezure: False date: 2019-05-21 16:23:03 lenthWindow: 2000 start: 790000 end: 792000
# is_sezure: False date: 2019-05-21 16:23:07 lenthWindow: 2000 start: 792000 end: 794000
# is_sezure: False date: 2019-05-21 16:23:11 lenthWindow: 2000 start: 794000 end: 796000
# is_sezure: False date: 2019-05-21 16:23:15 lenthWindow: 2000 start: 796000 end: 798000
# is_sezure: False date: 2019-05-21 16:23:19 lenthWindow: 2000 start: 798000 end: 800000
# is_sezure: False date: 2019-05-21 16:23:23 lenthWindow: 2000 start: 800000 end: 802000
# is_sezure: False date: 2019-05-21 16:23:27 lenthWindow: 2000 start: 802000 end: 804000
# is_sezure: False date: 2019-05-21 16:23:31 lenthWindow: 2000 start: 804000 end: 806000
# is_sezure: False date: 2019-05-21 16:23:35 lenthWindow: 2000 start: 806000 end: 808000
# is_sezure: False date: 2019-05-21 16:23:39 lenthWindow: 2000 start: 808000 end: 810000
# is_sezure: False date: 2019-05-21 16:23:43 lenthWindow: 2000 start: 810000 end: 812000
# is_sezure: False date: 2019-05-21 16:23:47 lenthWindow: 2000 start: 812000 end: 814000
# is_sezure: False date: 2019-05-21 16:23:51 lenthWindow: 2000 start: 814000 end: 816000
# is_sezure: False date: 2019-05-21 16:23:55 lenthWindow: 2000 start: 816000 end: 818000
# is_sezure: False date: 2019-05-21 16:23:59 lenthWindow: 2000 start: 818000 end: 820000
# is_sezure: False date: 2019-05-21 16:24:03 lenthWindow: 2000 start: 820000 end: 822000
# is_sezure: False date: 2019-05-21 16:24:07 lenthWindow: 2000 start: 822000 end: 824000
# is_sezure: False date: 2019-05-21 16:24:11 lenthWindow: 2000 start: 824000 end: 826000
# is_sezure: False date: 2019-05-21 16:24:15 lenthWindow: 2000 start: 826000 end: 828000
# is_sezure: False date: 2019-05-21 16:24:19 lenthWindow: 2000 start: 828000 end: 830000
# is_sezure: False date: 2019-05-21 16:24:23 lenthWindow: 2000 start: 830000 end: 832000
# is_sezure: False date: 2019-05-21 16:24:27 lenthWindow: 2000 start: 832000 end: 834000
# is_sezure: False date: 2019-05-21 16:24:31 lenthWindow: 2000 start: 834000 end: 836000
# is_sezure: False date: 2019-05-21 16:24:35 lenthWindow: 2000 start: 836000 end: 838000
# is_sezure: False date: 2019-05-21 16:24:39 lenthWindow: 2000 start: 838000 end: 840000
# is_sezure: False date: 2019-05-21 16:24:43 lenthWindow: 2000 start: 840000 end: 842000
# is_sezure: False date: 2019-05-21 16:24:47 lenthWindow: 2000 start: 842000 end: 844000
# is_sezure: False date: 2019-05-21 16:24:51 lenthWindow: 2000 start: 844000 end: 846000
# is_sezure: False date: 2019-05-21 16:24:55 lenthWindow: 2000 start: 846000 end: 848000
# is_sezure: False date: 2019-05-21 16:24:59 lenthWindow: 2000 start: 848000 end: 850000
# is_sezure: False date: 2019-05-21 16:25:03 lenthWindow: 2000 start: 850000 end: 852000
# is_sezure: False date: 2019-05-21 16:25:07 lenthWindow: 2000 start: 852000 end: 854000
# is_sezure: False date: 2019-05-21 16:25:11 lenthWindow: 2000 start: 854000 end: 856000
# is_sezure: False date: 2019-05-21 16:25:15 lenthWindow: 2000 start: 856000 end: 858000
# is_sezure: False date: 2019-05-21 16:25:19 lenthWindow: 2000 start: 858000 end: 860000
# is_sezure: False date: 2019-05-21 16:25:23 lenthWindow: 2000 start: 860000 end: 862000
# is_sezure: False date: 2019-05-21 16:25:27 lenthWindow: 2000 start: 862000 end: 864000
# is_sezure: False date: 2019-05-21 16:25:31 lenthWindow: 2000 start: 864000 end: 866000
# is_sezure: False date: 2019-05-21 16:25:35 lenthWindow: 2000 start: 866000 end: 868000
# is_sezure: False date: 2019-05-21 16:25:39 lenthWindow: 2000 start: 868000 end: 870000
# is_sezure: False date: 2019-05-21 16:25:43 lenthWindow: 2000 start: 870000 end: 872000
# is_sezure: False date: 2019-05-21 16:25:47 lenthWindow: 2000 start: 872000 end: 874000
# is_sezure: False date: 2019-05-21 16:25:51 lenthWindow: 2000 start: 874000 end: 876000
# is_sezure: False date: 2019-05-21 16:25:55 lenthWindow: 2000 start: 876000 end: 878000
# is_sezure: False date: 2019-05-21 16:25:59 lenthWindow: 2000 start: 878000 end: 880000
# is_sezure: False date: 2019-05-21 16:26:03 lenthWindow: 2000 start: 880000 end: 882000
# is_sezure: False date: 2019-05-21 16:26:07 lenthWindow: 2000 start: 882000 end: 884000
# is_sezure: False date: 2019-05-21 16:26:11 lenthWindow: 2000 start: 884000 end: 886000
# is_sezure: False date: 2019-05-21 16:26:15 lenthWindow: 2000 start: 886000 end: 888000
# is_sezure: False date: 2019-05-21 16:26:19 lenthWindow: 2000 start: 888000 end: 890000
# is_sezure: False date: 2019-05-21 16:26:23 lenthWindow: 2000 start: 890000 end: 892000
# is_sezure: False date: 2019-05-21 16:26:27 lenthWindow: 2000 start: 892000 end: 894000
# is_sezure: False date: 2019-05-21 16:26:31 lenthWindow: 2000 start: 894000 end: 896000
# is_sezure: False date: 2019-05-21 16:26:35 lenthWindow: 2000 start: 896000 end: 898000
# is_sezure: False date: 2019-05-21 16:26:39 lenthWindow: 2000 start: 898000 end: 900000
# is_sezure: False date: 2019-05-21 16:26:43 lenthWindow: 2000 start: 900000 end: 902000
# is_sezure: False date: 2019-05-21 16:26:47 lenthWindow: 2000 start: 902000 end: 904000
# is_sezure: False date: 2019-05-21 16:26:51 lenthWindow: 2000 start: 904000 end: 906000
# is_sezure: False date: 2019-05-21 16:26:55 lenthWindow: 2000 start: 906000 end: 908000
# is_sezure: False date: 2019-05-21 16:26:59 lenthWindow: 2000 start: 908000 end: 910000
# is_sezure: False date: 2019-05-21 16:27:03 lenthWindow: 2000 start: 910000 end: 912000
# is_sezure: False date: 2019-05-21 16:27:07 lenthWindow: 2000 start: 912000 end: 914000
# is_sezure: False date: 2019-05-21 16:27:11 lenthWindow: 2000 start: 914000 end: 916000
# is_sezure: False date: 2019-05-21 16:27:15 lenthWindow: 2000 start: 916000 end: 918000
# is_sezure: False date: 2019-05-21 16:27:19 lenthWindow: 2000 start: 918000 end: 920000
# is_sezure: False date: 2019-05-21 16:29:31 lenthWindow: 2000 start: 984000 end: 986000
# is_sezure: False date: 2019-05-21 16:29:35 lenthWindow: 2000 start: 986000 end: 988000
# is_sezure: False date: 2019-05-21 16:29:39 lenthWindow: 2000 start: 988000 end: 990000
# is_sezure: False date: 2019-05-21 16:29:43 lenthWindow: 2000 start: 990000 end: 992000
# is_sezure: False date: 2019-05-21 16:29:47 lenthWindow: 2000 start: 992000 end: 994000
# is_sezure: False date: 2019-05-21 16:29:51 lenthWindow: 2000 start: 994000 end: 996000
# is_sezure: False date: 2019-05-21 16:29:55 lenthWindow: 2000 start: 996000 end: 998000
# is_sezure: False date: 2019-05-21 16:29:59 lenthWindow: 2000 start: 998000 end: 1000000
# is_sezure: False date: 2019-05-21 16:30:03 lenthWindow: 2000 start: 1000000 end: 1002000
# is_sezure: False date: 2019-05-21 16:30:07 lenthWindow: 2000 start: 1002000 end: 1004000
# is_sezure: False date: 2019-05-21 16:30:11 lenthWindow: 2000 start: 1004000 end: 1006000
# is_sezure: False date: 2019-05-21 16:30:15 lenthWindow: 2000 start: 1006000 end: 1008000
# is_sezure: False date: 2019-05-21 16:30:19 lenthWindow: 2000 start: 1008000 end: 1010000
# is_sezure: False date: 2019-05-21 16:30:23 lenthWindow: 2000 start: 1010000 end: 1012000
# is_sezure: False date: 2019-05-21 16:30:27 lenthWindow: 2000 start: 1012000 end: 1014000
# is_sezure: False date: 2019-05-21 16:30:31 lenthWindow: 2000 start: 1014000 end: 1016000
# is_sezure: False date: 2019-05-21 16:30:35 lenthWindow: 2000 start: 1016000 end: 1018000
# is_sezure: False date: 2019-05-21 16:30:39 lenthWindow: 2000 start: 1018000 end: 1020000
# is_sezure: False date: 2019-05-21 16:30:43 lenthWindow: 2000 start: 1020000 end: 1022000
# is_sezure: False date: 2019-05-21 16:30:47 lenthWindow: 2000 start: 1022000 end: 1024000
# is_sezure: False date: 2019-05-21 16:30:51 lenthWindow: 2000 start: 1024000 end: 1026000
# is_sezure: False date: 2019-05-21 16:30:55 lenthWindow: 2000 start: 1026000 end: 1028000
# is_sezure: False date: 2019-05-21 16:30:59 lenthWindow: 2000 start: 1028000 end: 1030000
# is_sezure: False date: 2019-05-21 16:31:03 lenthWindow: 2000 start: 1030000 end: 1032000
# is_sezure: False date: 2019-05-21 16:31:07 lenthWindow: 2000 start: 1032000 end: 1034000
# is_sezure: False date: 2019-05-21 16:31:11 lenthWindow: 2000 start: 1034000 end: 1036000
# is_sezure: False date: 2019-05-21 16:31:15 lenthWindow: 2000 start: 1036000 end: 1038000
# is_sezure: False date: 2019-05-21 16:31:19 lenthWindow: 2000 start: 1038000 end: 1040000
# is_sezure: False date: 2019-05-21 16:31:23 lenthWindow: 2000 start: 1040000 end: 1042000
# is_sezure: False date: 2019-05-21 16:31:27 lenthWindow: 2000 start: 1042000 end: 1044000
# is_sezure: False date: 2019-05-21 16:31:31 lenthWindow: 2000 start: 1044000 end: 1046000
# is_sezure: False date: 2019-05-21 16:31:35 lenthWindow: 2000 start: 1046000 end: 1048000
# is_sezure: True date: 2019-05-21 16:07:19 lenthWindow: 2000 start: 318000 end: 320000
# is_sezure: True date: 2019-05-21 16:07:21 lenthWindow: 2000 start: 319000 end: 321000
# is_sezure: True date: 2019-05-21 16:07:23 lenthWindow: 2000 start: 320000 end: 322000
# is_sezure: True date: 2019-05-21 16:07:25 lenthWindow: 2000 start: 321000 end: 323000
# is_sezure: True date: 2019-05-21 16:07:27 lenthWindow: 2000 start: 322000 end: 324000
# is_sezure: True date: 2019-05-21 16:07:29 lenthWindow: 2000 start: 323000 end: 325000
# is_sezure: True date: 2019-05-21 16:07:31 lenthWindow: 2000 start: 324000 end: 326000
# is_sezure: True date: 2019-05-21 16:07:33 lenthWindow: 2000 start: 325000 end: 327000
# is_sezure: True date: 2019-05-21 16:07:35 lenthWindow: 2000 start: 326000 end: 328000
# is_sezure: True date: 2019-05-21 16:07:37 lenthWindow: 2000 start: 327000 end: 329000
# is_sezure: True date: 2019-05-21 16:07:39 lenthWindow: 2000 start: 328000 end: 330000
# is_sezure: True date: 2019-05-21 16:07:41 lenthWindow: 2000 start: 329000 end: 331000
# is_sezure: True date: 2019-05-21 16:07:43 lenthWindow: 2000 start: 330000 end: 332000
# is_sezure: True date: 2019-05-21 16:07:45 lenthWindow: 2000 start: 331000 end: 333000
# is_sezure: True date: 2019-05-21 16:07:47 lenthWindow: 2000 start: 332000 end: 334000
# is_sezure: True date: 2019-05-21 16:07:49 lenthWindow: 2000 start: 333000 end: 335000
# is_sezure: True date: 2019-05-21 16:07:51 lenthWindow: 2000 start: 334000 end: 336000
# is_sezure: True date: 2019-05-21 16:07:53 lenthWindow: 2000 start: 335000 end: 337000
# is_sezure: True date: 2019-05-21 16:07:55 lenthWindow: 2000 start: 336000 end: 338000
# is_sezure: True date: 2019-05-21 16:07:57 lenthWindow: 2000 start: 337000 end: 339000

# %%
non_sz_index_length = int(len(nsz_win))
sz_index_length = int(len(sz_win))
print(non_sz_index_length)
print(sz_index_length)
random_indexes_undersambler = random.sample(range(0,non_sz_index_length), sz_index_length)
random_indexes_undersambler
# Out:
# 16030
# 338
# [11437,
#  4079,
#  1686,
#  4279,
#  5140,
#  6440,
#  7519,
#  15282,
#  10925,
#  3586,
#  6123,
#  567,
#  13870,
#  11922,
#  6058,
#  6639,
#  8042,
#  788,
#  8469,
#  3184,
#  1061,
#  8347,
#  13248,
#  12880,
#  8626,
#  2571,
#  10178,
#  1450,
#  3356,
#  12563,
#  4820,
#  15902,
#  3787,
#  1006,
#  10811,
#  7067,
#  12682,
#  13699,
#  9871,
#  14523,
#  3679,
#  2192,
#  11754,
#  13501,
#  6684,
#  2183,
#  10849,
#  2459,
#  883,
#  10446,
#  3401,
#  15952,
#  9248,
#  3299,
#  12494,
#  2068,
#  5799,
#  11514,
#  768,
#  12274,
#  3427,
#  8160,
#  7221,
#  10948,
#  3253,
#  7462,
#  2946,
#  14273,
#  13009,
#  13173,
#  9315,
#  5766,
#  12847,
#  2290,
#  693,
#  13052,
#  14330,
#  3847,
#  3887,
#  2964,
#  10795,
#  10015,
#  8569,
#  11530,
#  10070,
#  13941,
#  14130,
#  10623,
#  15664,
#  14687,
#  11950,
#  15522,
#  8423,
#  13206,
#  7119,
#  2640,
#  7748,
#  972,
#  8096,
#  12660,
#  1377,
#  6279,
#  1133,
#  1751,
#  1371,
#  13820,
#  2603,
#  8651,
#  4680,
#  12337,
#  10287,
#  9851,
#  12102,
#  8422,
#  12841,
#  15416,
#  3579,
#  3909,
#  13785,
#  4690,
#  1268,
#  9388,
#  10412,
#  9781,
#  12605,
#  4182,
#  13210,
#  15939,
#  1442,
#  301,
#  9711,
#  12111,
#  10601,
#  6514,
#  13668,
#  4727,
#  8925,
#  10793,
#  7903,
#  5646,
#  6479,
#  5050,
#  8239,
#  13596,
#  2960,
#  6577,
#  8473,
#  9260,
#  234,
#  2154,
#  6159,
#  8480,
#  8608,
#  14948,
#  10616,
#  2098,
#  3678,
#  11243,
#  8254,
#  8632,
#  10940,
#  2970,
#  3690,
#  7402,
#  14453,
#  14926,
#  8313,
#  5744,
#  6623,
#  4555,
#  6589,
#  9191,
#  4912,
#  6854,
#  1424,
#  9154,
#  8978,
#  11293,
#  1066,
#  13490,
#  15483,
#  14765,
#  7595,
#  8500,
#  2761,
#  14606,
#  13446,
#  111,
#  6146,
#  1241,
#  15918,
#  9804,
#  4953,
#  2675,
#  14378,
#  7970,
#  7348,
#  6780,
#  4922,
#  2352,
#  8374,
#  5132,
#  13190,
#  4113,
#  3659,
#  13487,
#  5555,
#  59,
#  743,
#  9608,
#  5005,
#  5778,
#  8180,
#  10151,
#  4235,
#  4403,
#  10741,
#  474,
#  6621,
#  13182,
#  1495,
#  7687,
#  12912,
#  2248,
#  4345,
#  11515,
#  13476,
#  7623,
#  5665,
#  6012,
#  665,
#  7064,
#  14725,
#  12080,
#  492,
#  1532,
#  205,
#  6787,
#  16000,
#  3246,
#  15322,
#  7489,
#  10565,
#  1370,
#  1515,
#  10445,
#  12485,
#  453,
#  15774,
#  8639,
#  13271,
#  11848,
#  3501,
#  6482,
#  10833,
#  8756,
#  11959,
#  13123,
#  14277,
#  11439,
#  3199,
#  12836,
#  14278,
#  6861,
#  3434,
#  98,
#  7785,
#  14817,
#  3582,
#  14656,
#  12579,
#  7962,
#  3880,
#  2314,
#  5318,
#  5964,
#  6911,
#  10469,
#  11694,
#  10836,
#  8544,
#  14460,
#  11684,
#  9673,
#  8685,
#  12761,
#  6763,
#  8998,
#  9889,
#  13821,
#  6220,
#  782,
#  4389,
#  367,
#  3888,
#  6665,
#  5916,
#  380,
#  3174,
#  2250,
#  7477,
#  8318,
#  13109,
#  622,
#  14956,
#  13330,
#  3881,
#  5923,
#  10353,
#  12863,
#  5222,
#  1606,
#  6732,
#  14679,
#  1449,
#  14043,
#  7900,
#  14935,
#  8209,
#  15459,
#  9989,
#  8956,
#  6200,
#  4527,
#  2493,
#  3023,
#  14804,
#  1624,
#  12258,
#  15329,
#  8008,
#  12589,
#  6741,
#  7017,
#  12757,
#  9683,
#  6809,
#  7436]

# %%
list_keeper = []
for i in random_indexes_undersambler:
    window_of_choice = nsz_win[i]
    list_keeper.append(window_of_choice)
print(len(list_keeper))
# Out:
# 338

# %%
nsz_win = list_keeper
for x in range(5):
    print(nsz_win[x][1])
# Out:
# 2019-05-22 04:43:00.004000
# 2019-05-21 20:28:39
# 2019-05-21 17:49:07
# 2019-05-21 20:41:59
# 2019-05-21 21:39:23

# %%
print(type(nsz_win[x][0]))
print(type(nsz_win[x][0]))
# Out:
# <class 'list'>
# <class 'list'>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
w = np.array(sz_win[2][0])
plt.plot(w)

# %%
plt.figure(figsize=(3,4))
fig, axs = plt.subplots(4,2, figsize=(20,10))
plt.tight_layout()

for win in sz_win[0:1]:
    series, date_of_observation = win
    series = np.array(series)
    denoised_series = denoise_wavelet(series, method='BayesShrink',wavelet='db6', mode='soft',rescale_sigma=True, wavelet_levels=3)
    axs[0,0].set_title(f'$Sz-Before-denoise$ {date_of_observation}')
    axs[0,0].plot(series, color='red')
    axs[0,1].set_title(f'$Sz-After-denoise$ {date_of_observation}')
    axs[0,1].plot(denoised_series)
    axs[0,1].plot(series, color='red')
    pxx, freqs, bins, img = axs[1, 0].specgram(series,Fs=500,cmap='jet')
    pxx, freqs, bins, img = axs[1, 1].specgram(denoised_series,Fs=500,cmap='jet')

for win in nsz_win[100:101]:
    series, date_of_observation = win
    series = np.array(series)
    denoised_series = denoise_wavelet(series, method='BayesShrink',wavelet='db6', mode='soft',rescale_sigma=True, wavelet_levels=3)
    axs[2,0].set_title(f'$No-Sz-Before-denoise$ {date_of_observation}')
    axs[2,0].plot(series, color='blue')
    axs[2,1].set_title(f'$No-Sz-After-denoise$ {date_of_observation}')
    axs[2,1].plot(denoised_series)
    axs[2,1].plot(series, color='blue')
    pxx, freqs, bins, img = axs[3, 0].specgram(series,Fs=500,cmap='jet')
    pxx, freqs, bins, img = axs[3, 1].specgram(denoised_series,Fs=500,cmap='jet')

# %%
safe_window_path = "Dataset/windows/p4_nat2/"
sz_path = "sz/"
non_sz_path = "non-sz/"

# %%
def spec_transform_save_to_folder(index, win, is_seizure=False):
    plt.figure(figsize=(7,7))
    series, date_of_observation = win
    series = np.array(series)
    denoised_series = denoise_wavelet(series, method='BayesShrink',wavelet='db6', mode='soft',rescale_sigma=True, wavelet_levels=3)
    pxx, freqs, bins, img = plt.specgram(denoised_series,Fs=500,cmap='jet')
    if(is_seizure):
        plt.savefig(f'{safe_window_path}{sz_path}sz_{index}_{date_of_observation}.png')
    else:
        plt.savefig(f'{safe_window_path}{non_sz_path}nsz_{index}_{date_of_observation}.png')
    plt.close()

#Write to folders

for index, win in enumerate(sz_win):
    spec_transform_save_to_folder(index, win, is_seizure=True)

for index, win in enumerate(nsz_win):
    spec_transform_save_to_folder(index, win)

# %% [markdown]
# # Load png's and convert to np arrays with labels

# %%
event_time_path = "p4_nat2"
path_to_specplots = "Dataset/Windows/" + event_time_path

# %%
labels = [item for item in os.listdir(path_to_specplots)]
labels = np.array(labels)
labels = labels[1:]
print(labels.shape)
labels
# Out:
# (2,)
# array(['non-sz', 'sz'], dtype='<U9')

# %%
data_generator = ImageDataGenerator(rescale = 1./255, validation_split=0.3)

# %% [markdown]
# # Train, Test splits

# %%
spec_img_target_size_inception = (299, 299)
spec_img_target_size_inception_resnet = (224, 224)
spec_img_target_size_resnet = (224, 224)

# %%
train_data = data_generator.flow_from_directory(path_to_specplots, target_size=spec_img_target_size_resnet, color_mode='rgb', batch_size=32, classes = list(labels), subset='training')

valida_data = data_generator.flow_from_directory(path_to_specplots, target_size=spec_img_target_size_resnet, color_mode='rgb', batch_size=32, classes = list(labels), subset='validation')
# Out:
# Found 474 images belonging to 2 classes.
# Found 202 images belonging to 2 classes.

# %% [markdown]
# ## notice! we have the right img shape for the inception network as in the paper

# %%
train_data.image_shape
# Out:
# (224, 224, 3)

# %%
def show_batch(image, label):
  plt.figure(figsize=(10,10))
  for n in range(15):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image[n])
      plt.title(labels[label[n].argmax()])
      plt.axis('off')

# %%
image, label = next(train_data)
show_batch(image, label)

# %% [markdown]
# ## The paper loads the pretrained weights and doesn't freeze them

# %% [markdown]
# " Inception-v3
# has input images with a size of 299 × 299 × 3 and outputs
# 2,048-dimensional feature vectors" <br/>
# " (2) Loading
# pre-trained weights, and updating the parameters of the whole
# network during training.
# When the current datasets differ greatly from the datasets
# used in pre-trained weight training, the second approach above
# is usually adopted"

# %%
from tensorflow.keras.applications.resnet import ResNet152

base_resnet152 = ResNet152(
    weights='imagenet',
    include_top=False,
    input_shape = ((224, 224, 3))
)

for layer in base_resnet152.layers:
    layer.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234700800/234698864 [==============================] - 21s 0us/step

# %% [markdown]
# "Two fully connected layers with 1,024 and 512
# neurons are added to reduce the dimensions, and a dropout
# layer (0.5) is set behind each fully connected layer to prevent
# over-fitting. The softmax of the output layer is expressed as:" <br/>
# "For each image, the feature vectors extracted from three
# network features are concatenated into a 5,632-dimensional
# feature vector."

# %%
single_inc_model = Sequential()

single_inc_model.add(base_resnet152)
single_inc_model.add(layers.Dense(1024, activation='relu'))
single_inc_model.add(layers.Dropout(0.5))
single_inc_model.add(layers.Flatten())
single_inc_model.add(layers.Dense(512, activation='relu'))
single_inc_model.add(layers.Dropout(0.5))
single_inc_model.add(layers.Dense(2, activation='softmax'))

# %% [markdown]
# "An online hard example mining (OHEM) (29) loss function is
# used to replace the commonly used cross-entropy loss function;
# its expression is as Equation (5). In OHEM, the loss of a batch
# sample is sorted in descending order, and the largest k (topk
# )
# values are averaged as the final loss. "

# %%
# CREATE OHEM LOSS se: https://heartbeat.comet.ml/how-to-create-a-custom-loss-function-in-keras-637bd312e9ab og https://github.com/GXYM/OHEM-loss/blob/master/Ohem.py

# %%
single_inc_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
single_inc_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet152 (Functional)       (None, 7, 7, 2048)        58370944
# _________________________________________________________________
# dense (Dense)                (None, 7, 7, 1024)        2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               25690624
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 86,160,770
# Trainable params: 86,009,346
# Non-trainable params: 151,424
# _________________________________________________________________

# %%
class TestCallback(tensorflow.keras.callbacks.Callback):
    def __init__(self, test_data):
        self.test_data = test_data

    def on_epoch_end(self, epoch, logs={}):
        x = self.test_data
        loss, acc = self.model.evaluate(x, verbose=0)
        print('\nTesting loss: {}, acc: {}\n'.format(loss, acc))

# %%
history = single_inc_model.fit(
    train_data,
    epochs=10,
    steps_per_epoch = train_data.samples//32, 
    validation_data=valida_data, 
    validation_steps = valida_data.samples//32,
    callbacks=[TestCallback((valida_data))]
)
# Out:
# Epoch 1/10
# 14/14 [==============================] - 146s 10s/step - loss: 3.9913 - accuracy: 0.7511 - val_loss: 23605.0059 - val_accuracy: 0.4948
#
# Testing loss: 23361.353515625, acc: 0.5
#
# Epoch 2/10
# 14/14 [==============================] - 130s 9s/step - loss: 0.3954 - accuracy: 0.8869 - val_loss: 1591.0303 - val_accuracy: 0.5104
#
# Testing loss: 1624.9493408203125, acc: 0.5
#
# Epoch 3/10
# 14/14 [==============================] - 96s 7s/step - loss: 0.2675 - accuracy: 0.9095 - val_loss: 3791.2820 - val_accuracy: 0.5104
#
# Testing loss: 3878.010986328125, acc: 0.5
#
# Epoch 4/10
# 14/14 [==============================] - 98s 7s/step - loss: 0.2431 - accuracy: 0.9344 - val_loss: 1693.9163 - val_accuracy: 0.5000
#
# Testing loss: 1693.1302490234375, acc: 0.5
#
# Epoch 5/10
# 14/14 [==============================] - 100s 7s/step - loss: 0.1685 - accuracy: 0.9344 - val_loss: 1620.0638 - val_accuracy: 0.5104
#
# Testing loss: 1655.2490234375, acc: 0.5
#
# Epoch 6/10
# 14/14 [==============================] - 103s 7s/step - loss: 0.1606 - accuracy: 0.9389 - val_loss: 302.8106 - val_accuracy: 0.4792
#
# Testing loss: 290.708984375, acc: 0.5
#
# Epoch 7/10
# 14/14 [==============================] - 95s 7s/step - loss: 0.1554 - accuracy: 0.9389 - val_loss: 0.6931 - val_accuracy: 0.5052
#
# Testing loss: 0.6931948661804199, acc: 0.5
#
# Epoch 8/10
# 14/14 [==============================] - 96s 7s/step - loss: 0.2154 - accuracy: 0.9412 - val_loss: 0.6930 - val_accuracy: 0.5104
#
# Testing loss: 0.6931943297386169, acc: 0.5
#
# Epoch 9/10
# 14/14 [==============================] - 89s 6s/step - loss: 0.1712 - accuracy: 0.9412 - val_loss: 0.6930 - val_accuracy: 0.5156
#
# Testing loss: 0.6931812167167664, acc: 0.5
#
# Epoch 10/10
# 14/14 [==============================] - 98s 7s/step - loss: 0.2717 - accuracy: 0.8891 - val_loss: 0.6932 - val_accuracy: 0.5000
#
# Testing loss: 0.6931679248809814, acc: 0.5

# %%
plt.figure(figsize=(3,4))
fig, axs = plt.subplots(2,2, figsize=(10,10))
plt.tight_layout()
axs[0,0].set_title('acc')
axs[0,0].plot(history.history['accuracy'], color='red')
axs[0,1].set_title('loss')
axs[0,1].plot(history.history['loss'], color='red')
axs[1,0].set_title('val_acc')
axs[1,0].plot(history.history['val_accuracy'], color='red')
axs[1,1].set_title('val_loss')
axs[1,1].plot(history.history['val_loss'], color='red')
